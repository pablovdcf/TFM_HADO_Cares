# %% [markdown]
# # Información sobre los datos
#
# En los datos de HADO 2022, 2021 y 2020 *(Pendiente de recibir datos anteriores)*
#
# * **Fecha de alta:** Fecha en la que el paciente fue dado de alta del hospital (esta fecha solo existe para la mitad del 2022 y no está en el resto de los datos)
#
# * **H. Procedencia:** Hospital o centro médico de donde proviene el paciente.
#
# * **Servicio:** Servicio médico en el que fue atendido el paciente.
#
# * **AP**: Atención Primaria. Indica si el paciente fue derivado desde Atención Primaria o no.
#
# * **Motivo ING:** Motivo de ingreso del paciente en el hospital.
#
# * **Diagnóstico Principal:** Diagnóstico principal que se realizó al paciente durante su estancia en el hospital.
#
# * **Agudo Estable:** Indica si el paciente presentaba un estado agudo o estable.
#
# * **Crónico Agud.:** Indica si el paciente presenta alguna enfermedad crónica con un empeoramiento agudo.
#
# * **Paliativo ONC:** Indica si el paciente está recibiendo cuidados paliativos relacionados con una enfermedad oncológica.
#
# * **Palt No ONC:** Indica si el paciente está recibiendo cuidados paliativos por una enfermedad no oncológica.
#
# * **Trato antibiótico:** Indica si el paciente recibió tratamiento con antibióticos durante su estancia en el hospital.
#
# * **Dolor:** Indica si el paciente presentaba dolor durante su estancia en el hospital.
#
# * **Delirium:** Indica si el paciente presentaba delirium durante su estancia en el hospital.
#
# * **Disnea:** Indica si el paciente presentaba dificultad para respirar durante su estancia en el hospital.
#
# * **Ast-Anorx:** Indica si el paciente presenta un diagnóstico de astenia o anorexia. (cansado o tiene hambre)
#
# * **Fiebre:** Indica si el paciente presentaba fiebre durante su estancia en el hospital.
#
# * **Transfusion:** Indica si el paciente recibió una transfusión sanguínea durante su estancia en el hospital.
#
# * **Paracentesis:** Indica si se realizó una paracentesis durante la estancia del paciente en el hospital.
#
# * **Toracocentesis:** Indica si se realizó una toracocentesis durante la estancia del paciente en el hospital.
#
# * **PS/ECOG:** Escala de evaluación de la calidad de vida y del desempeño de actividades diarias del paciente.
#
# * **Barthel:** Indica el grado de dependencia del paciente para realizar actividades de la vida diaria.
#
# * **GDS/FAST:** Escala de evaluación de la función cognitiva del paciente.
#
# * **Otros/Complicaciones:** Indica cualquier otra complicación médica que haya surgido durante la estancia del paciente en el hospital.
#
# * **Agonia:** Indica si el paciente estaba en una fase terminal de la enfermedad y cerca de fallecer.
#
# * **Sedación:** Indica si el paciente recibió sedación para manejo de su dolor o ansiedad.
#
# * **Motivo Alta:** Indica el motivo por el cual el paciente fue dado de alta del hospital.
#
# * **N.º Visitas:** Número de veces que el paciente fue visitado por el personal médico durante su estancia en el hospital.
#
# * **N.º estancias:** Número de días que el paciente permaneció en el hospital.
#
# * **Ayuntamiento:** Ayuntamiento de residencia del paciente.
#
# * **Médico:** Nombre del médico que atendió al paciente durante su estancia en el hospital.

# %% [markdown]
# # Propuestas de proyecto:
#
# Los datos proporcionados parecen ser registros médicos de pacientes, que contienen información sobre su procedencia, servicios, diagnósticos, tratamientos, complicaciones, alta médica y otras variables. Con estos datos se pueden realizar varios proyectos de data science, algunos ejemplos podrían ser:

# %% [markdown]
# >1. **Análisis de los diagnósticos principales**: se podría analizar los diagnósticos principales para determinar las patologías más frecuentes que presentan los pacientes, así como su evolución a lo largo del tiempo y las posibles asociaciones con otras variables.
#
# >2. **Modelado de la estancia hospitalaria**: se podría modelar la estancia hospitalaria de los pacientes a partir de las variables disponibles en el dataset, para tratar de identificar los factores que influyen en su duración y cómo afectan a los distintos tipos de pacientes.
#
# >3. **Predicción del alta hospitalaria**: se podría desarrollar un modelo para predecir la fecha en que un paciente será dado de alta, teniendo en cuenta las variables disponibles y tratando de identificar aquellas que son más relevantes para la predicción.
#
# >4. **Análisis de la calidad de la atención**: se podría analizar la calidad de la atención a partir de variables como el número de visitas o estancias, el tipo de tratamiento recibido, el tipo de diagnóstico, etc., con el objetivo de identificar posibles áreas de mejora en la atención hospitalaria.
#
# >5. **Análisis de la mortalidad hospitalaria**: se podría analizar la mortalidad hospitalaria para tratar de identificar los factores que influyen en ella, así como para identificar patrones o grupos de pacientes que presenten un mayor riesgo de mortalidad.
#
# >6. **Clasificación de los pacientes**: se podría realizar una clasificación de los pacientes en función de su diagnóstico principal, su estado de salud, el tipo de tratamiento recibido, etc., con el objetivo de identificar posibles patrones o grupos de pacientes que presenten características similares.
#
# >7. **Análisis de tratamientos**: Utilizando las variables relacionadas con los tratamientos, se podría analizar qué tratamientos son más efectivos para diferentes diagnósticos y condiciones, y cómo influyen en el tiempo de estancia hospitalaria, la mortalidad y las complicaciones. Esto podría ayudar a los médicos y hospitales a tomar decisiones más informadas sobre los tratamientos a prescribir.
#
# >8. **Análisis de tendencias**: Utilizando las columnas de fechas, visitas y estancias, se puede analizar las tendencias en el número de pacientes ingresados en el hospital, el tiempo de estancia, y la frecuencia de visitas en un período determinado. Esto podría ayudar a los hospitales a planificar mejor su capacidad y recursos.

# %% [markdown]
# # Procedimiento para el trabajo
#
# 1. **Análisis exploratorio de datos (EDA)**: realizar un análisis detallado de los datos disponibles para identificar patrones y tendencias que puedan ayudar a entender mejor los datos. El EDA también ayudará a identificar cualquier problema con los datos, como valores atípicos o datos faltantes.
#
# 2. **Preprocesamiento de datos**: limpiar y preprocesar los datos para eliminar valores atípicos, datos faltantes y cualquier otro problema que pueda afectar la calidad del análisis. También aplicar técnicas de **normalización** y **estandarización** para asegurarse de que los datos estén en un formato adecuado para el análisis.
#
# 3. **Análisis de correlación**: investigar la correlación entre las variables disponibles para identificar cualquier patrón o relación entre ellas.
#
# 4. **Análisis de regresión**: aplicar técnicas de regresión para entender la relación entre variables dependientes e independientes y predecir valores futuros.
#
# 5. **Modelos predictivos**: usar modelos predictivos para hacer predicciones precisas sobre variables importantes.
#
# 6. **Análisis de series temporales**: si los datos incluyen información temporal, aplicar técnicas de análisis de series temporales para identificar patrones y tendencias a lo largo del tiempo.

# %% [markdown]
# # Pasos a seguir:
#
# 1. **Identificación del problema y definición de objetivos**: En este caso, el problema podría ser analizar los motivos de ingreso de los pacientes en un hospital y cómo se relacionan con otras variables, como el tiempo de estancia, el tratamiento recibido y la causa de alta. Los objetivos específicos podrían ser identificar patrones en los motivos de ingreso y su relación con otras variables y analizar la eficacia de diferentes tratamientos en función del motivo de ingreso.
#
# 2. **Recopilación de datos**: Para este proyecto, ya contamos con un dataframe con los datos de los pacientes. Sin embargo, es importante tener en cuenta las limitaciones de la Ley de protección de datos hacia los pacientes y asegurarnos de que no incluimos información que pudiera identificar a individuos específicos.
#
# 3. **Preparación de los datos**: En este paso, deberíamos revisar el dataframe para asegurarnos de que los datos estén limpios, completos y consistentes. Esto podría incluir la eliminación de columnas o filas irrelevantes o incompletas, la corrección de errores o inconsistencias en los datos y la codificación de variables categóricas para su uso en análisis estadísticos.
#
# 4. **Análisis exploratorio de datos**: Antes de comenzar con el análisis formal, es importante explorar los datos para entender mejor las relaciones entre las diferentes variables. Esto podría incluir gráficos y estadísticas descriptivas para resumir los datos y detectar posibles patrones o anomalías.
#
# 5. **Modelado y análisis estadístico**: Con los datos preparados y explorados, podemos comenzar a realizar análisis estadísticos y modelado para responder a nuestras preguntas de investigación. Esto podría incluir modelos de regresión para analizar la relación entre diferentes variables, modelos de clasificación para predecir el resultado del tratamiento y modelos de clustering para identificar grupos de pacientes con características similares.
#
# 6. **Evaluación y presentación de resultados**: Una vez que hayamos realizado el análisis estadístico y el modelado, debemos evaluar los resultados y presentarlos de una manera clara y comprensible. Esto podría incluir tablas, gráficos y explicaciones detalladas de los resultados, así como la interpretación de los mismos en relación con los objetivos del proyecto.
#
# 7. **Documentación y replicabilidad**: Para asegurarnos de que nuestro trabajo sea replicable, es importante documentar el proceso de análisis de datos y modelado. Esto podría incluir la creación de un informe detallado que explique los pasos que se siguieron, las decisiones tomadas y los resultados obtenidos. Además, deberíamos asegurarnos de que nuestro código sea legible y esté bien comentado para que otros puedan entender y replicar nuestro trabajo.
#
# 8. **UX y usabilidad**: Por último, pero no menos importante, es importante asegurarse de que nuestro análisis estadístico y modelado sea fácil de entender y utilizar por aquellos que lo necesiten. Esto podría implicar la creación de una interfaz de usuario intuitiva y fácil de usar para acceder a los resultados y obtener información relevante de manera sencilla y clara.

# %% [markdown]
# # Modulos y librerías
#
# Para leer un archivo ODS
# from pandas_ods_reader import read_ods

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
from pandas_ods_reader import read_ods

df_22 = read_ods("data/HADO 22.ods",sheet="Hoja1")  # Los valores están en la hoja 1
df_21 = read_ods("data/HADO21.ods")
df_20 = read_ods("data/HADO 20.ods")
df_19 = read_ods("data/HADO 19.ods")
df_18 = read_ods('data/Estadistica 2018.ods')
df_17 = read_ods("data/Estadística 2017.ods")

# %% [markdown]
# # Columnas
#
# ## Primero observo las columnas de los dataframes
#
# 1. Leo los datos
# ````python
# from pandas_ods_reader import read_ods
#
# df_22 = read_ods("data/HADO 22.ods",sheet= "Hoja1")
# df_21 = read_ods("data/HADO21.ods")
# df_20 = read_ods("data/HADO 20.ods")
# df_19 = read_ods("data/HADO 19.ods")
# df_18 = read_ods('data/Estadistica 2018.ods')
# df_17 = read_ods("data/Estadística 2017.ods")
# ````
# * Observamos espacios en los valores de las columnas pero antes hago unas transformaciones en los datos de 2019 ya que se repite la columna otros
#
# ````
# #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hospital        427 non-null    object
#  1   Servicio        427 non-null    object
#  2       AP          427 non-null    object
#  3    Otros          427 non-null    object
#  4   Diagnostico     427 non-null    object
#  5   Motivo Ing      421 non-null    object
#  6    pal Onc        427 non-null    object
#  7   Pal no Onc      427 non-null    object
#  8     Fiebre        426 non-null    object
#  9    Disnea         427 non-null    object
#  10    Dolor         427 non-null    object
#  11  Delirium        427 non-null    object
#  12  Astenia         427 non-null    object
#  13  Anorexia        427 non-null    object
#  14     Otros        427 non-null    object
#  15   P. terminal    426 non-null    object
#  16    Agonía        427 non-null    object
#  17    PS/IK         427 non-null    object
#  18  Barthel         427 non-null    object
#  19  GDS-FAST        427 non-null    object
#  20  EVA ing         426 non-null    object
#  21     Otros.1      427 non-null    object
#  22  Complicaciones  426 non-null    object
#  23  Nº estancias    427 non-null    float64
#  24  Nº visitas      427 non-null    object
#  25  SEDACIÓN        427 non-null    object
#  26  Mot. ALTA       427 non-null    object
#  27  Médico          427 non-null    object
# ````
# 2. Soluciono el problema de la columna 'Otros' duplicada
#
# ````python
# new_column_names = { ' Otros': 'otros', '   Otros': 'otros_1', '   Otros.1': 'otros_2'}
#
# df_19 = df_19.rename(columns=new_column_names)
# ````
# Entonces podemos hacer un strip pero esto separa también los espacios que forman los nombres de la columna
#
# ```python
# def df_split_lower(df: pd.DataFrame) -> list:
#     df.columns = df.columns.str.strip()         # Clean the spaces in columns names
#     df.columns = df.columns.str.lower()         # To lowercase
#     return df.columns
# ```
# 3. Aplico la función con un bucle for
#
# ````python
# total = 0
# for i, df in enumerate(dfs):
#     i += 2017
#     df_split_lower(df)
#     total += len(df)
#     print("df", i)
#     print(df.columns)
#     print(total)
# ````
# 4. Despues de pasar todas las columnas a lower y quitar espacios hacemos el rename
#
# ````python
# data_2017 = df_17.rename(columns={'hospital': 'h_procedencia',
#                                'servicio': 's_procedencia',
#                                'ap': 'ap',
#                                'otros': 'otros',
#                                'diagnostico': 'diagnostico',
#                                'motivo ing': 'motivo_ing',
#                                'paliativo onc': 'paliativo_onc/noc',
#                                'paliativo no onc': 'paliativo_no_onc/noc',
#                                'fiebre': 'fiebre',
#                                'disnea': 'disnea',
#                                'dolor': 'dolor',
#                                'delirium': 'delirium',
#                                'astenia': 'astenia',
#                                'anorexia': 'anorexia',
#                                'otros.1': 'otros_1',
#                                'agonía': 'agonia',
#                                'p terminal': 'p_terminal',
#                                'ps/ik': 'ps/ecog',
#                                'barthel': 'barthel',
#                                'gds-fast': 'gds/fast',
#                                'eva ing': 'eva_ing',
#                                'otros.2': 'otros_2',
#                                'complicaciones': 'otros/complicaciones',
#                                'nº estancias': "n_estancias",
#                                'nº visitas': "n_visitas",
#                                'sedación': 'sedacion',
#                                'mot. alta': 'motivo_alta',
#                                'médico': 'medico'})
#
# data_2018 = df_18.rename(columns={'hospital': 'h_procedencia',
#                                'servicio': 's_procedencia',
#                                'ap': 'ap',
#                                'otros': 'otros',
#                                'diagnostico': 'diagnostico',
#                                'motivo ing': 'motivo_ing',
#                                'paliativo onc': 'paliativo_onc/noc',
#                                'paliativo no onc': 'paliativo_no_onc/noc',
#                                'fiebre': 'fiebre',
#                                'disnea': 'disnea',
#                                'dolor': 'dolor',
#                                'delirium': 'delirium',
#                                'astenia': 'astenia',
#                                'anorexia': 'anorexia',
#                                'otros.1': 'otros_1',
#                                'agonía': 'agonia',
#                                'p terminal': 'p_terminal',
#                                'ps/ik': 'ps/ecog',
#                                'barthel': 'barthel',
#                                'gds-fast': 'gds/fast',
#                                'eva ing': 'eva_ing',
#                                'otros.2': 'otros_2',
#                                'complicaciones': 'otros/complicaciones',
#                                'nº estancias': "n_estancias",
#                                'nº visitas': "n_visitas",
#                                'sedación': 'sedacion',
#                                'mot. alta': 'motivo_alta',
#                                'médico': 'medico'})
#
# data_2019 = df_19.rename(columns={'hospital': 'h_procedencia',
#                                'servicio': 's_procedencia',
#                                'ap': 'ap',
#                                'otros': 'otros',
#                                'diagnostico': 'diagnostico',
#                                'motivo ing': 'motivo_ing',
#                                'pal onc': 'paliativo_onc/noc',
#                                'pal no onc': 'paliativo_no_onc/noc',
#                                'fiebre': 'fiebre',
#                                'disnea': 'disnea',
#                                'dolor': 'dolor',
#                                'delirium': 'delirium',
#                                'astenia': 'astenia',
#                                'anorexia': 'anorexia',
#                                'otros_1': 'otros_1', # Problema se repite otros en una colunmna ver si lo traga así
#                                'agonía': 'agonia',
#                                'p. terminal': 'p_terminal',
#                                'ps/ik': 'ps/ecog',
#                                'barthel': 'barthel',
#                                'gds-fast': 'gds/fast',
#                                'eva ing': 'eva_ing',
#                                'otros_2': 'otros_2',
#                                'complicaciones': 'otros/complicaciones',
#                                'nº estancias': "n_estancias",
#                                'nº visitas': "n_visitas",
#                                'sedación': 'sedacion',
#                                'mot. alta': 'motivo_alta',
#                                'médico': 'medico'})
#
# data_2020 = df_20.rename(columns={'h proced': 'h_procedencia',
#                                's proced': 's_procedencia',
#                                'ap': 'ap',
#                                'otros': 'otros',
#                                'diag principal': 'diagnostico',
#                                'motivo ing': 'motivo_ing',
#                                'agudo estable': 'agudo_estable',    # Posible otros
#                                'crónico reag': 'cronico_reag',      # Posible otros
#                                'paliativo onc': 'paliativo_onc/noc',
#                                'pal no onc': 'paliativo_no_onc/noc',
#                                'trato antibiótico': "trato_antibiotico",
#                                'dolor': 'dolor',
#                                'delirium': 'delirium',
#                                'disnea': 'disnea',
#                                'ast-anorx': 'ast/anorx',     # Agrupan astenia y anorexia (en 17,18 y 19 la separaban)
#                                'fiebre': 'fiebre',
#                                'transfusion': 'transfusion',        # Posible otros
#                                'paracentesis': 'paracentesis',      # Posible otros
#                                'toracentesis': 'toracentesis',
#                                'ps/ik': 'ps/ecog',
#                                'barthel': 'barthel',
#                                'gds-fast': 'gds/fast',
#                                'otros/complicaciones': 'otros/complicaciones',
#                                'agonía': 'agonia',
#                                'sedación': 'sedacion',
#                                'motivo alta': 'motivo_alta',
#                                'n.º estancias': "n_estancias",
#                                'n.º visitas': "n_visitas",
#                                'ayuntamiento': 'ayuntamiento',          # Se empieza a incluir en el 2020
#                                'médico': 'medico'})
#
# data_2021 = df_21.rename(columns={'h proced': 'h_procedencia',
#                                's proced': 's_procedencia',
#                                'ap': 'ap',
#                                'otros': 'otros',
#                                'diag principal': 'diagnostico',
#                                'motivo ing': 'motivo_ing',
#                                'agudo estable': 'agudo_estable',    # Posible otros
#                                'crónico reag': 'cronico_reag',      # Posible otros
#                                'paliativo onc': 'paliativo_onc/noc',
#                                'pal no onc': 'paliativo_no_onc/noc',
#                                'trato antibiótico': "trato_antibiotico",
#                                'dolor': 'dolor',
#                                'delirium': 'delirium',
#                                'disnea': 'disnea',
#                                'ast-anorx': 'ast/anorx',     # Agrupan astenia y anorexia (en 17,18 y 19 la separaban)
#                                'fiebre': 'fiebre',
#                                'transfusion': 'transfusion',        # Posible otros
#                                'paracentesis': 'paracentesis',      # Posible otros
#                                'toracentesis': 'toracentesis',
#                                'ps/ik': 'ps/ecog',
#                                'barthel': 'barthel',
#                                'gds-fast': 'gds/fast',
#                                'otros/complicaciones': 'otros/complicaciones',
#                                'agonia': 'agonia',
#                                'sedación': 'sedacion',
#                                'motivo alta': 'motivo_alta',
#                                'n.º estancias': "n_estancias",
#                                'n.º visitas': "n_visitas",
#                                'ayuntamiento': 'ayuntamiento',          # Se empieza a incluir en el 2020
#                                'médico': 'medico'})
#
# data_2022 = df_22.rename(columns={'fecha de alta': 'fecha_alta',
#                                'h.procedencia': 'h_procedencia',
#                                'servicio': 's_procedencia',
#                                'ap': 'ap',
#                                'motivo ing': 'motivo_ing',
#                                'diagnóstico principal': 'diagnostico',
#                                'agudo estable': 'agudo_estable',    # Posible otros
#                                'crónico agud.': 'cronico_reag',      # Posible otros
#                                'paliativo onc': 'paliativo_onc/noc',
#                                'palt no onc': 'paliativo_no_onc/noc',
#                                'antibiotico iv': "trato_antibiotico",
#                                'dolor': 'dolor',
#                                'disnea': 'disnea',
#                                's febril': 'fiebre',
#                                'delirium': 'delirium',
#                                'astenia/anorexia': 'ast/anorx', # Agrupan astenia y anorexia (en 17,18 y 19 la separaban)
#                                'fe iv': '¿?',          # Se añade en 2022 (Puede ser fiebre)
#                                'transf': 'transfusion',        # Posible otros
#                                'paracen': 'paracentesis',      # Posible otros
#                                'toracen': 'toracentesis',
#                                'ps/ecog': 'ps/ecog',
#                                'barthel': 'barthel',
#                                'gds/fast': 'gds/fast',
#                                'sedación': 'sedacion',
#                                'motivo alta': 'motivo_alta',
#                                'n.º estancias': "n_estancias",
#                                'n.º visitas': "n_visitas",
#                                'ayuntamiento': 'ayuntamiento',          # Se empieza a incluir en el 2020
#                                'médico': 'medico'})
# `````
#
# * Antes de hacer el concat o el merge vamos a crear una columna nueva de año para cada dataframe y así identificar a que año pertenecen esos datos.
#
# 5. Añadimos columna year para identificar el año de los datos.
#
# ````python
# data_2017["year"] = 2017
# data_2018["year"] = 2018
# data_2019["year"] = 2019
# data_2020["year"] = 2020
# data_2021["year"] = 2021
# data_2022["year"] = 2022
# ````
# 6. Seleccionamos y eliminamos las columnas no deseadas
#
#    * Eliminamos la columna `unnamed.1` No conocemos que representan los 5 valores unnamed de los datos de 2017.
#    * La columna de `trato_anibiotico` solo está a partir del 2020 se mantiene pero solo para esos años
#    * La columna de astenia y anorexia viene a partir del 2020 agrupada
#      * Agrupar los datos de astenia y anorexia del 17 al 19 antes del `concat` y renombrar la columna por `ast/anorx`
#    * La columna fe_iv no sé a que pertenece pero solo está en 2022 con el nombre cambiado a `¿?`
#    * ¿Qué hacer con las columnas `otros_1` y `otros_2`?
#
# ````python
# # Quitamos columnas innecesarias
#
# data_2017.drop(columns="unnamed.1", inplace=True)  # Unnamed no tiene valores importantes sólo 5 valores numéricos que no sé que son
# ````
# ````python
# # Función para eliminar la columna de trato_antibiotico de los datos de 2020 en adelante
# def del_trato_antibiotico(dataframes):
#     for df in dataframes:
#         df = df.drop(['trato_antibiotico'], axis=1, inplace=True)
#
# # Función para agrupar las columnas de astenia y anorexia porque se agrupan en los datos de 2020 en adelante
#
# def col_astenia_anorexia(dataframes):
#     for df in dataframes:
#         df['ast/anorx'] = np.where(df['astenia']=='si', 'si', df['anorexia'])
#         df = df.drop(['astenia', 'anorexia'],axis=1, inplace=True)
# ````
# 7. Agrupamos astenia y anorexia y eliminamos la columna trato antibiotico
# ````python
# astenia_anorexia = [data_2017, data_2018, data_2019]      # Lista con los df que tienen astenia y anorexia separados
#
# col_astenia_anorexia(astenia_anorexia)
#
# datos_trato_antibiotico = [data_2020, data_2021, data_2022]
#
# del_trato_antibiotico(datos_trato_antibiotico)
# ````
#
# 8. Seguidamente creo una lista con todos los dataframes renombrados:
#
# ````python
# all_data_rename = [data_2017, data_2018, data_2019 ,data_2020, data_2021, data_2022]
# ````
#
# 9. Muestro los datos con la función para ver la forma e información de los dataframes
# ````python
# def df_split_lower_list(dataframes) -> list:
#     for df in dataframes:
#         df.columns = df.columns.str.strip()         # Clean the spaces in columns names
#         df.columns = df.columns.str.lower()         # To lowercase
#         print(df.columns)
#
# for i, data in enumerate(all_data_rename):
#     i += 2017
#     print("Datos del año",i)
#     print(data.shape)
#     print(data.info())
#     print("="*80)
# ````
# 10. Hago el concat de todos los dataframes
# ````python
# df_concatenado = pd.concat(all_data_rename, ignore_index=True, axis=0)
# ````
# * Para ver si hay index duplicado:
# ````python
# print(data_2017.index.duplicated().sum())
# print(data_2018.index.duplicated().sum())
# print(data_2019.index.duplicated().sum())
# print(data_2020.index.duplicated().sum())
# print(data_2021.index.duplicated().sum())
# print(data_2022.index.duplicated().sum())
# ````
# 11. Función para ver los valores unicos del dataframe concatenado
# ````python
# def unicos(df):
#     columns = df.columns.tolist()
#     for i, column in enumerate(columns):
#         v_column = df[column].unique()
#         print(df.columns.values[i])
#         print(len(v_column), v_column)
#         print("="*66)
# ````
#
# # NEXT STEPS:
#
# 1. Limpieza de los datos.
# 2. Pasar los datos que correspondan a enteros.
# 3. Normalizar los datos.
# 4. **Fuzzy String Matching**
#
# # TO DOS:
#
#  1. Municipios, datos faltantes
#  2. Normalizar y pasar el tipo de datos
#  3. Preguntar columnas `otros` y con interrogantes (fe iv)
#  4. ~~Group de astenia y anorexia para las otras fechas que van por separado~~
#  5. ~~Columna otros duplicada en 2019. Solucionar~~
#  6. Hacer dataframe con listas de los valores correctos para remplazar con 'fuzzywuzzy'
#     1. H.procedencia, servicio, ap, ast/anorx, etc
#     > Fuzzywuzzy ahora es `thefuzz` https://github.com/seatgeek/thefuzz

# %%
# Le cambio el nombre a la columna duplicada otros

new_column_names = { ' Otros': 'otros', '   Otros': 'otros_1', '   Otros.1': 'otros_2'}

df_19 = df_19.rename(columns=new_column_names)

# %%
df_19.columns
# Out:
# Index(['Hospital', 'Servicio', '    AP', 'otros', 'Diagnostico', 'Motivo Ing',
#        ' pal Onc', 'Pal no Onc', '  Fiebre', ' Disnea', '  Dolor', 'Delirium',
#        'Astenia', 'Anorexia', 'otros_1', ' P. terminal ', '  Agonía',
#        '  PS/IK', 'Barthel', 'GDS-FAST', 'EVA ing', 'otros_2',
#        'Complicaciones', 'Nº estancias', 'Nº visitas', 'SEDACIÓN', 'Mot. ALTA',
#        'Médico'],
#       dtype='object')

# %% [markdown]
# Después de leer los datos y cambiar las columnas problemáticas. Los pasamos a una lista

# %%
# CUIDADO CON LAS LISTAS QUE LAS CARGA EL DIABLO
# SI DESPUÉS DE REALIZAR ALGÚN CAMBIO EN UN DATAFRAME HAY QUE VOLVER A CARGAR LA LISTA
# PORQUE SINO SE QUEDAN LOS VALORES ANTERIORES DEL DATAFRAME SIN LAS MODIFICACIONES

dfs = [df_17, df_18, df_19, df_20, df_21, df_22]

# %% [markdown]
# Observamos espacios en los valores de las columnas
#
# Entonces podemos hacer un strip pero esto separa también los espacios que forman los nombres de la columna

# %%
def df_split_lower_list(dataframes) -> list:
    for df in dataframes:
        df.columns = df.columns.str.strip()         # Clean the spaces in columns names
        df.columns = df.columns.str.lower()         # To lowercase
        print(df.columns)

# %%
def df_split_lower(df: pd.DataFrame) -> list:
    df.columns = df.columns.str.strip()         # Clean the spaces in columns names
    df.columns = df.columns.str.lower()         # To lowercase
    return df.columns

# %%
df_split_lower_list(dfs)
# Out:
# Index(['hospital', 'servicio', 'ap', 'otros', 'diagnostico', 'motivo ing',
#        'paliativo onc', 'paliativo no onc', 'fiebre', 'disnea', 'dolor',
#        'delirium', 'astenia', 'anorexia', 'otros.1', 'p terminal', 'agonía',
#        'ps/ik', 'barthel', 'gds-fast', 'eva ing', 'otros.2', 'complicaciones',
#        'nº estancias', 'nº visitas', 'sedación', 'mot. alta', 'médico',
#        'unnamed.1'],
#       dtype='object')
# Index(['hospital', 'servicio', 'ap', 'otros', 'diagnostico', 'motivo ing',
#        'paliativo onc', 'paliativo no onc', 'fiebre', 'disnea', 'dolor',
#        'delirium', 'astenia', 'anorexia', 'otros.1', 'p terminal', 'agonía',
#        'ps/ik', 'barthel', 'gds-fast', 'eva ing', 'otros.2', 'complicaciones',
#        'nº estancias', 'nº visitas', 'sedación', 'mot. alta', 'médico'],
#       dtype='object')
# Index(['hospital', 'servicio', 'ap', 'otros', 'diagnostico', 'motivo ing',
#        'pal onc', 'pal no onc', 'fiebre', 'disnea', 'dolor', 'delirium',
#        'astenia', 'anorexia', 'otros_1', 'p. terminal', 'agonía', 'ps/ik',
#        'barthel', 'gds-fast', 'eva ing', 'otros_2', 'complicaciones',
#        'nº estancias', 'nº visitas', 'sedación', 'mot. alta', 'médico'],
#       dtype='object')
# Index(['h proced', 's proced', 'ap', 'otros', 'diag principal', 'motivo ing',
#        'agudo estable', 'crónico reag', 'paliativo onc', 'pal no onc',
#        'trato antibiótico', 'dolor', 'delirium', 'disnea', 'ast-anorx',
#        'fiebre', 'transfusion', 'paracentesis', 'toracocentesis', 'ps/ik',
#        'barthel', 'gds-fast', 'otros/complicaciones', 'agonia', 'sedación',
#        'motivo alta', 'n.º visitas', 'n.º estancias', 'ayuntamiento',
#        'médico'],
#       dtype='object')
# Index(['h proced', 's proced', 'ap', 'otros', 'diag principal', 'motivo ing',
#        'agudo estable', 'crónico reag', 'paliativo onc', 'pal no onc',
#        'trato antibiótico', 'dolor', 'delirium', 'disnea', 'ast-anorx',
#        'fiebre', 'transfusion', 'paracentesis', 'toracocentesis', 'ps/ik',
#        'barthel', 'gds-fast', 'otros/complicaciones', 'agonia', 'sedación',
#        'motivo alta', 'n.º visitas', 'n.º estancias', 'ayuntamiento',
#        'médico'],
#       dtype='object')
# Index(['fecha de alta', 'h.procedencia', 'servicio', 'ap', 'motivo ing',
#        'diagnóstico principal', 'agudo estable', 'crónico agud.',
#        'paliativo onc', 'palt no onc', 'antibiotico iv', 'dolor', 'disnea',
#        's febril', 'delirium', 'astenia/anorexia', 'fe iv', 'transf',
#        'paracen', 'toracocen', 'ps/ecog', 'gds/fast', 'barthel', 'sedación',
#        'motivo alta', 'n.º visitas', 'n.º estancias', 'ayuntamiento',
#        'médico'],
#       dtype='object')

# %%
data_2017 = df_17.rename(columns={'hospital': 'h_procedencia',
                               'servicio': 's_procedencia',
                               'ap': 'ap',
                               'otros': 'otros',
                               'diagnostico': 'diagnostico',
                               'motivo ing': 'motivo_ing',
                               'paliativo onc': 'paliativo_onc/noc', 
                               'paliativo no onc': 'paliativo_no_onc/noc',
                               'fiebre': 'fiebre',
                               'disnea': 'disnea',
                               'dolor': 'dolor',
                               'delirium': 'delirium',
                               'astenia': 'astenia',
                               'anorexia': 'anorexia',                               
                               'otros.1': 'otros_1',
                               'agonía': 'agonia',
                               'p terminal': 'p_terminal',
                               'ps/ik': 'ps/ecog',
                               'barthel': 'barthel',
                               'gds-fast': 'gds/fast', 
                               'eva ing': 'eva_ing',
                               'otros.2': 'otros_2',
                               'complicaciones': 'otros/complicaciones',
                               'nº estancias': "n_estancias",
                               'nº visitas': "n_visitas",
                               'sedación': 'sedacion',
                               'mot. alta': 'motivo_alta', 
                               'médico': 'medico'})

data_2018 = df_18.rename(columns={'hospital': 'h_procedencia',
                               'servicio': 's_procedencia',
                               'ap': 'ap',
                               'otros': 'otros',
                               'diagnostico': 'diagnostico',
                               'motivo ing': 'motivo_ing',
                               'paliativo onc': 'paliativo_onc/noc', 
                               'paliativo no onc': 'paliativo_no_onc/noc',
                               'fiebre': 'fiebre',
                               'disnea': 'disnea',
                               'dolor': 'dolor',
                               'delirium': 'delirium',
                               'astenia': 'astenia',
                               'anorexia': 'anorexia',                               
                               'otros.1': 'otros_1',
                               'agonía': 'agonia',
                               'p terminal': 'p_terminal',
                               'ps/ik': 'ps/ecog',
                               'barthel': 'barthel',
                               'gds-fast': 'gds/fast', 
                               'eva ing': 'eva_ing',
                               'otros.2': 'otros_2',
                               'complicaciones': 'otros/complicaciones',
                               'nº estancias': "n_estancias",
                               'nº visitas': "n_visitas",
                               'sedación': 'sedacion',
                               'mot. alta': 'motivo_alta', 
                               'médico': 'medico'})
                               
data_2019 = df_19.rename(columns={'hospital': 'h_procedencia',
                               'servicio': 's_procedencia',
                               'ap': 'ap',
                               'otros': 'otros',
                               'diagnostico': 'diagnostico',
                               'motivo ing': 'motivo_ing',
                               'pal onc': 'paliativo_onc/noc', 
                               'pal no onc': 'paliativo_no_onc/noc',
                               'fiebre': 'fiebre',
                               'disnea': 'disnea',
                               'dolor': 'dolor',
                               'delirium': 'delirium',
                               'astenia': 'astenia',
                               'anorexia': 'anorexia',                               
                               'otros_1': 'otros_1', # Problema se repite otros en una colunmna ver si lo traga así
                               'agonía': 'agonia',
                               'p. terminal': 'p_terminal',
                               'ps/ik': 'ps/ecog',
                               'barthel': 'barthel',
                               'gds-fast': 'gds/fast', 
                               'eva ing': 'eva_ing',
                               'otros_2': 'otros_2',
                               'complicaciones': 'otros/complicaciones',
                               'nº estancias': "n_estancias",
                               'nº visitas': "n_visitas",
                               'sedación': 'sedacion',
                               'mot. alta': 'motivo_alta', 
                               'médico': 'medico'})
                               
data_2020 = df_20.rename(columns={'h proced': 'h_procedencia', 
                               's proced': 's_procedencia',
                               'ap': 'ap',
                               'otros': 'otros',
                               'diag principal': 'diagnostico',
                               'motivo ing': 'motivo_ing',
                               'agudo estable': 'agudo_estable',    # Posible otros
                               'crónico reag': 'cronico_reag',      # Posible otros
                               'paliativo onc': 'paliativo_onc/noc', 
                               'pal no onc': 'paliativo_no_onc/noc',
                               'trato antibiótico': "trato_antibiotico",
                               'dolor': 'dolor',
                               'delirium': 'delirium',
                               'disnea': 'disnea',
                               'ast-anorx': 'ast/anorx',     # Agrupan astenia y anorexia (en 17,18 y 19 la separaban)
                               'fiebre': 'fiebre',
                               'transfusion': 'transfusion',        # Posible otros
                               'paracentesis': 'paracentesis',      # Posible otros
                               'toracentesis': 'toracentesis',
                               'ps/ik': 'ps/ecog',
                               'barthel': 'barthel',
                               'gds-fast': 'gds/fast',
                               'otros/complicaciones': 'otros/complicaciones',
                               'agonía': 'agonia',
                               'sedación': 'sedacion',
                               'motivo alta': 'motivo_alta',
                               'n.º estancias': "n_estancias",
                               'n.º visitas': "n_visitas",
                               'ayuntamiento': 'ayuntamiento',          # Se empieza a incluir en el 2020
                               'médico': 'medico'})

data_2021 = df_21.rename(columns={'h proced': 'h_procedencia', 
                               's proced': 's_procedencia',
                               'ap': 'ap',
                               'otros': 'otros',
                               'diag principal': 'diagnostico',
                               'motivo ing': 'motivo_ing',
                               'agudo estable': 'agudo_estable',    # Posible otros
                               'crónico reag': 'cronico_reag',      # Posible otros
                               'paliativo onc': 'paliativo_onc/noc', 
                               'pal no onc': 'paliativo_no_onc/noc',
                               'trato antibiótico': "trato_antibiotico",
                               'dolor': 'dolor',
                               'delirium': 'delirium',
                               'disnea': 'disnea',
                               'ast-anorx': 'ast/anorx',     # Agrupan astenia y anorexia (en 17,18 y 19 la separaban)
                               'fiebre': 'fiebre',
                               'transfusion': 'transfusion',        # Posible otros
                               'paracentesis': 'paracentesis',      # Posible otros
                               'toracentesis': 'toracentesis',
                               'ps/ik': 'ps/ecog',
                               'barthel': 'barthel',
                               'gds-fast': 'gds/fast',
                               'otros/complicaciones': 'otros/complicaciones',
                               'agonia': 'agonia',
                               'sedación': 'sedacion',
                               'motivo alta': 'motivo_alta',
                               'n.º estancias': "n_estancias",
                               'n.º visitas': "n_visitas",
                               'ayuntamiento': 'ayuntamiento',          # Se empieza a incluir en el 2020
                               'médico': 'medico'})
                               
data_2022 = df_22.rename(columns={'fecha de alta': 'fecha_alta', 
                               'h.procedencia': 'h_procedencia',
                               'servicio': 's_procedencia',
                               'ap': 'ap',
                               'motivo ing': 'motivo_ing',
                               'diagnóstico principal': 'diagnostico',
                               'agudo estable': 'agudo_estable',    # Posible otros
                               'crónico agud.': 'cronico_reag',      # Posible otros
                               'paliativo onc': 'paliativo_onc/noc', 
                               'palt no onc': 'paliativo_no_onc/noc',
                               'antibiotico iv': "trato_antibiotico",
                               'dolor': 'dolor',
                               'disnea': 'disnea',
                               's febril': 'fiebre',
                               'delirium': 'delirium',
                               'astenia/anorexia': 'ast/anorx', # Agrupan astenia y anorexia (en 17,18 y 19 la separaban)
                               'fe iv': '¿?',          # Se añade en 2022 (Puede ser fiebre)                                                      
                               'transf': 'transfusion',        # Posible otros
                               'paracen': 'paracentesis',      # Posible otros
                               'toracen': 'toracentesis',
                               'ps/ecog': 'ps/ecog',
                               'barthel': 'barthel',
                               'gds/fast': 'gds/fast',
                               'sedación': 'sedacion',
                               'motivo alta': 'motivo_alta',
                               'n.º estancias': "n_estancias",
                               'n.º visitas': "n_visitas",
                               'ayuntamiento': 'ayuntamiento',          # Se empieza a incluir en el 2020
                               'médico': 'medico'})

# %%
all_data_rename = [data_2017, data_2018, data_2019 ,data_2020, data_2021, data_2022]

# %%
# Para observar de nuevo los datos con las columnas renombradas

for i, data in enumerate(all_data_rename):
    i += 2017
    print("Datos del año",i)
    print(data.shape)
    print(data.info())
    print("="*80)
# Out:
# Datos del año 2017
# (587, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   h_procedencia         586 non-null    object
#  1   s_procedencia         587 non-null    object
#  2   ap                    586 non-null    object
#  3   otros                 587 non-null    object
#  4   diagnostico           587 non-null    object
#  5   motivo_ing            587 non-null    object
#  6   paliativo_onc/noc     586 non-null    object
#  7   paliativo_no_onc/noc  586 non-null    object
#  8   fiebre                587 non-null    object
#  9   disnea                586 non-null    object
#  10  dolor                 587 non-null    object
#  11  delirium              587 non-null    object
#  12  astenia               587 non-null    object
#  13  anorexia              587 non-null    object
#  14  otros_1               587 non-null    object
#  15  p_terminal            587 non-null    object
#  16  agonia                587 non-null    object
#  17  ps/ecog               587 non-null    object
#  18  barthel               587 non-null    object
#  19  gds/fast              587 non-null    object
#  20  eva_ing               587 non-null    object
#  21  otros_2               586 non-null    object
#  22  otros/complicaciones  587 non-null    object
#  23  n_estancias           587 non-null    float64
#  24  n_visitas             587 non-null    float64
#  25  sedacion              587 non-null    object
#  26  motivo_alta           587 non-null    object
#  27  medico                587 non-null    object
#  28  unnamed.1             5 non-null      float64
# dtypes: float64(3), object(26)
# memory usage: 133.1+ KB
# None
# ================================================================================
# Datos del año 2018
# (536, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   h_procedencia         536 non-null    object
#  1   s_procedencia         536 non-null    object
#  2   ap                    536 non-null    object
#  3   otros                 536 non-null    object
#  4   diagnostico           536 non-null    object
#  5   motivo_ing            536 non-null    object
#  6   paliativo_onc/noc     536 non-null    object
#  7   paliativo_no_onc/noc  535 non-null    object
#  8   fiebre                536 non-null    object
#  9   disnea                536 non-null    object
#  10  dolor                 536 non-null    object
#  11  delirium              536 non-null    object
#  12  astenia               536 non-null    object
#  13  anorexia              536 non-null    object
#  14  otros_1               535 non-null    object
#  15  p_terminal            534 non-null    object
#  16  agonia                534 non-null    object
#  17  ps/ecog               535 non-null    object
#  18  barthel               536 non-null    object
#  19  gds/fast              536 non-null    object
#  20  eva_ing               535 non-null    object
#  21  otros_2               535 non-null    object
#  22  otros/complicaciones  536 non-null    object
#  23  n_estancias           536 non-null    float64
#  24  n_visitas             536 non-null    object
#  25  sedacion              535 non-null    object
#  26  motivo_alta           535 non-null    object
#  27  medico                535 non-null    object
# dtypes: float64(1), object(27)
# memory usage: 117.4+ KB
# None
# ================================================================================
# Datos del año 2019
# (427, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   h_procedencia         427 non-null    object
#  1   s_procedencia         427 non-null    object
#  2   ap                    427 non-null    object
#  3   otros                 427 non-null    object
#  4   diagnostico           427 non-null    object
#  5   motivo_ing            421 non-null    object
#  6   paliativo_onc/noc     427 non-null    object
#  7   paliativo_no_onc/noc  427 non-null    object
#  8   fiebre                426 non-null    object
#  9   disnea                427 non-null    object
#  10  dolor                 427 non-null    object
#  11  delirium              427 non-null    object
#  12  astenia               427 non-null    object
#  13  anorexia              427 non-null    object
#  14  otros_1               427 non-null    object
#  15  p_terminal            426 non-null    object
#  16  agonia                427 non-null    object
#  17  ps/ecog               427 non-null    object
#  18  barthel               427 non-null    object
#  19  gds/fast              427 non-null    object
#  20  eva_ing               426 non-null    object
#  21  otros_2               427 non-null    object
#  22  otros/complicaciones  426 non-null    object
#  23  n_estancias           427 non-null    float64
#  24  n_visitas             427 non-null    object
#  25  sedacion              427 non-null    object
#  26  motivo_alta           427 non-null    object
#  27  medico                427 non-null    object
# dtypes: float64(1), object(27)
# memory usage: 93.5+ KB
# None
# ================================================================================
# Datos del año 2020
# (643, 30)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   h_procedencia         643 non-null    object
#  1   s_procedencia         643 non-null    object
#  2   ap                    643 non-null    object
#  3   otros                 643 non-null    object
#  4   diagnostico           643 non-null    object
#  5   motivo_ing            641 non-null    object
#  6   agudo_estable         643 non-null    object
#  7   cronico_reag          643 non-null    object
#  8   paliativo_onc/noc     643 non-null    object
#  9   paliativo_no_onc/noc  643 non-null    object
#  10  trato_antibiotico     643 non-null    object
#  11  dolor                 643 non-null    object
#  12  delirium              642 non-null    object
#  13  disnea                643 non-null    object
#  14  ast/anorx             643 non-null    object
#  15  fiebre                643 non-null    object
#  16  transfusion           643 non-null    object
#  17  paracentesis          643 non-null    object
#  18  toracocentesis        642 non-null    object
#  19  ps/ecog               643 non-null    object
#  20  barthel               642 non-null    object
#  21  gds/fast              643 non-null    object
#  22  otros/complicaciones  642 non-null    object
#  23  agonia                643 non-null    object
#  24  sedacion              643 non-null    object
#  25  motivo_alta           643 non-null    object
#  26  n_visitas             642 non-null    object
#  27  n_estancias           643 non-null    float64
#  28  ayuntamiento          643 non-null    object
#  29  medico                643 non-null    object
# dtypes: float64(1), object(29)
# memory usage: 150.8+ KB
# None
# ================================================================================
# Datos del año 2021
# (765, 30)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 765 entries, 0 to 764
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   h_procedencia         765 non-null    object
#  1   s_procedencia         765 non-null    object
#  2   ap                    765 non-null    object
#  3   otros                 765 non-null    object
#  4   diagnostico           765 non-null    object
#  5   motivo_ing            762 non-null    object
#  6   agudo_estable         765 non-null    object
#  7   cronico_reag          765 non-null    object
#  8   paliativo_onc/noc     765 non-null    object
#  9   paliativo_no_onc/noc  765 non-null    object
#  10  trato_antibiotico     765 non-null    object
#  11  dolor                 765 non-null    object
#  12  delirium              765 non-null    object
#  13  disnea                765 non-null    object
#  14  ast/anorx             765 non-null    object
#  15  fiebre                765 non-null    object
#  16  transfusion           765 non-null    object
#  17  paracentesis          765 non-null    object
#  18  toracocentesis        765 non-null    object
#  19  ps/ecog               765 non-null    object
#  20  barthel               765 non-null    object
#  21  gds/fast              765 non-null    object
#  22  otros/complicaciones  765 non-null    object
#  23  agonia                764 non-null    object
#  24  sedacion              765 non-null    object
#  25  motivo_alta           765 non-null    object
#  26  n_visitas             765 non-null    float64
#  27  n_estancias           765 non-null    object
#  28  ayuntamiento          764 non-null    object
#  29  medico                765 non-null    object
# dtypes: float64(1), object(29)
# memory usage: 179.4+ KB
# None
# ================================================================================
# Datos del año 2022
# (1056, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fecha_alta            767 non-null    object
#  1   h_procedencia         1056 non-null   object
#  2   s_procedencia         1056 non-null   object
#  3   ap                    1056 non-null   object
#  4   motivo_ing            1056 non-null   object
#  5   diagnostico           1053 non-null   object
#  6   agudo_estable         1055 non-null   object
#  7   cronico_reag          1056 non-null   object
#  8   paliativo_onc/noc     1056 non-null   object
#  9   paliativo_no_onc/noc  1056 non-null   object
#  10  trato_antibiotico     1056 non-null   object
#  11  dolor                 1056 non-null   object
#  12  disnea                1056 non-null   object
#  13  fiebre                1055 non-null   object
#  14  delirium              1056 non-null   object
#  15  ast/anorx             1056 non-null   object
#  16  ¿?                    1055 non-null   object
#  17  transfusion           1056 non-null   object
#  18  paracentesis          1056 non-null   object
#  19  toracocen             1056 non-null   object
#  20  ps/ecog               1056 non-null   object
#  21  gds/fast              1056 non-null   object
#  22  barthel               1056 non-null   object
#  23  sedacion              1052 non-null   object
#  24  motivo_alta           1056 non-null   object
#  25  n_visitas             1055 non-null   float64
#  26  n_estancias           1055 non-null   float64
#  27  ayuntamiento          1056 non-null   object
#  28  medico                1056 non-null   object
# dtypes: float64(2), object(27)
# memory usage: 239.4+ KB
# None
# ================================================================================

# %% [markdown]
# # Funciones para diferenciar columnas, ver columnas iguales y todas

# %%
# Pruebas para ver las diferentes columnas entre los dataframes

def diff_cols(df1,df2,df3,df4,df5,df6):
    df_1_cols = set(df1.columns)
    df_2_cols = set(df2.columns)
    df_3_cols = set(df3.columns)
    df_4_cols = set(df4.columns)
    df_5_cols = set(df5.columns)
    df_6_cols = set(df6.columns)
    all_cols = df_1_cols.union(df_2_cols).union(df_3_cols).union(df_4_cols).union(df_5_cols).union(df_6_cols)
    common_cols = df_1_cols.intersection(df_2_cols).intersection(df_3_cols).intersection(df_4_cols).intersection(df_5_cols).intersection(df_6_cols)
    different_cols = all_cols - common_cols
    return different_cols

diff_cols(data_2017,data_2018,data_2019,data_2020,data_2021,data_2022)
# Out:
# {'agonia',
#  'agudo_estable',
#  'anorexia',
#  'ast/anorx',
#  'astenia',
#  'ayuntamiento',
#  'cronico_reag',
#  'eva_ing',
#  'fecha_alta',
#  'otros',
#  'otros/complicaciones',
#  'otros_1',
#  'otros_2',
#  'p_terminal',
#  'paracentesis',
#  'toracocen',
#  'toracocentesis',
#  'transfusion',
#  'trato_antibiotico',
#  'unnamed.1',
#  '¿?'}

# %%
def diff_cols_v2(dataframes):
    all_cols = set()
    common_cols = set(dataframes[0].columns)
    
    for df in dataframes:
        all_cols |= set(df.columns)
        common_cols &= set(df.columns)
    
    different_cols = all_cols - common_cols
    return different_cols

# %%
# Prueba para ver las columnas comunes
def common_cols_v2(dataframes):
    all_cols = set()
    common_cols = set(dataframes[0].columns)
    
    for df in dataframes:
        all_cols |= set(df.columns)
        common_cols &= set(df.columns)
  
    return common_cols

# %%
def all_cols_v2(dataframes):
    all_cols = set()
        
    for df in dataframes:
        all_cols |= set(df.columns)
          
    return all_cols

# %%
all_cols_data = all_cols_v2(all_data_rename)
print(len(all_cols_data),all_cols_data)
# Out:
# 40 {'ps/ecog', 'diagnostico', 'otros/complicaciones', 'toracocen', 'gds/fast', 'otros_2', 'toracocentesis', 'dolor', 'delirium', 'fecha_alta', 'n_visitas', 'motivo_alta', 'paracentesis', 'motivo_ing', 'agonia', 'astenia', 'sedacion', 'ayuntamiento', 'ap', 'disnea', 'fiebre', 'p_terminal', 's_procedencia', 'unnamed.1', 'ast/anorx', 'agudo_estable', 'otros_1', 'paliativo_no_onc/noc', 'barthel', 'anorexia', '¿?', 'h_procedencia', 'n_estancias', 'medico', 'trato_antibiotico', 'cronico_reag', 'eva_ing', 'transfusion', 'paliativo_onc/noc', 'otros'}

# %%
diff_cols_data = diff_cols_v2(all_data_rename)
print(len(diff_cols_data), diff_cols_data)
# Out:
# 21 {'otros/complicaciones', 'toracocen', 'otros_2', 'toracocentesis', 'fecha_alta', 'paracentesis', 'agonia', 'astenia', 'ayuntamiento', 'p_terminal', 'unnamed.1', 'ast/anorx', 'agudo_estable', 'otros_1', 'anorexia', '¿?', 'trato_antibiotico', 'cronico_reag', 'eva_ing', 'transfusion', 'otros'}

# %%
equal_cols_data = common_cols_v2(all_data_rename)
print(len(equal_cols_data), equal_cols_data)
# Out:
# 19 {'ps/ecog', 'diagnostico', 'gds/fast', 'dolor', 'delirium', 'n_visitas', 'motivo_alta', 'motivo_ing', 'sedacion', 'ap', 'disnea', 'fiebre', 's_procedencia', 'paliativo_no_onc/noc', 'barthel', 'h_procedencia', 'n_estancias', 'medico', 'paliativo_onc/noc'}

# %% [markdown]
# ### Antes de hacer el concat o el merge vamos a crear una columna nueva de año para cada dataframe y así identificar a que año pertenecen esos datos

# %%
# Añadimos columna year para identificar el año de los datos

data_2017["year"] = 2017
data_2018["year"] = 2018
data_2019["year"] = 2019
data_2020["year"] = 2020
data_2021["year"] = 2021
data_2022["year"] = 2022

# %% [markdown]
# ## Seleccionar y borrar columnas no deseadas
#
# * Eliminamos la columna `unnamed.1` No conocemos que representan los 5 valores unnamed de los datos de 2017.
# * La columna de `trato_anibiotico` solo está a partir del 2020 se mantiene pero solo para esos años
# * La columna de astenia y anorexia viene a partir del 2020 agrupada
#   * Agrupar los datos de astenia y anorexia del 17 al 19 antes del `concat` y renombrar la columna por `ast/anorx`
# * La columna fe_iv no sé a que pertenece pero solo está en 2022 con el nombre cambiado a `¿?`
# * ¿Qué hacer con las columnas `otros_1` y `otros_2`?

# %%
# Quitamos columnas innecesarias 

data_2017.drop(columns="unnamed.1", inplace=True)  # Unnamed no tiene valores importantes sólo 5 valores numéricos que no sé que son

# %%
# Función para eliminar la columna de trato_antibiotico de los datos de 2020 en adelante
def del_trato_antibiotico(dataframes):
    for df in dataframes:
        df = df.drop(['trato_antibiotico'], axis=1, inplace=True)

# %%
# Función para agrupar las columnas de astenia y anorexia porque se agrupan en los datos de 2020 en adelante

def col_astenia_anorexia(dataframes):
    for df in dataframes:
        df['ast/anorx'] = np.where(df['astenia']=='si', 'si', df['anorexia'])
        df = df.drop(['astenia', 'anorexia'],axis=1, inplace=True)

# %%
# Agrupamos astenia y anorexia

astenia_anorexia = [data_2017, data_2018, data_2019]      # Lista con los df que tienen astenia y anorexia separados

col_astenia_anorexia(astenia_anorexia)

# %%
datos_trato_antibiotico = [data_2020, data_2021, data_2022]

del_trato_antibiotico(datos_trato_antibiotico)

# %%
total = 0
for i, df in enumerate(all_data_rename):
    i += 2017
    # df_split_lower(df)               # Ya están pasadas a lower y quitados los espacios anteriormente
    total += len(df)
    print("df", i)
    # print(df.dtypes,len(df), df.columns) 
    print(len(df.columns), df.columns)
    print(total, " Datos acumulados")
    print("="*80)
# Out:
# df 2017
# 28 Index(['h_procedencia', 's_procedencia', 'ap', 'otros', 'diagnostico',
#        'motivo_ing', 'paliativo_onc/noc', 'paliativo_no_onc/noc', 'fiebre',
#        'disnea', 'dolor', 'delirium', 'otros_1', 'p_terminal', 'agonia',
#        'ps/ecog', 'barthel', 'gds/fast', 'eva_ing', 'otros_2',
#        'otros/complicaciones', 'n_estancias', 'n_visitas', 'sedacion',
#        'motivo_alta', 'medico', 'year', 'ast/anorx'],
#       dtype='object')
# 587  Datos acumulados
# ================================================================================
# df 2018
# 28 Index(['h_procedencia', 's_procedencia', 'ap', 'otros', 'diagnostico',
#        'motivo_ing', 'paliativo_onc/noc', 'paliativo_no_onc/noc', 'fiebre',
#        'disnea', 'dolor', 'delirium', 'otros_1', 'p_terminal', 'agonia',
#        'ps/ecog', 'barthel', 'gds/fast', 'eva_ing', 'otros_2',
#        'otros/complicaciones', 'n_estancias', 'n_visitas', 'sedacion',
#        'motivo_alta', 'medico', 'year', 'ast/anorx'],
#       dtype='object')
# 1123  Datos acumulados
# ================================================================================
# df 2019
# 28 Index(['h_procedencia', 's_procedencia', 'ap', 'otros', 'diagnostico',
#        'motivo_ing', 'paliativo_onc/noc', 'paliativo_no_onc/noc', 'fiebre',
#        'disnea', 'dolor', 'delirium', 'otros_1', 'p_terminal', 'agonia',
#        'ps/ecog', 'barthel', 'gds/fast', 'eva_ing', 'otros_2',
#        'otros/complicaciones', 'n_estancias', 'n_visitas', 'sedacion',
#        'motivo_alta', 'medico', 'year', 'ast/anorx'],
#       dtype='object')
# 1550  Datos acumulados
# ================================================================================
# df 2020
# 30 Index(['h_procedencia', 's_procedencia', 'ap', 'otros', 'diagnostico',
#        'motivo_ing', 'agudo_estable', 'cronico_reag', 'paliativo_onc/noc',
#        'paliativo_no_onc/noc', 'dolor', 'delirium', 'disnea', 'ast/anorx',
#        'fiebre', 'transfusion', 'paracentesis', 'toracocentesis', 'ps/ecog',
#        'barthel', 'gds/fast', 'otros/complicaciones', 'agonia', 'sedacion',
#        'motivo_alta', 'n_visitas', 'n_estancias', 'ayuntamiento', 'medico',
#        'year'],
#       dtype='object')
# 2193  Datos acumulados
# ================================================================================
# df 2021
# 30 Index(['h_procedencia', 's_procedencia', 'ap', 'otros', 'diagnostico',
#        'motivo_ing', 'agudo_estable', 'cronico_reag', 'paliativo_onc/noc',
#        'paliativo_no_onc/noc', 'dolor', 'delirium', 'disnea', 'ast/anorx',
#        'fiebre', 'transfusion', 'paracentesis', 'toracocentesis', 'ps/ecog',
#        'barthel', 'gds/fast', 'otros/complicaciones', 'agonia', 'sedacion',
#        'motivo_alta', 'n_visitas', 'n_estancias', 'ayuntamiento', 'medico',
#        'year'],
#       dtype='object')
# 2958  Datos acumulados
# ================================================================================
# df 2022
# 29 Index(['fecha_alta', 'h_procedencia', 's_procedencia', 'ap', 'motivo_ing',
#        'diagnostico', 'agudo_estable', 'cronico_reag', 'paliativo_onc/noc',
#        'paliativo_no_onc/noc', 'dolor', 'disnea', 'fiebre', 'delirium',
#        'ast/anorx', '¿?', 'transfusion', 'paracentesis', 'toracocen',
#        'ps/ecog', 'gds/fast', 'barthel', 'sedacion', 'motivo_alta',
#        'n_visitas', 'n_estancias', 'ayuntamiento', 'medico', 'year'],
#       dtype='object')
# 4014  Datos acumulados
# ================================================================================

# %%
# Esto es para verificar si tienen index duplicados

print(data_2017.index.duplicated().sum())
print(data_2018.index.duplicated().sum())
print(data_2019.index.duplicated().sum())
print(data_2020.index.duplicated().sum())
print(data_2021.index.duplicated().sum())
print(data_2022.index.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# ````python
# data_2017_copy['ast/anorx'] = data_2017_copy['astenia'].fillna(data_2017_copy['anorexia'])
# ````
#
# Aquí me devolvió el problema de que cuando astenia era "no" y anorexia "si" devolvía "NO"
# solucionado con numpy y el método `where`

# %%
# data_2017_copy[['ast/anorx', 'anorexia','astenia']]

# %%
# Creo una columna check para ver si existen valores diferentes

# data_2017_copy['check'] = data_2017_copy[['astenia', 'anorexia', 'ast/anorx']].apply(lambda x: all(x == x[0]), axis=1)

# %%
# data_2017_copy[['astenia','anorexia','ast/anorx','check']][data_2017_copy['check']==0]

# %%
# data_2017_copy['check'].value_counts()

# %%
# data_2017_copy = data_2017_copy.drop(['astenia', 'anorexia', 'check'], axis=1)

# %% [markdown]
# ## Concat y Merge
#
# * Utilizaré `concat` para unir los dataframes con las columnas iguales.
# * Para el caso de que existen columnas que no están en otros dataframes utilizaré `merge`

# %%
# Esto es un a saco PACO
# Hago el concat de la lista de dataframes con las columnas renombradas

df_concatenado = pd.concat(all_data_rename, ignore_index=True, axis=0)

# %%
df_concatenado.shape
# Out:
# (4014, 37)

# %%
df_concatenado.isna().sum()
# Out:
# h_procedencia              1
# s_procedencia              0
# ap                         1
# otros                   1056
# diagnostico                3
# motivo_ing                11
# paliativo_onc/noc          1
# paliativo_no_onc/noc       2
# fiebre                     2
# disnea                     1
# dolor                      0
# delirium                   1
# otros_1                 2465
# p_terminal              2467
# agonia                  1059
# ps/ecog                    1
# barthel                    1
# gds/fast                   0
# eva_ing                 2466
# otros_2                 2466
# otros/complicaciones    1058
# n_estancias                1
# n_visitas                  2
# sedacion                   5
# motivo_alta                1
# medico                     1
# year                       0
# ast/anorx                  0
# agudo_estable           1551
# cronico_reag            1550
# transfusion             1550
# paracentesis            1550
# toracocentesis          2607
# ayuntamiento            1551
# fecha_alta              3247
# ¿?                      2959
# toracocen               2958
# dtype: int64

# %%
df_concatenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   h_procedencia         4013 non-null   object
#  1   s_procedencia         4014 non-null   object
#  2   ap                    4013 non-null   object
#  3   otros                 2958 non-null   object
#  4   diagnostico           4011 non-null   object
#  5   motivo_ing            4003 non-null   object
#  6   paliativo_onc/noc     4013 non-null   object
#  7   paliativo_no_onc/noc  4012 non-null   object
#  8   fiebre                4012 non-null   object
#  9   disnea                4013 non-null   object
#  10  dolor                 4014 non-null   object
#  11  delirium              4013 non-null   object
#  12  otros_1               1549 non-null   object
#  13  p_terminal            1547 non-null   object
#  14  agonia                2955 non-null   object
#  15  ps/ecog               4013 non-null   object
#  16  barthel               4013 non-null   object
#  17  gds/fast              4014 non-null   object
#  18  eva_ing               1548 non-null   object
#  19  otros_2               1548 non-null   object
#  20  otros/complicaciones  2956 non-null   object
#  21  n_estancias           4013 non-null   object
#  22  n_visitas             4012 non-null   object
#  23  sedacion              4009 non-null   object
#  24  motivo_alta           4013 non-null   object
#  25  medico                4013 non-null   object
#  26  year                  4014 non-null   int64
#  27  ast/anorx             4014 non-null   object
#  28  agudo_estable         2463 non-null   object
#  29  cronico_reag          2464 non-null   object
#  30  transfusion           2464 non-null   object
#  31  paracentesis          2464 non-null   object
#  32  toracocentesis        1407 non-null   object
#  33  ayuntamiento          2463 non-null   object
#  34  fecha_alta            767 non-null    object
#  35  ¿?                    1055 non-null   object
#  36  toracocen             1056 non-null   object
# dtypes: int64(1), object(36)
# memory usage: 1.1+ MB

# %%
df_concatenado.head()
# Out:
#   h_procedencia s_procedencia  ap otros                  diagnostico  \
# 0   gil casares          upal  no    no                       ca orl
# 1       clinico           ONC  no    no              Melanoma vulvar
# 2       clinico           MIR  no    no              ca broncogenico
# 3       clinico           DIG  no    no            cirrosis hepatica
# 4       clinico           URG  no    no  neplasia de mama estadio IV
#
#                    motivo_ing paliativo_onc/noc paliativo_no_onc/noc fiebre  \
# 0           contro d sintomas                si                   si     no
# 1           mal control dolor                si                   no     no
# 2           control evolutivo                si                   si     no
# 3  admininistacion octreotido                no                   no     no
# 4         control de sintomas                si                   no     no
#
#   disnea dolor delirium otros_1 p_terminal agonia ps/ecog barthel gds/fast  \
# 0     no    si       no      no         si     no     4.0    30.0       no
# 1     no    si       no      no         si     no     3-4      no       no
# 2     si    no       no      no         no     no     3-4    40.0       no
# 3     no    no       no      no         no     no     1.0    90.0       no
# 4     si    si       no      no         si     no     4.0    30.0       no
#
#   eva_ing otros_2      otros/complicaciones n_estancias n_visitas sedacion  \
# 0      no      no    reingreso en urgencias        21.0      10.0       no
# 1      no      no  met. pulmonares y digest        24.0       8.0       no
# 2      no      no                        no        14.0       6.0       no
# 3      no      no                        no         1.0       1.0       no
# 4     7.0      no                        no         2.0       1.0       no
#
#        motivo_alta         medico  year ast/anorx agudo_estable cronico_reag  \
# 0       reingreso          valdes  2017        si           NaN          NaN
# 1           exitus    galego feal  2017        si           NaN          NaN
# 2  fin de cuidados  lopez renedo.  2017        no           NaN          NaN
# 3  fin de cuidados  lopez renedo.  2017        no           NaN          NaN
# 4           exitus  lopez renedo.  2017        no           NaN          NaN
#
#   transfusion paracentesis toracocentesis ayuntamiento fecha_alta   ¿?  \
# 0         NaN          NaN            NaN          NaN        NaN  NaN
# 1         NaN          NaN            NaN          NaN        NaN  NaN
# 2         NaN          NaN            NaN          NaN        NaN  NaN
# 3         NaN          NaN            NaN          NaN        NaN  NaN
# 4         NaN          NaN            NaN          NaN        NaN  NaN
#
#   toracocen
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df_concatenado["n_estancias"] = pd.to_numeric(df_concatenado["n_estancias"], errors='coerce')
df_concatenado["n_visitas"] = pd.to_numeric(df_concatenado["n_visitas"], errors='coerce')

# %%
df_concatenado["n_estancias"].dtype
# Out:
# dtype('float64')

# %%
df_concatenado["n_estancias"].dropna(inplace=True)

# %%
# df_concatenado["n_estancias"] = df_concatenado["n_estancias"].astype(int)

# %%
df_concatenado.shape
# Out:
# (4014, 37)

# %%
plt.hist(df_concatenado["n_estancias"], bins=20)
plt.show()

# %%
plt.hist(df_concatenado["n_visitas"], bins=20)
plt.show()

# %%
'''
merged_df = pd.merge(data_2022, pd.merge(data_2021, data_2020, on=['fiebre', 'n_visitas', 'ap', 'dolor', 'disnea', 's_procedencia', 'sedacion', 'medico',
                                                                   'ps/ecog', 'paliativo_no_onc/noc', 'n_estancias', 'motivo_alta', 'motivo_ing', 'h_procedencia',
                                                                   'diagnostico', 'delirium', 'barthel', 'paliativo_onc/noc', 'gds/fast',"year"]), 
                                                               on=['fiebre', 'n_visitas', 'ap', 'dolor', 'disnea', 's_procedencia', 'sedacion', 'medico',
                                                                   'ps/ecog', 'paliativo_no_onc/noc', 'n_estancias', 'motivo_alta', 'motivo_ing', 'h_procedencia',
                                                                   'diagnostico', 'delirium', 'barthel', 'paliativo_onc/noc', 'gds/fast',"year"])

merged_df = pd.merge(merged_df, data_2019, on=['fiebre', 'n_visitas', 'ap', 'dolor', 'disnea', 's_procedencia', 'sedacion', 'medico',
                                                                   'ps/ecog', 'paliativo_no_onc/noc', 'n_estancias', 'motivo_alta', 'motivo_ing', 'h_procedencia',
                                                                   'diagnostico', 'delirium', 'barthel', 'paliativo_onc/noc', 'gds/fast',"year"])

merged_df = pd.merge(merged_df, data_2018, on=['fiebre', 'n_visitas', 'ap', 'dolor', 'disnea', 's_procedencia', 'sedacion', 'medico',
                                                                   'ps/ecog', 'paliativo_no_onc/noc', 'n_estancias', 'motivo_alta', 'motivo_ing', 'h_procedencia',
                                                                   'diagnostico', 'delirium', 'barthel', 'paliativo_onc/noc', 'gds/fast',"year"])
merged_df = pd.merge(merged_df, data_2017, on=['fiebre', 'n_visitas', 'ap', 'dolor', 'disnea', 's_procedencia', 'sedacion', 'medico',
                                                                   'ps/ecog', 'paliativo_no_onc/noc', 'n_estancias', 'motivo_alta', 'motivo_ing', 'h_procedencia',
                                                                   'diagnostico', 'delirium', 'barthel', 'paliativo_onc/noc', 'gds/fast',"year"])
    
# Imprimimos el dataframe resultante
print(merged_df)
'''
# Out:
# '\nmerged_df = pd.merge(data_2022, pd.merge(data_2021, data_2020, on=[\'fiebre\', \'n_visitas\', \'ap\', \'dolor\', \'disnea\', \'s_procedencia\', \'sedacion\', \'medico\',\n                                                                   \'ps/ecog\', \'paliativo_no_onc/noc\', \'n_estancias\', \'motivo_alta\', \'motivo_ing\', \'h_procedencia\',\n                                                                   \'diagnostico\', \'delirium\', \'barthel\', \'paliativo_onc/noc\', \'gds/fast\',"year"]), \n                                                               on=[\'fiebre\', \'n_visitas\', \'ap\', \'dolor\', \'disnea\', \'s_procedencia\', \'sedacion\', \'medico\',\n                                                                   \'ps/ecog\', \'paliativo_no_onc/noc\', \'n_estancias\', \'motivo_alta\', \'motivo_ing\', \'h_procedencia\',\n                                                                   \'diagnostico\', \'delirium\', \'barthel\', \'paliativo_onc/noc\', \'gds/fast\',"year"])\n\nmerged_df = pd.merge(merged_df, data_2019, on=[\'fiebre\', \'n_visitas\', \'ap\', \'dolor\', \'disnea\', \'s_procedencia\', \'sedacion\', \'medico\',\n                                                                   \'ps/ecog\', \'paliativo_no_onc/noc\', \'n_estancias\', \'motivo_alta\', \'motivo_ing\', \'h_procedencia\',\n                                                                   \'diagnostico\', \'delirium\', \'barthel\', \'paliativo_onc/noc\', \'gds/fast\',"year"])\n\nmerged_df = pd.merge(merged_df, data_2018, on=[\'fiebre\', \'n_visitas\', \'ap\', \'dolor\', \'disnea\', \'s_procedencia\', \'sedacion\', \'medico\',\n                                                                   \'ps/ecog\', \'paliativo_no_onc/noc\', \'n_estancias\', \'motivo_alta\', \'motivo_ing\', \'h_procedencia\',\n                                                                   \'diagnostico\', \'delirium\', \'barthel\', \'paliativo_onc/noc\', \'gds/fast\',"year"])\nmerged_df = pd.merge(merged_df, data_2017, on=[\'fiebre\', \'n_visitas\', \'ap\', \'dolor\', \'disnea\', \'s_procedencia\', \'sedacion\', \'medico\',\n                                                                   \'ps/ecog\', \'paliativo_no_onc/noc\', \'n_estancias\', \'motivo_alta\', \'motivo_ing\', \'h_procedencia\',\n                                                                   \'diagnostico\', \'delirium\', \'barthel\', \'paliativo_onc/noc\', \'gds/fast\',"year"])\n    \n# Imprimimos el dataframe resultante\nprint(merged_df)\n'

# %% [markdown]
# # Problema
#
# Posibles columnas distintas en el 'on'
# Solución: Poner solo las columnas que sean iguales en todos los dataframes
#
# Posible problema:
# EL tipo de datos
# Normalizar los datos de todas las columnas para que sean iguales
#
# No podemos juntar peras con naranjas
# (Pero si en python...)
# ````python
# print("peras" + " naranjas"+ "😁")
# ````

# %% [markdown]
# # To dos:
#     1. Municipios, datos faltantes
#     2. Normalizar y pasar el tipo de datos
#     3. Preguntar columnas con interrogantes
#     4. Group de astenia y anorexia para las otras fechas que van por separado
#     5. Columna otros duplicada en 2019. Solucionar

# %% [markdown]
# # Datos
#
# * Observamos los valores únicos
#
# * Para eliminar los espacios en los datos utilizaremos expresiones regulares

# %%
def unicos(df):
    columns = df.columns.tolist()
    for i, column in enumerate(columns):
        v_column = df[column].unique()
        print(df.columns.values[i])
        print(len(v_column), v_column)
        print("="*66)

# %%
df_strip = df.replace(r"^ +| +$",r"", regex = True) # Quitamos los espacios del principio y final de los datos
check = df_strip.replace(" ", "@", regex = True)    # Cambiamos los espacios del medio por un @ como check
check
# Out:
#       fecha_alta h_procedencia     s_procedencia          ap  \
# 0     2022-08-11       clínico               ACV          NO
# 1     2022-06-03       clínico               CAR          no
# 2     2022-06-07       clínico               CAR          no
# 3     2022-09-13       clínico               DIG          no
# 4     2022-08-13       clínico               MIR          no
# 5     2022-07-04         conxo               MIR          no
# 6     2022-09-02         conxo               MIR          no
# 7     2022-10-26         conxo               MIR          no
# 8     2022-10-25         conxo               MIR          no
# 9     2022-10-24         conxo               MIR          no
# 10    2022-10-24         conxo               MIR          no
# 11    2022-11-03         conxo               MIR          no
# 12    2022-11-04         conxo               MIR          no
# 13    2022-09-26   gil@casares               MIR          no
# 14    2022-07-07   gil@casares               MIR          no
# 15    2022-05-19            no               NCR          si
# 16    2022-08-02       clínico               NML          no
# 17    2022-08-12       clínico               NML          no
# 18    2022-08-24       clínico               NML          no
# 19    2022-07-11            no                no          si
# 20    2022-07-25            no                no          si
# 21    2022-07-30            no                no          SI
# 22    2022-08-01            no                no          si
# 23    2022-09-08            no                no          si
# 24    2022-09-19            no                no          si
# 25    2022-09-21            no                no          si
# 26    2022-09-27            no                no          si
# 27    2022-09-30            no                no          si
# 28    2022-10-31            no                no          si
# 29    2022-06-10       clínico               ONC          no
# 30    2022-06-16       clínico               ONC          no
# 31    2022-07-15       clínico               ONC          no
# 32    2022-10-03       clínico               ONC          no
# 33    2022-11-07       clínico               ONC          no
# 34    2022-11-08       clínico               ONC          no
# 35    2022-06-23         conxo              UPAL          no
# 36    2022-06-16       clínico               URG          no
# 37    2022-07-04       clínico               URG          no
# 38    2022-07-04       clínico               URG          no
# 39    2022-07-04       clínico               URG          no
# 40    2022-07-28       clínico               URG          no
# 41    2022-08-08       clínico               URG          no
# 42    2022-09-22       clínico               URG          no
# 43    2022-10-19       clínico               URG          no
# 44    2022-11-03       clínico               URG          no
# 45    2022-05-30       clínico               URG          no
# 46    2022-06-07       clínico               URG          no
# 47    2022-02-20       clínico               ACV          no
# 48          None       clínico               ACV          no
# 49          None       clínico               ACV          no
# 50          None       clínico               CAR          no
# 51    2022-07-18       clínico               CGD          no
# 52          None       clínico               CGD          no
# 53    2022-05-11       clínico               TRA          no
# 54    2022-07-10       clínico               DIG          no
# 55    2022-07-11       clínico               DIG          no
# 56    2022-08-30       clínico               DIG          no
# 57    2022-07-19         conxo               END          no
# 58    2022-05-12            no              HADO          no
# 59    2022-06-28       clínico               HEM          no
# 60    2022-07-05       clínico               HEM          no
# 61    2022-07-26       clínico               HEM          no
# 62    2022-06-21       clínico               MIR          no
# 63    2022-06-23       clínico               MIR          no
# 64    2022-06-23       clínico               MIR          no
# 65    2022-06-27       clínico               MIR          no
# 66    2022-07-11       clínico               MIR          no
# 67    2022-08-12       clínico               MIR          no
# 68    2022-08-24       clínico               MIR          no
# 69          None       clínico               MIR          no
# 70    2022-06-22         conxo               MIR          no
# 71    2022-07-11       clínico               NML          no
# 72    2022-08-30       clínico               NML          no
# 73          None       clínico               NML          no
# 74    2022-01-11            no                no          si
# 75    2022-03-03            no                no          si
# 76    2022-03-06            no                no          si
# 77    2022-03-30            no                no          si
# 78    2022-05-06            no                no          si
# 79    2022-06-03            no                no          si
# 80    2022-06-06            no                no          si
# 81    2022-06-07            no                no          si
# 82    2022-06-07            no                no          si
# 83    2022-06-17            no                no          si
# 84    2022-06-22            no                no          si
# 85    2022-06-26            no                no          si
# 86    2022-07-01            no                no          si
# 87    2022-07-09            no                no          si
# 88    2022-07-19            no                no          si
# 89    2022-07-21            no                no          si
# 90    2022-07-22            no                no          si
# 91    2022-08-10            no                no          si
# 92    2022-08-11            no                no          si
# 93    2022-08-11            no                no          si
# 94    2022-08-12            no                no          si
# 95    2022-08-12            no                no          si
# 96    2022-08-16            no                no          si
# 97    2022-08-17            no                no          si
# 98    2022-08-18            no                no          si
# 99    2022-08-20            no                no          si
# 100   2022-08-24            no                no          si
# 101   2022-08-31            no                no          si
# 102   2022-09-01            no                no          si
# 103         None            no                no          si
# 104         None            no                no          si
# 105         None            no                no          si
# 106         None            no                no          si
# 107         None            no                no          si
# 108         None            no                no          si
# 109         None            no                no          si
# 110         None            no                no          si
# 111         None            no                no          si
# 112         None            no                no          si
# 113         None            no                no          si
# 114         None            no                no          si
# 115         None            no                no          si
# 116         None            no                no          si
# 117         None            no                no          si
# 118   2022-05-09       clínico               ONC          no
# 119   2022-06-05       clínico               ONC          no
# 120   2022-07-14       clínico               ONC          no
# 121   2022-07-18       clínico               ONC          no
# 122   2022-08-03       clínico               ONC          no
# 123         None       clínico               ONC          no
# 124         None       clínico               ONC          no
# 125         None       clínico               ONC          no
# 126   2022-06-03       clínico               ONC          no
# 127         None       clínico               REU          no
# 128   2022-02-25       clínico               TRA          no
# 129   2022-07-01       clínico               NML          no
# 130         None       clínico               NML          no
# 131         None       clínico               MIR          no
# 132         None       clínico               MIR          no
# 133   2022-02-20         conxo              UPAL          no
# 134         None         conxo              UPAL          no
# 135   2022-03-06       clínico               URG          no
# 136   2022-06-08       clínico               URG          no
# 137   2022-06-29       clínico               URG          no
# 138   2022-07-05       clínico               URG          no
# 139   2022-07-11       clínico               URG          no
# 140   2022-07-19       clínico               URG          no
# 141   2022-07-21       clínico               URG          no
# 142   2022-07-22       clínico               URG          no
# 143   2022-08-04       clínico               URG          no
# 144   2022-08-12       clínico               URG          no
# 145   2022-08-17       clínico               URG          no
# 146   2022-08-22       clínico               URG          no
# 147   2022-08-22       clínico               URG          no
# 148   2022-08-24       clínico               URG          no
# 149   2022-08-24       clínico               URG          no
# 150   2022-10-07       clínico               URG          no
# 151         None       clínico               URG          no
# 152         None       clínico               URG          no
# 153   2022-06-08       clínico               URO          no
# 154   2022-08-30       clínico               URO          no
# 155   2022-06-16       clínico               ACV          no
# 156   2022-06-27       clínico               ACV          no
# 157   2022-09-16       clínico               ACV          no
# 158         None       clínico               ACV          no
# 159         None       clínico               ACV          no
# 160         None       clínico               ACV          no
# 161         None       clínico               ACV          no
# 162   2022-06-27         conxo               CPR          si
# 163         None       clínico               CAR          no
# 164   2022-09-26       clínico               CAR          no
# 165         None       clínico              CCAR          no
# 166   2022-06-23       clínico               CGD          no
# 167         None       clínico               CGD          no
# 168         None       clínico               CGD          no
# 169         None       clínico               CGD          no
# 170   2022-10-20       clínico               TRA          no
# 171   2022-06-15       clínico               DIG          no
# 172         None       clínico               DIG          no
# 173         None       clínico               DIG          no
# 174         None       clínico               DIG          no
# 175         None       clínico               HEM          no
# 176   2022-07-29       clínico               MIR          no
# 177   2022-09-01       clínico               MIR          no
# 178   2022-09-02       clínico               MIR          no
# 179   2022-10-17       clínico               MIR          no
# 180   2022-08-02       clínico               MIR          no
# 181         None       clínico               MIR          no
# 182         None       clínico               MIR          no
# 183         None       clínico               MIR          no
# 184         None       clínico               MIR          no
# 185         None         conxo               MIR          no
# 186         None         conxo               MIR          no
# 187         None         conxo               MIR          no
# 188   2022-10-20         conxo               MIR          no
# 189         None   gil@casares               MIR          no
# 190         None   gil@casares               MIR          no
# 191         None   gil@casares               MIR          no
# 192         None   gil@casares               MIR          no
# 193   2022-08-17         conxo               MIR          no
# 194         None       clínico               NFR          no
# 195         None       clínico               NFR          no
# 196   2022-07-29       clínico               NML          no
# 197   2022-06-23       clínico               NML          no
# 198         None       clínico               NML          no
# 199         None       clínico               NML          no
# 200         None       clínico               NML          no
# 201   2022-06-23            no                no          si
# 202   2022-08-09            no                no          si
# 203   2022-08-14            no                no          si
# 204   2022-08-18            no                no          si
# 205   2022-08-18            no                no          si
# 206   2022-08-19            no                no          si
# 207         None            no                no          si
# 208         None            no                no          si
# 209         None            no                no          si
# 210         None            no                no          si
# 211         None            no                no          si
# 212         None            no                no          si
# 213         None            no                no          si
# 214         None            no                no          si
# 215         None            no                no          si
# 216         None            no                no          si
# 217         None            no                no          si
# 218         None            no                no          si
# 219         None            no                no          si
# 220         None            no                no          si
# 221         None            no                no          si
# 222   2022-09-20            no                no          si
# 223   2022-10-03            no                no          si
# 224   2022-10-11            no                no          si
# 225   2022-10-17            no                no          si
# 226   2022-07-19       clínico               ONC          no
# 227   2022-09-09       clínico               ONC          no
# 228   2022-09-06       clínico               ONC          no
# 229   2022-09-05       clínico               ONC          no
# 230   2022-06-20       clínico               ONC          no
# 231   2022-07-23       clínico               ONC          si
# 232         None       clínico               ONC          no
# 233         None       clínico               ONC          no
# 234         None       clínico               ONC          no
# 235         None       clínico               ONC          si
# 236         None       clínico               ONC          no
# 237         None       clínico               ONC          no
# 238         None       clínico               ONC          no
# 239         None       clínico               ONC          no
# 240         None       clínico               ONC          no
# 241         None       clínico               ONC          no
# 242         None       clínico               ONC          no
# 243         None       clínico               ONC          no
# 244         None       clínico               ONC          no
# 245         None       clínico               ONC          no
# 246         None       clínico               ONC          no
# 247         None       clínico               ONC          no
# 248   2022-10-04       clínico               ONC          no
# 249   2022-10-05       clínico               ONC          no
# 250   2022-10-11       clínico               ONC          no
# 251   2022-10-20       clínico               ONC          no
# 252         None       clínico               ORL          no
# 253         None       clínico               RDT          no
# 254         None         conxo             REHAB          no
# 255   2022-06-17       clínico               MIR          no
# 256   2022-06-10         conxo              UPAL          no
# 257   2022-08-21         conxo              UPAL          no
# 258         None         conxo              UPAL          no
# 259         None         conxo              UPAL          no
# 260         None         conxo              UPAL          no
# 261   2022-06-16       clínico               URG          no
# 262   2022-09-30       clínico               URG          no
# 263   2022-06-17       clínico               URG          no
# 264   2022-06-20       clínico               URG          no
# 265   2022-06-27       clínico               URG          no
# 266   2022-06-29       clínico               URG          no
# 267   2022-07-20       clínico               URG          no
# 268   2022-08-02       clínico               URG          no
# 269   2022-08-04       clínico               URG          no
# 270   2022-08-09       clínico               URG         uro
# 271   2022-08-22       clínico               URG          no
# 272   2022-08-29       clínico               URG          no
# 273         None       clínico               URG          no
# 274         None       clínico               URG          no
# 275         None       clínico               URG          no
# 276         None       clínico               URG          no
# 277         None       clínico               URG          no
# 278         None       clínico               URG          no
# 279   2022-09-26       clínico               URG          no
# 280   2022-10-04       clínico               URG          no
# 281   2022-10-14       clínico               URG          no
# 282   2022-08-12       clínico               ACV          no
# 283   2022-03-17       clínico               ACV          no
# 284   2022-04-25       clínico               ACV          no
# 285   2022-05-22       clínico               CGD          no
# 286   2022-05-30       clínico               CGD          no
# 287   2022-08-08       clínico               CGD          no
# 288   2022-08-12       clínico               CGD          no
# 289   2022-10-27       clínico               CGD          no
# 290   2022-11-02       clínico               CGD          no
# 291   2022-03-30       clínico               CGD          no
# 292   2022-04-12       clínico               CGD          no
# 293   2022-05-06       clínico               CGD          no
# 294   2022-07-26       clínico               MIR          no
# 295   2022-08-31       clínico               MIR          no
# 296   2022-10-18       clínico               MIR          no
# 297   2022-10-24       clínico               MIR          no
# 298   2022-03-10       clínico               MIR          no
# 299   2022-03-17       clínico               MIR          no
# 300   2022-04-27       clínico               MIR          no
# 301   2022-05-02       clínico               MIR          no
# 302   2022-05-05       clínico               MIR          no
# 303   2022-05-05            no               NCR          si
# 304   2022-05-18            no               NCR          si
# 305   2022-07-14            no               NCR          si
# 306   2022-07-29            no               NCR          si
# 307   2022-08-18            no               NCR          si
# 308   2022-08-26            no               NCR          si
# 309   2022-09-29       clínico               NFR          no
# 310   2022-09-19       clínico               NML          no
# 311   2022-09-20       clínico               NML          no
# 312   2022-05-19       clínico               NML          no
# 313   2022-08-10       clínico               NML          no
# 314   2022-10-19       clínico               NML          no
# 315   2022-04-05       clínico               NML          no
# 316   2022-05-02       clínico               NML          no
# 317   2022-05-07       clínico               NML          no
# 318   2022-05-27       clínico               NML          no
# 319   2022-03-25            no                no          si
# 320   2022-05-09            no                no          si
# 321   2022-07-11            no                no          si
# 322   2022-07-13            no                no          si
# 323   2022-08-22            no                no          si
# 324   2022-09-09            no                no          si
# 325   2022-09-02            no                no          si
# 326   2022-09-13            no                no          si
# 327   2022-09-15            no                no          si
# 328   2022-09-20            no                no          si
# 329   2022-09-20            no                no          si
# 330   2022-09-22            no                no          si
# 331   2022-10-24            no                no          si
# 332   2022-10-27            no                no          si
# 333   2022-11-02            no                no          si
# 334   2022-05-03       clínico               NRL          no
# 335   2022-05-05       clínico               NRL          no
# 336   2022-05-19       clínico               ONC          no
# 337   2022-05-27       clínico               ONC          no
# 338   2022-07-20       clínico               ONC          no
# 339   2022-08-04       clínico               ONC          no
# 340   2022-08-12       clínico               ONC          no
# 341   2022-08-19       clínico               ONC          no
# 342   2022-08-31       clínico               ONC          no
# 343   2022-09-12       clínico               ONC          no
# 344   2022-09-25       clínico               ONC          no
# 345   2022-10-03       clínico               ONC          no
# 346   2022-10-11       clínico               ONC          no
# 347   2022-03-14       clínico               ONC          no
# 348   2022-03-25       clínico               ONC          no
# 349   2022-03-28       clínico               ONC          no
# 350   2022-05-11       clínico               ONC          no
# 351   2022-05-18       clínico               ONC          no
# 352   2022-05-18       clínico               ONC          no
# 353   2022-07-31       clínico               MIR          no
# 354   2022-05-09       clínico               MIR          no
# 355   2022-04-04       clínico              UPAL          no
# 356   2022-07-09         conxo              UPAL          no
# 357   2022-08-09         conxo              UPAL          no
# 358   2022-08-16         conxo              UPAL          no
# 359   2022-08-22         conxo              UPAL          no
# 360   2022-09-30         conxo              UPAL          no
# 361   2022-10-11         conxo              UPAL          no
# 362   2022-05-27       clínico               URG          no
# 363   2022-07-07       clínico               URG          no
# 364   2022-07-20       clínico               URG          no
# 365   2022-08-05       clínico               URG          no
# 366   2022-08-17       clínico               URG          no
# 367   2022-08-22       clínico               URG          no
# 368   2022-08-31       clínico               URG          no
# 369   2022-09-12       clínico               URG          no
# 370   2022-09-30       clínico               URG          no
# 371   2022-10-07       clínico               URG          no
# 372   2022-03-22       clínico               URG          no
# 373   2022-03-29       clínico               URG          no
# 374   2022-04-11       clínico               URG          no
# 375   2022-04-28       clínico               URG          no
# 376   2022-05-05       clínico               URG          no
# 377   2022-05-16       clínico               URG          no
# 378   2022-09-29       clínico               UTR          no
# 379   2022-07-09       clínico               ACV          no
# 380         None       clínico               ACV          no
# 381         None       clínico               ACV          no
# 382         None       clínico               ACV          no
# 383   2022-09-03       clínico               CAR          no
# 384   2022-06-07       clínico               CGD          no
# 385   2022-06-08       clínico               CGD          no
# 386         None       clínico               HEM          no
# 387   2022-07-12       clínico               MIR          no
# 388   2022-09-21       clínico               MIR          no
# 389         None       clínico               MIR          no
# 390         None       clínico               MIR          no
# 391         None       clínico               MIR          no
# 392         None       clínico               MIR          no
# 393         None       clínico               MIR          no
# 394   2022-08-18       clínico               MIR          no
# 395   2022-06-01         conxo               MIR          no
# 396         None         conxo               MIR          no
# 397         None         conxo               MIR          no
# 398         None   gil@casares               MIR          no
# 399   2022-11-03   gil@casares               MIR          no
# 400         None       clínico               NCR          no
# 401         None       clínico               NFR          no
# 402   2022-06-23       clínico               NML          no
# 403   2022-06-27       clínico               NML          no
# 404   2022-07-21       clínico               NML          no
# 405   2022-10-04       clínico               NML          no
# 406   2022-08-25       clínico               NML          no
# 407         None       clínico               NML          no
# 408         None       clínico               NML          no
# 409   2022-07-05       clínico                no          si
# 410   2022-05-19            no                no          si
# 411   2022-08-23            no                no          si
# 412         None            no                no          si
# 413         None            no                no          si
# 414         None            no                no          si
# 415         None            no                no          si
# 416         None            no                no          si
# 417         None            no                no          si
# 418         None            no                no          si
# 419         None            no                no          si
# 420         None            no                no          si
# 421         None            no                no          si
# 422   2022-08-19            no                no          si
# 423     26/09722            no                no          si
# 424   2022-05-19       clínico               ONC          no
# 425   2022-05-30       clínico               ONC          no
# 426   2022-06-17       clínico               ONC          no
# 427   2022-07-26       clínico               ONC          no
# 428   2022-08-17       clínico               ONC          no
# 429   2022-09-19       clínico               ONC          no
# 430         None       clínico               ONC          no
# 431         None       clínico               ONC          no
# 432         None       clínico               ONC          no
# 433         None       clínico               ONC          no
# 434         None       clínico               ONC          no
# 435   2022-06-30       clínico               RDT          no
# 436         None       clínico               RDT          no
# 437     20/09722       clínico               MIR          no
# 438   2022-05-27         conxo              UPAL          no
# 439   2022-07-11         conxo              UPAL          no
# 440         None         conxo              UPAL          no
# 441         None         conxo              UPAL          no
# 442   2022-08-25         conxo              UPAL          no
# 443   2022-06-21         conxo              UPAL          no
# 444   2022-06-14       clínico               URG          no
# 445   2022-06-22       clínico               URG          no
# 446   2022-06-28       clínico               URG          no
# 447   2022-07-07       clínico               URG          no
# 448   2022-07-11       clínico               URG          no
# 449   2022-07-27       clínico               URG          no
# 450   2022-08-17       clínico               URG          no
# 451   2022-08-18       clínico               URG          no
# 452   2022-10-18       clínico               URG          no
# 453   2022-08-30       clínico               URG          no
# 454   2022-09-02       clínico               URG          no
# 455         None       clínico               URG          no
# 456         None       clínico               URG          no
# 457         None       clínico               URG          no
# 458         None       clínico               URG          no
# 459         None       clínico               URG          no
# 460         None       clínico               URG          no
# 461   2022-06-28            no               URG          no
# 462   2022-07-26       clínico               URO          no
# 463         None       clínico               MIR          no
# 464         None            no                no          si
# 465         None       clínico               ONC          no
# 466   2022-06-14       clínico               ACV          no
# 467   2022-06-23       clínico               ACV          no
# 468   2022-07-27       clínico               ACV          no
# 469   2022-09-23       clínico               ACV          no
# 470         None       clínico               ACV          no
# 471   2022-06-14       clínico               CGD          no
# 472   2022-08-08       clínico               CGD          no
# 473   2022-10-10       clínico               CGD          no
# 474         None       clínico               CGD          no
# 475         None       clínico               CGD          no
# 476   2022-09-12       clínico               DIG          NO
# 477   2022-11-07       clínico               DIG          no
# 478         None       clínico               DIG          no
# 479   2022-06-28       clínico               GIN          no
# 480   2022-10-05       clínico               GIN          no
# 481   2022-06-30       clínico               HEM          no
# 482   2022-07-27       clínico               HEM          no
# 483   2022-09-13       clínico               HEM          no
# 484   2022-06-03       clínico               HEM          no
# 485   2022-06-06       clínico               HEM          no
# 486         None       clínico               HEM          no
# 487         None       clínico               HEM          no
# 488         None       clínico               HEM          no
# 489         None       clínico               HEM          no
# 490         None       clínico               HEM          no
# 491   2022-08-08       clínico               MIR          no
# 492   2022-09-15       clínico               MIR          no
# 493   2022-10-03       clínico               MIR          no
# 494   2022-10-14       clínico               MIR          no
# 495   2022-06-01       clínico               MIR          no
# 496         None       clínico               MIR          no
# 497         None       clínico               MIR          no
# 498         None       clínico               MIR          no
# 499   2022-05-16         conxo               MIR          no
# 500   2022-06-09         conxo               MIR          no
# 501   2022-06-09         conxo               MIR          no
# 502   2022-06-20         conxo               MIR          no
# 503   2022-06-20         conxo               MIR          no
# 504   2022-06-22         conxo               MIR          no
# 505   2022-08-01         conxo               MIR          no
# 506   2022-08-02         conxo               MIR          no
# 507   2022-08-05         conxo               MIR          no
# 508   2022-08-09         conxo               MIR          NO
# 509   2022-09-08         conxo               MIR          no
# 510         None         conxo               MIR          no
# 511         None         conxo               MIR          no
# 512   2022-09-17         conxo               MIR          no
# 513   2022-10-05         conxo               MIR          no
# 514   2022-10-14         conxo               MIR          no
# 515   2022-10-25         conxo               MIR          no
# 516   2022-06-17   gil@casares               MIR          no
# 517   2022-06-20   gil@casares               MIR          no
# 518         None   gil@casares               MIR          no
# 519         None   gil@casares               MIR          no
# 520         None   HM@rosaleda               MIR          no
# 521   2022-06-16       clínico               NCR          no
# 522         None       clínico               NCR          no
# 523   2022-06-06            no               NCR          si
# 524         None            no               NCR          si
# 525         None       clínico               NFR          no
# 526         None            no               NFR          si
# 527   2022-09-23       clínico               NML          no
# 528         None       clínico               NML          no
# 529         None       clínico               NML          no
# 530         None       clínico               NML          no
# 531   2022-03-23            no                no          si
# 532   2022-04-18            no                no          si
# 533   2022-06-13            no                no          si
# 534   2022-06-14            no                no          si
# 535   2022-06-16            no                no          si
# 536   2022-06-20            no                no          si
# 537   2022-06-20            no                no          si
# 538   2022-06-23            no                no          si
# 539   2022-06-27            no                no          si
# 540   2022-07-21            no                no          si
# 541   2022-08-01            no                no          si
# 542   2022-08-02            no                NO          SI
# 543   2022-08-02            no                NO          SI
# 544   2022-08-03            no                NO          SI
# 545   2022-08-04            no                no          SI
# 546   2022-08-05            no                NO          SI
# 547   2022-08-10            no                no          si
# 548   2022-08-11            no                NO          si
# 549   2022-09-07            no                no          si
# 550   2022-09-08            no                no          si
# 551         None            no                no          si
# 552         None            no                no          si
# 553         None            no                no          si
# 554         None            no                no          si
# 555         None            no                no          si
# 556         None            no                no          si
# 557   2022-09-09            no                no          si
# 558   2022-09-09            no                no          si
# 559   2022-09-16            no                no          si
# 560   2022-09-19            no                no          si
# 561   2022-09-20            no                no          si
# 562   2022-09-21            no                no          si
# 563   2022-09-26            no                no          si
# 564   2022-09-30            no                no          si
# 565   2022-09-26            no                no          si
# 566   2022-09-28            no                no          si
# 567   2022-10-10            no                no          si
# 568   2022-10-10            no                no          si
# 569   2022-10-06            no                no          si
# 570   2022-10-11            no                NO          si
# 571   2022-10-19            no                no          si
# 572   2022-10-19            no                no          si
# 573   2022-10-21            no                no          si
# 574   2022-10-28            no                no          si
# 575   2022-10-28            no                no          si
# 576   2022-11-02            no                no          si
# 577   2022-11-03       clínico               NRL          no
# 578   2022-03-25       clínico               ONC          no
# 579   2022-06-14       clínico               ONC          no
# 580   2022-07-01       clínico               ONC          no
# 581   2022-10-16       clínico               ONC          no
# 582   2022-10-14       clínico               ONC          no
# 583   2022-10-25       clínico               ONC          no
# 584   2022-10-28       clínico               ONC          no
# 585   2022-04-25       clínico               ONC          no
# 586   2022-05-02       clínico               ONC          no
# 587         None       clínico               ONC          no
# 588         None       clínico               ONC          no
# 589         None       clínico               ONC          no
# 590         None       clínico               ONC          no
# 591         None       clínico               ONC          no
# 592         None       clínico               ONC          no
# 593   2022-09-13       clínico               ONC          no
# 594         None       clínico               TRA          no
# 595   2022-10-19         conxo               TRA          no
# 596         None       clínico              UPAL          no
# 597   2022-04-18         conxo              UPAL          no
# 598   2022-06-17         conxo              UPAL          no
# 599   2022-06-25         conxo              UPAL          no
# 600   2022-06-29         conxo              UPAL          no
# 601   2022-06-30         conxo              UPAL          no
# 602   2022-10-09         conxo              UPAL          no
# 603   2022-03-28       clínico               URG          no
# 604   2022-05-13       clínico               URG          no
# 605   2022-06-13       clínico               URG          no
# 606   2022-06-13       clínico               URG          no
# 607   2022-06-14       clínico               URG          no
# 608   2022-06-28       clínico               URG          no
# 609   2022-07-22       clínico               URG          no
# 610   2022-07-26       clínico               URG          no
# 611   2022-07-28       clínico               URG          no
# 612   2022-08-04       clínico               URG          NO
# 613   2022-08-09       clínico               URG          NO
# 614   2022-08-12       clínico               URG          no
# 615   2022-09-21       clínico               URG          no
# 616   2022-09-30       clínico               URG          no
# 617   2022-10-14       clínico               URG          no
# 618   2022-10-13       clínico               URG          no
# 619   2022-10-14       clínico               URG          no
# 620   2022-03-24       clínico               URG          no
# 621         None       clínico               URG          no
# 622         None       clínico               URG          no
# 623         None       clínico               URG          no
# 624         None       clínico               URG          no
# 625         None       clínico               URG          no
# 626         None       clínico               URG          no
# 627         None       clínico               URG          no
# 628   2022-08-23       clínico               ACV          no
# 629   2022-09-26       clínico               ACV          no
# 630   2022-10-03       clínico               ACV          no
# 631         None       clínico               ACV          no
# 632   2022-06-20       clínico               CGD          no
# 633   2022-09-26       clínico               CGD          no
# 634         None       clínico               CGD          no
# 635         None       clínico               DIG          no
# 636         None       clínico               DIG          no
# 637   2022-06-28       clínico               HEM          no
# 638   2022-07-28       clínico               HEM          no
# 639   2022-09-02       clínico               HEM          no
# 640         None       clínico               HEM          no
# 641         None       clínico               HEM          no
# 642         None       clínico               HEM          no
# 643         None       clínico               HEM          no
# 644         None       clínico               HEM          no
# 645   2022-06-19       clínico               HEM          no
# 646   2022-06-20       clínico               MIR          no
# 647   2022-07-11       clínico               MIR          no
# 648   2022-07-18       clínico               MIR          no
# 649   2022-07-19       clínico               MIR          no
# 650   2022-08-17       clínico               MIR          no
# 651   2022-08-23       clínico               MIR          no
# 652   2022-08-23       clínico               MIR          no
# 653   2022-09-07       clínico               MIR          no
# 654   2022-09-08       clínico               MIR          no
# 655   2022-09-19       clínico               MIR          no
# 656   2022-10-31       clínico               MIR          no
# 657         None       clínico               MIR          no
# 658         None       clínico               MIR          no
# 659         None       clínico               MIR          no
# 660         None       clínico               MIR          no
# 661         None       clínico               MIR          no
# 662         None       clínico               MIR          no
# 663   2022-07-05         conxo               MIR          no
# 664         None         conxo               MIR          no
# 665         None         conxo               MIR          no
# 666         None         conxo               MIR          no
# 667         None         conxo               MIR          no
# 668         None         conxo               MIR          no
# 669         None         conxo               MIR          no
# 670         None         conxo               MIR          no
# 671         None         conxo               MIR          no
# 672         None         conxo               MIR          no
# 673   2022-09-06         conxo               MIR          no
# 674   2022-07-04   gil@casares               MIR          no
# 675   2022-08-26            no               MIR          no
# 676   2022-08-24       clínico               NCR          no
# 677   2022-07-11       clínico               NML          no
# 678   2022-06-07            no                no          si
# 679   2022-08-19            no                no          AP
# 680         None            no                no          si
# 681         None            no                no          si
# 682         None            no                no          si
# 683         None            no                no          si
# 684         None            no                no          si
# 685         None            no                no          si
# 686         None            no                no          si
# 687         None            no                no          si
# 688         None            no                no          si
# 689         None            no                no          si
# 690   2022-10-31            no                no          AP
# 691   2022-07-15       clínico               NRL          no
# 692   2022-03-22       clínico               ONC          no
# 693   2022-06-09       clínico               ONC          no
# 694   2022-06-16       clínico               ONC          no
# 695   2022-06-23       clínico               ONC          no
# 696   2022-08-31       clínico               ONC          no
# 697   2022-08-31       clínico               ONC          no
# 698   2022-09-27       clínico               ONC          no
# 699   2022-10-27       clínico               ONC          no
# 700   2022-10-27       clínico               ONC          no
# 701         None       clínico               ONC          no
# 702         None       clínico               ONC          no
# 703         None       clínico               ONC          no
# 704         None       clínico               ONC          no
# 705         None       clínico               ONC          no
# 706         None       clínico               ONC          no
# 707         None       clínico               ONC          no
# 708         None       clínico               ONC          no
# 709         None       clínico               ONC          no
# 710   2022-06-13       clínico               ORL          no
# 711         None       clínico               TRA          no
# 712         None         conxo              UPAL          no
# 713   2022-06-06       clínico               URG          no
# 714   2022-06-16       clínico               URG          no
# 715   2022-06-29       clínico               URG          no
# 716   2022-07-12       clínico               URG          no
# 717   2022-07-13       clínico               URG          no
# 718   2022-07-20       clínico               URG          no
# 719   2022-07-26       clínico               URG          no
# 720   2022-09-01       clínico               URG          no
# 721   2022-09-08       clínico               URG          no
# 722   2022-09-13       clínico               URG          no
# 723   2022-09-21       clínico               URG          no
# 724   2022-09-19       clínico               URG          no
# 725   2022-09-20       clínico               URG          no
# 726   2022-10-28       clínico               URG          no
# 727         None       clínico               URG          no
# 728         None       clínico               URG          no
# 729         None       clínico               URG          no
# 730         None       clínico               URG          no
# 731         None       clínico               URG          no
# 732         None       clínico              UTAB          no
# 733   2022-07-09       clínico               UTR          no
# 734   2022-08-24       clínico               ACV          no
# 735         None       clínico               ACV          no
# 736         None       clínico               ACV          no
# 737         None       clínico               CMX          no
# 738         None       clínico               CMX          no
# 739         None       clínico               DIG          no
# 740         None       clínico               DIG          no
# 741   2022-08-09       clínico               END          no
# 742         None       clínico               END          no
# 743         None       clínico               END          no
# 744         None       clínico               END          no
# 745   2022-08-05       clínico               MIR          no
# 746   2022-10-05       clínico               MIR          no
# 747   2022-10-10       clínico               MIR          no
# 748   2022-10-24       clínico               MIR          no
# ...
# 843         1.0          2.0             Ames                 novo  2022
# 844         5.0          6.0         santiago                 novo  2022
# 845         3.0          5.0            lalin  villar@del@castillo  2022
# 846         1.0          3.0   vila@de@cruces                 novo  2022
# 847         7.0         39.0             Ames              beceiro  2022
# 848         3.0          3.0            lalin  villar@del@castillo  2022
# 849         4.0          6.0        Boqueixon               suarez  2022
# 850         3.0          4.0        Boqueixon                 novo  2022
# 851         4.0          6.0   vila@de@cruces                 novo  2022
# 852         4.0          5.0              Teo               suarez  2022
# 853         8.0         10.0          silleda  villar@del@castillo  2022
# 854         1.0          2.0          ordenes         lopez@renedo  2022
# 855         9.0         25.0         santiago         lopez@renedo  2022
# 856         4.0          8.0         santiago         lopez@renedo  2022
# 857         4.0          8.0          silleda  villar@del@castillo  2022
# 858         5.0          8.0            lalin  villar@del@castillo  2022
# 859         6.0         16.0         santiago     fernandez@benito  2022
# 860         1.0          3.0           rianxo     fernandez@benito  2022
# 861         2.0          4.0             Ames     fernandez@benito  2022
# 862         2.0          6.0         santiago     fernandez@benito  2022
# 863         1.0          2.0         santiago     fernandez@benito  2022
# 864        17.0         56.0         santiago     fernandez@benito  2022
# 865         2.0          2.0           Ortoño     fernandez@benito  2022
# 866         4.0         11.0             ames     fernandez@benito  2022
# 867         3.0         11.0         santiago     fernandez@benito  2022
# 868         2.0          7.0         santiago     fernandez@benito  2022
# 869         6.0         14.0         santiago     fernandez@benito  2022
# 870         9.0         16.0         santiago     fernandez@benito  2022
# 871         5.0         14.0             NOIA     fernandez@benito  2022
# 872         1.0          2.0          lousame     fernandez@benito  2022
# 873         5.0         12.0           rianxo     fernandez@benito  2022
# 874         2.0          6.0           padron     fernandez@benito  2022
# 875         2.0          6.0         santiago     fernandez@benito  2022
# 876         1.0          2.0          lousame     fernandez@benito  2022
# 877         5.0         21.0           rianxo     fernandez@benito  2022
# 878         4.0          9.0             noia     fernandez@benito  2022
# 879         4.0         11.0         santiago     fernandez@benito  2022
# 880         6.0         21.0             Ames     fernandez@benito  2022
# 881         4.0          7.0             NOIA     fernandez@benito  2022
# 882         6.0         14.0           rianxo     fernandez@benito  2022
# 883         3.0          7.0         santiago     fernandez@benito  2022
# 884         1.0          2.0           rianxo     fernandez@benito  2022
# 885         8.0         29.0         santiago     fernandez@benito  2022
# 886         2.0          7.0           rianxo     fernandez@benito  2022
# 887         1.0          2.0             NOIA     fernandez@benito  2022
# 888         1.0          2.0           rianxo     fernandez@benito  2022
# 889         7.0         18.0         santiago     fernandez@benito  2022
# 890         1.0          2.0          Lousame     fernandez@benito  2022
# 891        20.0         30.0        a@Estrada               suarez  2022
# 892         7.0         14.0              Teo               suarez  2022
# 893         5.0         10.0        a@Estrada               suarez  2022
# 894         1.0          2.0            trazo         lopez@renedo  2022
# 895         4.0          9.0     Pontecesures              beceiro  2022
# 896         4.0          7.0             Ames              beceiro  2022
# 897         4.0          8.0           padron              beceiro  2022
# 898        18.0         28.0            lalin  villar@del@castillo  2022
# 899         2.0          2.0          silleda  villar@del@castillo  2022
# 900         7.0         13.0            Dodro              beceiro  2022
# 901         4.0          8.0         santiago                 novo  2022
# 902         1.0          1.0            lalin  villar@del@castillo  2022
# 903         6.0          9.0            lalin  villar@del@castillo  2022
# 904        10.0         33.0       la@estrada               suarez  2022
# 905         3.0          8.0              Teo               suarez  2022
# 906         2.0          8.0       La@Estrada               suarez  2022
# 907         2.0         10.0              Teo               suarez  2022
# 908         8.0         14.0          silleda  villar@del@castillo  2022
# 909        15.0         92.0              Teo               suarez  2022
# 910         1.0          5.0         santiago                 novo  2022
# 911         1.0          1.0              Teo                 novo  2022
# 912         5.0          9.0            lalin  villar@del@castillo  2022
# 913         2.0          8.0         Negreira              beceiro  2022
# 914         6.0         12.0       La@Estrada               suarez  2022
# 915         3.0          7.0          ordenes         lopez@renedo  2022
# 916         3.0          5.0           o@pino         lopez@renedo  2022
# 917        40.0         58.0            lalin  villar@del@castillo  2022
# 918         7.0         13.0         santiago          gómez@buela  2022
# 919         3.0          7.0         santiago          gómez@buela  2022
# 920         3.0          7.0         santiago          gómez@buela  2022
# 921        14.0         20.0         santiago          gómez@buela  2022
# 922         2.0          8.0         santiago          gómez@buela  2022
# 923         1.0          1.0         santiago          gómez@buela  2022
# 924         3.0          9.0         santiago          gómez@buela  2022
# 925         2.0          3.0         santiago          gómez@buela  2022
# 926         4.0          5.0         santiago          gómez@buela  2022
# 927         5.0          8.0         santiago          gómez@buela  2022
# 928         4.0         13.0             Ames          gómez@buela  2022
# 929         3.0         10.0         santiago          gómez@buela  2022
# 930         1.0          5.0         santiago          gómez@buela  2022
# 931         3.0         11.0         santiago          gómez@buela  2022
# 932         6.0         13.0         santiago          gómez@buela  2022
# 933         7.0         24.0         santiago          gómez@buela  2022
# 934         3.0          5.0         santiago          gómez@buela  2022
# 935         2.0          4.0         santiago          gómez@buela  2022
# 936         5.0         17.0         santiago          gómez@buela  2022
# 937         7.0         21.0         santiago          gómez@buela  2022
# 938         7.0         30.0         santiago          gómez@buela  2022
# 939         7.0         29.0         santiago          gómez@buela  2022
# 940         7.0         18.0             Ames          gómez@buela  2022
# 941         2.0          4.0         santiago          gómez@buela  2022
# 942        10.0         33.0              Teo               suarez  2022
# 943         6.0         11.0          silleda  villar@del@castillo  2022
# 944         1.0          2.0          lousame     fernandez@benito  2022
# 945         1.0          2.0         santiago     fernandez@benito  2022
# 946         2.0          4.0         santiago     fernandez@benito  2022
# 947         5.0         11.0           rianxo     fernandez@benito  2022
# 948        10.0         33.0             NOIA     fernandez@benito  2022
# 949         1.0          2.0           rianxo     fernandez@benito  2022
# 950        16.0         32.0          lousame     fernandez@benito  2022
# 951         5.0         13.0             noia     fernandez@benito  2022
# 952         3.0          7.0           rianxo     fernandez@benito  2022
# 953         7.0         24.0             noia     fernandez@benito  2022
# 954         5.0         17.0         santiago     fernandez@benito  2022
# 955        30.0         37.0            lalin  villar@del@castillo  2022
# 956         3.0          6.0            oroso         lopez@renedo  2022
# 957        10.0         17.0          silleda  villar@del@castillo  2022
# 958         8.0         16.0            brión              beceiro  2022
# 959         7.0         24.0            touro         lopez@renedo  2022
# 960         2.0          3.0              Teo               suarez  2022
# 961        12.0         52.0         santiago                 novo  2022
# 962         6.0         10.0          silleda  villar@del@castillo  2022
# 963        50.0         65.0          silleda  villar@del@castillo  2022
# 964         1.0          7.0             Ames                 novo  2022
# 965         6.0         20.0         santiago                 novo  2022
# 966         4.0          7.0             Ames                 novo  2022
# 967         4.0         37.0              Teo               suarez  2022
# 968         3.0          8.0     val@do@dubra         lopez@renedo  2022
# 969         8.0         16.0           o@pino         lopez@renedo  2022
# 970         2.0          2.0       La@Estrada               suarez  2022
# 971         3.0          7.0            trazo         lopez@renedo  2022
# 972        14.0         38.0          ordenes         lopez@renedo  2022
# 973        10.0         18.0              Teo               suarez  2022
# 974         4.0         14.0             Ames              beceiro  2022
# 975         7.0         28.0             Ames              beceiro  2022
# 976         2.0          6.0           padron              beceiro  2022
# 977         7.0         19.0         Negreira              beceiro  2022
# 978         8.0         21.0             Rois              beceiro  2022
# 979        39.0         79.0           o@pino         lopez@renedo  2022
# 980        24.0         60.0           o@pino         lopez@renedo  2022
# 981         3.0         12.0          ordenes         lopez@renedo  2022
# 982         4.0          7.0          Tordoia         lopez@renedo  2022
# 983         7.0         29.0            oroso         lopez@renedo  2022
# 984         6.0         14.0            touro         lopez@renedo  2022
# 985         3.0         10.0          silleda  villar@del@castillo  2022
# 986         3.0          8.0           o@pino         lopez@renedo  2022
# 987         6.0          9.0              Teo               suarez  2022
# 988         2.0          7.0       la@Estrada               suarez  2022
# 989         4.0         13.0        Boqueixon               suarez  2022
# 990         9.0         15.0              Teo               suarez  2022
# 991         2.0          6.0           rianxo     fernandez@benito  2022
# 992        16.0         42.0         santiago     fernandez@benito  2022
# 993         6.0         18.0             noia     fernandez@benito  2022
# 994         2.0          4.0         santiago     fernandez@benito  2022
# 995         5.0         12.0           rianxo     fernandez@benito  2022
# 996         4.0          7.0           rianxo     fernandez@benito  2022
# 997         2.0          5.0           rianxo     fernandez@benito  2022
# 998         4.0         14.0         santiago     fernandez@benito  2022
# 999         3.0          7.0             noia     fernandez@benito  2022
# 1000        1.0          3.0             noia     fernandez@benito  2022
# 1001        1.0          2.0             noia     fernandez@benito  2022
# 1002        6.0          6.0            lalin  villar@del@castillo  2022
# 1003       12.0         28.0             Rois              beceiro  2022
# 1004        2.0          5.0             Rois              beceiro  2022
# 1005        2.0          5.0              Teo                 novo  2022
# 1006        5.0         15.0        a@Estrada                 novo  2022
# 1007       14.0         28.0            lalin  villar@del@castillo  2022
# 1008        1.0          2.0             Ames              beceiro  2022
# 1009        5.0          9.0       la@Estrada               suarez  2022
# 1010        6.0         24.0     Pontecesures              beceiro  2022
# 1011        4.0          7.0   vila@de@cruces  villar@del@castillo  2022
# 1012        6.0         15.0           A@Baña              beceiro  2022
# 1013       11.0         36.0        Boqueixon               suarez  2022
# 1014        4.0          7.0         santiago          gómez@buela  2022
# 1015        2.0          7.0         santiago          gómez@buela  2022
# 1016        2.0          9.0         santiago          gómez@buela  2022
# 1017        6.0         30.0         santiago          gómez@buela  2022
# 1018        1.0          2.0         santiago          gómez@buela  2022
# 1019        1.0          7.0         santiago          gómez@buela  2022
# 1020        3.0          5.0         santiago          gómez@buela  2022
# 1021        2.0         20.0         santiago          gómez@buela  2022
# 1022        1.0          2.0         santiago          gómez@buela  2022
# 1023        1.0          2.0         santiago          gómez@buela  2022
# 1024        4.0         28.0         santiago          gómez@buela  2022
# 1025        2.0          9.0         santiago          gómez@buela  2022
# 1026        6.0          9.0         santiago          gómez@buela  2022
# 1027        2.0          8.0            brión          gómez@buela  2022
# 1028        3.0         31.0         santiago          gómez@buela  2022
# 1029        2.0          8.0         santiago          gómez@buela  2022
# 1030        3.0          7.0              teo               suarez  2022
# 1031        6.0         13.0            lalin  villar@del@castillo  2022
# 1032        2.0          7.0             Rois              beceiro  2022
# 1033        1.0          2.0             Ames                 novo  2022
# 1034        1.0          2.0         santiago                 novo  2022
# 1035        7.0         22.0           padron              beceiro  2022
# 1036       37.0        171.0         Negreira              beceiro  2022
# 1037        6.0         10.0          silleda  villar@del@castillo  2022
# 1038       16.0         29.0            lalin  villar@del@castillo  2022
# 1039        3.0          5.0            vedra                 novo  2022
# 1040        1.0          6.0        Boqueixon               suarez  2022
# 1041       12.0         24.0         santiago                 novo  2022
# 1042        1.0          3.0         santiago                 novo  2022
# 1043        6.0         10.0       La@Estrada               suarez  2022
# 1044        6.0          8.0          ordenes         lopez@renedo  2022
# 1045        2.0          7.0         santiago          gómez@buela  2022
# 1046        3.0          7.0         santiago          gómez@buela  2022
# 1047        3.0          8.0         santiago          gómez@buela  2022
# 1048        2.0          6.0         santiago          gómez@buela  2022
# 1049        4.0          6.0         santiago          gómez@buela  2022
# 1050        4.0          4.0         santiago          gómez@buela  2022
# 1051        7.0         15.0     Pontecesures              beceiro  2022
# 1052        4.0          6.0          silleda  villar@del@castillo  2022
# 1053        7.0         21.0           rianxo     fernandez@benito  2022
# 1054        3.0         11.0             noya     fernandez@benito  2022
# 1055        6.0         11.0         santiago                 novo  2022

# %%
def data_strip(df):
    for column in df:
        df[column] = df[column].replace(r"^ +| +$",r"", regex = True) # Quitamos los espacios del principio y final de los datos

# %%
data_strip(df_concatenado)
df_concatenado["ap"].unique()
# Out:
# array(['no', 'si', 'PAC', None, 'NO', 'ap', 'mo', 'consulta externa',
#        'AP', 'SI', 'uro', 'residencia'], dtype=object)

# %%
unicos(df_concatenado)
# Out:
# h_procedencia
# 34 ['gil casares' 'clinico' 'no' 'provincial' 'hula' 'conxo' 'CHUAC'
#  'clincio' 'clnico' 'si' 'clínico' 'cliinico' None 'salnes' 'rosaleda'
#  'clincico' 'HGC' 'HCG' 'hgc' 'ap' 'San Rafael La Coruña'
#  'Quiron La Coruña' 'Clínico' 'Clinico-ap' 'clinoco' 'Clinico'
#  'Lucus Augusti' 'chuac' 'HM' 'residencia' 'CLINICO' 'Pontevedra'
#  'HM rosaleda' 'Gil Casares']
# ==================================================================
# s_procedencia
# 213 ['upal' 'ONC' 'MIR' 'DIG' 'URG' 'no' 'onc' 'hem' 'tra' 'urg' 'rdt' 'mir'
#  'nml' 'mirp' 'cgd' 'ume' 'dig' 'cot' 'nmlp' 'acv' 'umap' 'nef' 'nof'
#  'cardiologia' 'NML' 'car' 'nrl' 'mirg' 'ncr' 'neumo' 'card' 'uro' 'gine'
#  'psqg' 'hematol' 'mir conxo' 'oncologia' 'nefrologia' 'digestivo'
#  'hematologia' 'urgencias' 'cirugía vascular' 'orl' 'neumologia' 'neuro'
#  'urologia' 'neurc' 'EIF MIR' 'cgd/urg' 'mirpro' 'cirugia general'
#  'hospital de dia' 'consulta ela multidisciplinar' 'UME' 'urgrn'
#  'mir gil casares no' 'Mir-ap protocolo hierro en domicilio'
#  'reumatologia' 'Nml-consultas esterna' 'Nml-urg' 'Nml-cosultas externas'
#  'hado' 'Onc-urg' 'Onc-consultas' 'Nml-consutas externas' 'Urg-onc'
#  'HDD nml' 'onc/urg' 'end' 'RTP' 'COT' 'urg/urg' 'MIRP' 'rtp'
#  'infecciosas' 'hematolog' 'neurologia' 'consulta mir' 'trauma'
#  'neurocirugia' 'cirugía torácica' 'cirugia vasc' 'eif' 'angiología'
#  'hematoloxia' 'mir provincial' 'nol' 'mirhp' 'Umap-mir' 'onc ccee'
#  'traumatologia' 'tramatologia' 'neomologia' 'si' 'Cvascular' 'Hem-urg'
#  'cmf' 'nutricion' 'consultas onc' 'unidad ela' 'cardiología' 'MIR-EIF'
#  'ap' 'cpl' 'UPAL' 'MIRG' 'neeumologia' 'C.Plástica' 'Cirugia General'
#  'mirc' 'Urg' '0nc' 'mir p' 'ccee mir' 'mir infecciosas' 'oncolo' 'crg'
#  'oncol consulta externa' 'radtp' 'Onco-urg' 'reu' 'nemologia' 'onco'
#  'cirugia vascular' 'consultas onco' 'endocrino' 'hepatologia' 'nfr'
#  'medicina interna' 'cee nefrologia' 'maxilofac' 'hemato'
#  'Mir- p -consultas externas' 'Urg-cirugia' 'con ext onco' 'Mir-Lugo'
#  'ccee onc' 'neum' 'cirugia cardiaca' 'mir gil' 'c.vascular'
#  'enfermedad infecciosas' 'c.cardiaca' 'c. vascular' 'CGD' 'respiratorio'
#  'consultas externas digestivo' 'Eif – mir' 'c.plástica'
#  'Neurologia – consultas externas' 'rdp' 'cirugia maxilofacial'
#  'Onc-consultas externa' 'UTR' 'ORL' 'Mir-p' 'c.externas mir'
#  'ccee neumologia' 'c externas c.plastica' 'endocrinologia'
#  'cirugia plastica' 'u. dolor' 'c.externas neumologia' 'ACV'
#  'consulta hipertension' 'der' 'UMAP' 'CLP' 'urg nrl' 'TRA' 'anr'
#  'c. toracica' 'gin' 'neu' 'Urg acv' 'urg hem' 'radioterapia' 'vascular'
#  'plastica' 'Onc urg' 'CPL' 'GIN' 'HADO' 'digstivo' 'Urg onc' 'Urg HEM'
#  'diagestivo' 'urg onc' 'mnl' 'CAR' 'HEM' 'ginecología' 'Urg trauma'
#  'nefrología' 'MIR Conxo' 'C.Vascular' 'cadiologia' 'UPIA' 'NCR' 'END'
#  'REU' 'URO' 'CPR' 'CCAR' 'NFR' 'RDT' 'REHAB' 'NRL' 'NO' 'UTAB' 'CMX'
#  'cirugía cardiaca' 'cirugia toracica']
# ==================================================================
# ap
# 12 ['no' 'si' 'PAC' None 'NO' 'ap' 'mo' 'consulta externa' 'AP' 'SI' 'uro'
#  'residencia']
# ==================================================================
# otros
# 52 ['no' 'nefro' 'cardiologia' 'cgd' 'nef' 'onc' 'uro' 'RTP' 'nrl' 'consulta'
#  'rosaleda' 'urg' 'c.e' 'si' 'consultas' 'residencia san marcos' 'ncr'
#  'NO' 'familia' 'hija' 'iniciativa propia' 'dig' 'nml' 'H.La Rosaleda'
#  'unidad EF MIR' 'residencia' 'solicitud familiar' 'np' 'familiares'
#  'Nml-end' 'nefro y dig' 'acv' 'Mir' 'vascular' 'mno' 'paliativos Salnes'
#  'nol' 'privado' 'Residencia sociosanitaria As Dores'
#  'residencia sanitaria' 'P. La Rosaleda' 61.0 'hospitales madrid'
#  'uro, cardiología' 'car,nefro,c.vasc' 'PAC Santiago' 'C. Plástica'
#  'Policlinico La Rosaleda' 'CCEE' 'hospital la Rosaleda' 'c. vascular' nan]
# ==================================================================
# diagnostico
# 1765 ['ca orl' 'Melanoma vulvar' 'ca broncogenico' ...
#  'ca urotelial estadio IV' 'pseudoartrosis de tibia' 'neoplasia pulmón']
# ==================================================================
# motivo_ing
# 668 ['contro d sintomas' 'mal control dolor' 'control evolutivo'
#  'admininistacion octreotido' 'control de sintomas' 'transfusion'
#  'Inf.osteosintesis' 'dolor' 'valoración' 'dolor abdominal'
#  'infección respiratoria' 'valoracion' 'neumonia' 'control síntomas'
#  'celulitis' 'control de sintom' 'tratamiento' 'broncoaspiracion'
#  'control d síntomas' 'inyección octreótrido' 'control dolor'
#  'tratamiento antibiotico iv' 'recambio peg' 'curas' 'transfusión'
#  'postoperatorio' 'angustia' 'diarrea' 'valoracion ulcera'
#  'valoracion ulceras' 'control de síntomas' 'paracentesis'
#  'infec respirat' 'ITU' 'continuacion cuidados' 'fiebre y dolor costal'
#  'antibioterapia' 'ulcera tumoral' 'tratamiento IV' 'dolo abdominal'
#  'curas herida quirurgica' 'ascitis' 'deterioor del estado general'
#  'infeccion urinaria' 'bronquiectasias infectadas' 'seguimiento' 'fiebre'
#  'hierro iv' 'tratamiento antibiotico IV' 'administracion seguril IV'
#  'control analgesico' 'seguimineto evolutivo ajuste de tratamiento'
#  'tratamiento IV y control evolutivo'
#  'tratamiento antibiotico y control evolutivo'
#  'tratamiento analgesico y control evolutivo'
#  'control analgesico y recambio PEG' 'cuidados paliativos'
#  'dolor precordial' 'control analgesico y valoracion hematuria'
#  'curas y control evolutivo' 'sindrome anemico-transfusión'
#  'valoración clínica' 'infección respiratoria y/o urinaria'
#  'tto antibiotico iv' 'protocolo vidaza'
#  'disnea, deterioro del estado general' 'tratamiento iv'
#  'control en domicilio y ajuste de tratamiento'
#  'control y tratamiento antibiotico IV' 'cuidados paliativos avanzadios'
#  'fase agónica, control de síntomas' 'obstrucción intestinal'
#  'síndrome anémico, protocolo transfusional' 'tto diurético iv'
#  'diarrea tóxica postquimioterapia' 'itu' 'fase final de vida'
#  'descompensación metabolica dolor' 'coma'
#  'control de sintomas fase de ultimos dias'
#  'control síntomas paciente agónica' 'agitacion'
#  'administracion hierro iv' 'tratmiento sintomatico'
#  'protocolo administracion lovo/carvidopa' 'control sintomas'
#  'comntrol sintomas' 'diarrea toxica,control sintomas' 'cuidados finales'
#  'administracion tratamiento IV' 'control sintomatico' 'sueroterapia'
#  'valoracion por nauseas y vomitos' 'anemia' 'antibioterapia iv'
#  'control y tratamiento sintomas' 'cantrol y paracentesis'
#  'control y cuidados paliativos' 'tto VIDAZA' 'tratmiento IV'
#  'comntrol de sintomas' 'cancer de prostata' 'cambio peg'
#  'infeccion abdominal' 'alteración hábito intestinal'
#  'ITU. Descompensación diabética' 'rectorragias'
#  'infeccion respiratoria, antibioterapia iv' 'infeccion tumor'
#  'curas y control de sintomas' 'ulceras presion' 'transfusion hierro'
#  'suboclusion intestinal' 'oclusión intestinal' 'cuidados colostomia'
#  'astenia' 'infeccion respiratoria,' 'inyeccion octreotrido'
#  'controld e sintomas' 'valoración nutricional' 'agonía'
#  'tratamiento antibiotico IV y control evolutivo' 'control y curas'
#  'tratmiento antibiotico IV' 'control y tratamientop sintomas'
#  'tratameinto antibiotico IV' 'recambio PEG' 'valoracion de tratamiento'
#  'trasfundir' 'reposicion colostomia, control y curas'
#  'analitica sanguinea' 'control ascitis' 'sedacion' 'oclusion intestinal'
#  'broncoaspiraciones recurrentes' 'itu...tto iv'
#  'deterioro del estado general y alteración del nivel de conciencia'
#  'curas y seguimiento' 'ITU, tto antibiótico' 'suboclusión intestinal'
#  'agonía, claudicación de AP' 'broncoaspiración, antibióticos iv'
#  'curas de herida, intolerancia oral'
#  'infección respiratoria, antibioterapia iv' 'sangrado ginecologico'
#  'transfusión de hemoderivados' 'infeccion respiratorias'
#  'agitación extrema y pérdida de vía oral' 'administracion hierro i v'
#  'protocolo peg' 'recambi peg' 'deteriro cognitivo' 'broncoaspiración'
#  'bronconeumonia' 'protocolo recambio peg' 'situacion agonica'
#  'osteomielitis' 'descompensacion cardio respiratoria'
#  'infeccion urinaria y-o respiratoria' 'valoracion clinica'
#  'controo dolor cadra' 'administración de hierro'
#  'valoracion nutricion enteral' 'agitacion psicomotriz'
#  'tatamiento antibiotico iv' 'inquietud, sospecha de RAO'
#  'control evolutivo y curas de úlceras' 'Control evolutivo'
#  'administracion antibiotico iv' 'admininistracio de antibiotico iv'
#  'conrol de sintomas' 'intolerancia via oral' 'iyeccion octreotido'
#  'transfusión hematies' 'insuficiencia respiratoria' 'perfusión hierro iv'
#  'Anemia, valorar transfusion' 'ajuste tratamiento analgesico'
#  'oclusion intestinal control de sintomas'
#  'infeccion respiratoria y deterioro estado general'
#  'tratamiento IV en domicilio' 'estudio' 'ulcera inguinal izr grado IV'
#  'dolor abdominal tras paracentesis' 'curas herida quirúrgica'
#  'antibioterapia iv y continuacion cuidados' 'curas úlceras por presión'
#  'infeccion  respiratoria' 'continuación de cuidados'
#  'Aislamiento Estafilococo epidermidis en hemocultivo y Klebsiella en punta de catéter. Administración de Daptomicina iv'
#  'continuación de cuidados. Antibioterapia iv' 'valoración trratamiento.'
#  'valoración UPP' 'continuacion de cuiodados' 'antibioterapia IV'
#  'control y ajuste de tratamiento' 'control danalgesico' 'cambio PEG'
#  'contrl y seguimineto' 'tratamioento antibiotico IV'
#  'mal control analgesico' 'control sintomas y cuidados paliativos'
#  'administracion sandostatin' 'tratamiento de sintomas'
#  'paracentesis evacuadora' 'insuficiencia cardiorespiratoria'
#  'protocolo vidaza y tto sintomatico' 'continuacion de cuidados'
#  'deterioro del estado general' 'infeccion respiratoria'
#  'manejo del dolor' 'tratamiento analgesico' 'control y tratamiento'
#  'disnea' 'administración de Myozime' 'tratamiento antibiotico'
#  'insuficiecia respiratoria' 'situación de final de vida/últimos días'
#  'tto iv' 'lesione ee ii y herida quirúrgica' 'antibiotico iv'
#  'paracentesis y control de sintomas' 'recambio de peg'
#  'disnea y sindrome anemico'
#  'lesiones en eeii, tto antibiotico y sintomatico en general'
#  'control analitico' 'tratamiento sintomas' 'sindrome anemico'
#  'retirada picc' 'trasfusion'
#  'cambio programado de sonda vesical y administración de tto'
#  'antibioterapia intravenosa' 'descompensacion hidropica'
#  'itu, fiebre, perdida via oral' 'colocacion de bomba duodopa'
#  'paracentesis evacuadora, control de sintomas'
#  'preagonía, control de síntomas' 'control analgésico' 'lesiones presión'
#  'lesiones presion' 'solicitud familiar cura paliativa' 'ciatalgia'
#  'Revision' 'hematuria' 'analitica de control' 'fiebre, traqueitis'
#  'sindrome febril' 'antibiotico semanal' 'dolor neuropático'
#  'situacion de agonia' 'rotura de tendones' 'tsindrome anemico'
#  'tratamient intravenoso' 'itu, tto iv' 'tto antibiot iv'
#  'tto iv antibiotico' 'ictus' 'infeccion herida quirurgica'
#  'curas y trao antibiotico' 'trato antibiotico iv'
#  'administración de Vidaza' 'agonia' 'retirada de soporte nutricional'
#  'Alteraciones hidroelectroliticas, intolerancia digestiva y control de sintomas'
#  'infeccio respiratoria' 'valoracion SNG' 'control inquietud e insomnio'
#  'valoracion y tratamiento por encefalopatia' 'control agitacion'
#  'valoracion de dolor e inquietud' 'curas y antibioterapia' 'agitación'
#  'tto diuretico iv' 'tratamiento intravenoso'
#  'cuidados palaitivos avanzados' 'valoracion tratamiento antibiotico'
#  'negativa a la ingesta'
#  'antibioterapia intravenosa,continuación de cuidados'
#  'obstruccion intestinal' 'cambio de sonda vesical' 'evaluacion'
#  'contro de sintomas' 'infeccion respiratoria e insuficiencia cardiaca'
#  'tratamiento antibiotico intravenoso' None 'curas ulcera sacra'
#  'valoración situación clinica' 'curas locales ulceras MMII'
#  'valoración y control de síntomas' 'transfusion y control de síntomas'
#  'control  evolutivo'
#  'antibioterapia iv y continuación de cuidados herida quirúrgica'
#  'valoracion broncoaspiracion' 'valoracion situacion clinica'
#  'trato antibiotico' 'antibioticos+curas' 'valoracio nutricional'
#  'infeccion ulcera presion' 'let' 'ulcera vascular'
#  'infección local y tto iv' 'protocolo iv' 'nauseas y vomitos'
#  'cambio sonda' 'retirada' 'protocolo tto iv' 'tto iv y control sintomas'
#  'protocolo antibiotico semanal' 'protocolo antibioterapico'
#  'administacion myozime' 'administracion zoladex' 'hipercalcemia'
#  'lesion presion infectada' 'control sintomatico y postquirurgico'
#  'celulitis en eeii derecha' 'insomnio rebelde' 'cuidados postquirurgicos'
#  'hiponatremia' 'recambio de peg en protocolo' 'protocolo antibiotico iv'
#  'infeccion urinaria con bacteriemia' 'vigilancia evolutiva'
#  'protocolo farmacologico' 'ditension abdominal' 'contol sintomas'
#  'trto antibiotico' 'protocolo neurologia' 'inf respiratoria'
#  'tratamientoiv' 'tratamiento i v' 'control scfv'
#  'control y tratamiento paliativo' 'cuidados paliativos y paracentesis'
#  'control y cuidados paliativos curas ulceras'
#  'cumplimentar tratamiento antibiotico IV' 'control y seguimiento'
#  'control del dolor' 'aumento de las secrecione'
#  'control evolutivo y ajuste de tratamiento' 'tratamiento IV y control'
#  'protocolo de transfusion' 'vaoracion'
#  'suministro de fármacos de empleo hospitalario'
#  'administracion antibiotico IV' 'control analgesia'
#  'control evolutivo tratamiento antibiotico IV'
#  'control sintomas diureticos' 'tratamiento IV antibiotico'
#  'control sintomas .LET' 'control evolutivo y tratamiento antibiotico IV'
#  'control sintomas dolor mal controlado'
#  'control analgesico y cambio infusor semanal'
#  'cuidados y evolucion. Tratamiento antibiotico IV' 'cuidados palaitivos'
#  'depresion' 'alteracion comportamiento' 'control y curas laparotomia'
#  'ulceras sacras' 'valoracion tumoracion cervical'
#  'tratamiento  antibiotico iv' 'tratamiento  iv'
#  'administracion tratamioento' 'hiperglucemia'
#  'isquemia distal 1-2-5 dedo pie derecho'
#  'administracion tratamiento antibiotico IV' 'coma metabolico'
#  'valoracion oxigenoterapia' 'Fiebre-disnea' 'valoracion tratamiento'
#  'antbioterapia,control de síntomas' 'control evolutivos'
#  'solicitud de valoración por HADo desde la residencia ss As Dores'
#  'metrorragia' 'valoracion y tratamiento' 'control sintomas y tratamiento'
#  'Sellado PIC' 'tratmiento antibiotico' 'control y paracentesis'
#  'control y sintomas' 'trtamiento antibiotico' 'ajuste de tratamiento'
#  'tratamioento antibiotico IV y curas ulceras'
#  'perdida via oral .valoracion' 'control y valoracion paracentesis'
#  'valoracion derrame' 'valoracion por lesiones dermicas' 'antbioterapia'
#  'cambio de PEG' 'control y curas de by pass' 'ajuste tratamiento'
#  'curas tras by pass' 'tratamiento antibiotico y curas'
#  'administración furosemida iv' 'control de sintoms'
#  'infeccion de cateter' 'cura de PICC' 'valoracion transafusion'
#  'tratamiento antibiótico' 'encefalopatia hepatica'
#  'antibioterapia iv, curas' 'analitica de sangre' 's. confusional'
#  'antbioterapia iv' 'control sintomas y tratamiento dolor'
#  'valoracion por edema' 'tratamiento antibiotico y evolucion'
#  'antibioterapia y control evolutivo' 'antibioterapia y curas ulceras'
#  'antibioterapia  IV' 'cntrl de sintomas' 'control sintomas paliativos'
#  'curas ulceras' 'control tras radioterapìa'
#  'cuidados PEG radiologica u control sintomas'
#  'control sintoma en paliativo avanzado'
#  'control sintomas en paliativo avanzado' 'tratamiento antibiótico iv'
#  'control de sintomas, curas ulcera tumoral' 'tratamiento antibiótico IV'
#  'scffv' 'control evolutivo y tratamiento' 'trtamiento antibiotico iv'
#  'demencia avanzada' 'control' 'infeccion boca negativa ingesta'
#  'continuación de cuidados, antibioterapia iv'
#  'control curas y tratamiento analgesico' 'Dispepsi dolor abdominal'
#  'administración aciclovir iv' 'control y tratamiento antibiotico'
#  'curas y tratamiento antibiotico IV' 'anemia,transfusion'
#  'cambio sonda suprapubica' 'curas úlceras' 'tratamiento antbiotico'
#  'evolucion' 'tratatmiento antibiotico'
#  'tratamiento seguril y albúmina iv' 'tratamiento antibiotico  iv'
#  'tratamiento antbiotico iv' 'tratamiento antibiotico oral' 'cura ulcera'
#  'control clinico estreñimiento' 'control y tratamiento de sintomas'
#  'control sintomas y evolutivo' 'S fragilidad intenso'
#  'facilitar medicacion hospitalaria' 'administracion sandostatin lar'
#  'antibioticoterapia' 'tansfusion' 'administracion de inmunoglobulinas'
#  'antibioticos iv' 'ascitis a tension'
#  'Tratamiento antibiotico hospitalario' 'administración de seguril sc'
#  'tratamiento antibiotico hospitalario'
#  'control sintomas. Cuidados paliativos avanzados' 'sindrome general'
#  'Curas . Pulsos de metilprenisolona' 'insuficiencia cardiaca'
#  'ajuste por hipertension' 'sedación final vida'
#  'seguimiento y control analítico' 'ajuste analgésico'
#  'trat ALPROSTADIL IV' 'control analítico'
#  'antibioterapia iv y control de síntomas' 'antiobioterpia IV'
#  'antibioterapia IV y curas' 'obstruccion sonda urinaria'
#  'antibioterapia  colangitis' 'valoracion seguimiento'
#  'administracion inmunoglobulinas' 'control y antibioterapia IV'
#  'encefalopatia' 'couidados paliativos' 'tratamiento antibiotico neumonia'
#  'control sintomas cuidados paliativos' 'vomitos' 'Infección urinaria'
#  'control evolutivo, Paracentesis' 'antibioticoterapia iv' 'SCFV'
#  'antibioterapia  iv' 'tratamiento antibioitico iv' 'disfagia'
#  'ctratamiento antibiotico IV' 'curas y tratamiento'
#  'control evolutivo y curas' 'cvaloracion encefalopatia'
#  'administracion ganmaglobulinas' 'adminiostracion duodopa'
#  'dolor cervical' 'control lesion mandibula' 'valoracion peg'
#  'perdida via oral' 'tratamiento encefalopatia' 'paracentesis periodicas'
#  'tratamiento antibiotio IV' 'antibioterapia u sueroterapia IV'
#  'control ulceras y tratamiento antibiotico IV'
#  'tratamiento y control evolutivo'
#  'infeccion urinaria tratamiento antibiotico' 'curas  y control evolutivo'
#  'tratmiento antibiotico y control evolutivo'
#  'curas amputacion dos dedos pie' 'dolor en columna lumbar' 'rectorragia'
#  'valoracion dolor' 'prostatectomia endoscopica'
#  'posible infeccion urinaria' 'curas lesion tumoral'
#  'habituacion domicilio' 'cuidados  paliativos' 'administracion calcio IV'
#  'Dolor lumbar' 'rehidratación IR prerrenal'
#  'co0ntrol evolutivo y paracentesis periodicas.' 'tratamiento paliativo'
#  'urocultivo de control' 'deterioro general' 'dolor a nivel lumbar'
#  'cuidados de final vida' 'ajuste de tratamientyo'
#  'valoracion por estupor' 'valracion de tratamiento por vahidos'
#  'tratamiento antibioptico IV' 'control dolor abdominal'
#  'trasfusion hematies' 'tratamiento y curas' 'contol de sintomas'
#  'control sde síntomas' 'cuidadosm paliativos' 'contrl y trtatamiento'
#  'uirurgica' 'antibioterapia IV y curas c¡quirurgicas'
#  'antibioterapia iv, curas locales' 'recambio de PEG'
#  'adiestramiento nutricion y control sintomas'
#  'curas de ulcera y contrl evolutivo' 'valoracion y dolor oidos'
#  'incarceracion hernia' 'valrar encefalopatia' 'control de sintpmas'
#  'tratamiento iv Alprostadil' 'encefalopatía' 'insomnio'
#  'Amd. de Inmunoglobulinas' 'sugiran iv' 'vigilancia postoperatorio'
#  'contrl de sintomas' 'control s de síntomas' 'antibioterapia sc'
#  'furosemida iv' 'contrlol de sintomas' 'antibioterapia  sc'
#  'control envolutivo y trtatamiento'
#  'tratamiento antibiotico y control evolitivo' 'control curas'
#  'control sintomatico y tratamioento paliativo'
#  'control y curas de ulceras' 'control analgesico y curas'
#  'cvaloracion dolor y fiebre'
#  'control y cumplimentacion tratamiento antibiotico'
#  'valoracion y diahgnostico' 'valoracion por disfagia' 'LET'
#  'valoracion por deterioro general' 'valoracion y cuidados paliativos'
#  'administracion tratamiento antibiotico' 'convulsiones scffv'
#  'administración alprostadil iv' 'control evolutiva'
#  'antibioterapia iv,control de síntomas' 'dolor rebelde'
#  'control simtomas' 'neumonia tratamiento IV' 'Tratamiento antibiotico IV'
#  'diureticos IV' 'taramiento qantibiotico IV' 'Tratamiento antibiótico IV'
#  'furosemida IV' 'furosemida sc' 'tratamieto furosemida iv'
#  'curas ulcera vascular MMII izquierdo' 'antibiotico' 'tantibioterapia IV'
#  'recambio PEG a boton de alimentacion' 'administracion de Azacitidina'
#  'Administracion 5 Azatadina'
#  'control sintomas y paracentesis evacuadorasa'
#  'curas celulitis EEII izquieda' 'control evolutivo y ulceras sacras'
#  'cuidados paliativos avanzados' 'paracentesis evacuadoras periodicas'
#  'antibioterapia IV por hemocultivos positivos'
#  'recambio canula traqueostomia' 'ulcera sacra'
#  'control sintomas diureticos IV infusor'
#  'deterioro enfermedad Nieman Pick' 'valoracion ulcera sacra sangrante'
#  'valoracion ulceras de decubito' 'valoracion ulcera sacra'
#  'cambio canula traqueostomia' 'deterioro estado general'
#  'Valoración en domicilio' 'cambios canula traqueostomia'
#  'control en domicilio portador VMI nocturna' 'control por ITU' 'covid'
#  'paracentesis y control sintomas' 'cuidados pañiativos'
#  'tratamiento furosemida IV' 'curas úlcera'
#  'transfusión,control de síntomas' 'valoración y tratamiento'
#  'tratamiento furosemida sc' 'valoración y tto' 'control de sítomas'
#  'tratamiento y control de síntomas' 'cambio cánula traqueotomía'
#  'antibioterapia IV,control de síntomas' 'control clínico' 'eccema'
#  'final de vida' 'antifúngico iv' 'antibiotico iv, curas by-pass'
#  'recambio pca' 'antibiotico Iv' 'Furosemida IV' 'tratamiento alprostadil'
#  'tratamiento 5AZA' 'hierro IV' 'tratamiento diurético' 'nutrición'
#  'inmunoglobulinas' 'antibioterapia VO' 'tratamiento inmunoglobulinas'
#  'tratamiento con inmunoglobulinas' 'Paracentesis' 'Disfagia' 'Disnea'
#  'tratamiento diurético iv' 'curas ulcera brazo derecho'
#  'curas gastrostomia y antibioterapia' 'ncontrol evolutivo y tratamiento'
#  'Control evolutivo y cuidados paliativos'
#  'administracion de tratamiento antibiotico IV' 'PARACENTESIS EVACUADORA'
#  'tratmiento antibiortico IV' 'CONTROL SINTOMAS'
#  'recambio botan de alimentacion'
#  'curas de amputacion 3er dedo pie izquierdo'
#  'curas de hematoma en dorso mano' 'oxigenoterapia' 'diuréticos'
#  'paracentesis periodica' 'tratamiento antibioticom IV'
#  'control sintomas y tratamiento IV'
#  'control de sintomas y tratamiento iv'
#  'control sintomas y ajuste de tratamiento'
#  'deterioro progresivo y descontrol glucemico'
#  'evaluacion de ulceras en EEII' 'tratamiento antiibiotico IV'
#  'valracion y ajuste de tratamiento' 'negativa ingesta oral'
#  'valoración disnea' 'tratamiento.']
# ==================================================================
# paliativo_onc/noc
# 8 ['si' 'no' None 'mo' 'nsi' 'o' 'so' 'm']
# ==================================================================
# paliativo_no_onc/noc
# 7 ['si' 'no' None 'ns' 'o' 'nsi' 'm']
# ==================================================================
# fiebre
# 8 ['no' 'si' 'b' 'ni' 'nsi' 'ssi' None 'nop']
# ==================================================================
# disnea
# 4 ['no' 'si' None 'nsi']
# ==================================================================
# dolor
# 4 ['si' 'no' 'ni' 'nsi']
# ==================================================================
# delirium
# 6 ['no' 'si' 'nsi' None 'mo' 'son']
# ==================================================================
# otros_1
# 186 ['no' 'estreñimiento' 'mucositis' 'hematuria' 'nauseas y vómitos'
#  'oligoanuria,ITU' 'infeccion respiratoria' 'tos' 'si, hipotensión'
#  'si, vómitos' 'edemas, oliguria' 'candidiasis orof.' 'agitacion'
#  'vómitos fecaloideos' 'itu' 'exudación herida' 'anemia'
#  'si, diarrea, mareo' 'sangrado' 'diarrea' 'edema lengua' 'ITU'
#  '0clusión intestinal' 'insuficiencia respiratoria' 'si,nauseas y vomitos'
#  'vómitos' 'muguet' 'si,vomitos,hematemesis' 'insomnio' 'mialgias' 'hipo'
#  'dolor abdominal' 'inquietud psicomotriz' 'hipotension' 'nauseas'
#  'deterioro cognitivo' 'abdomen agudo' 'ictericia' 'retencion urinaria'
#  'si,retencion urinaria' 'agitacion,panico' 'obstruccion intestinal'
#  'coma profundo' 'comatosa' 'tiritona y fiebre' 'vomitos'
#  'nauseas,vómitos, edema m.inf' 'disfagia' 'inquietud'
#  'nauseas, vómitos, inquietud' 'nauseas y vomitos' 'candidiasis oral'
#  'dolor epigastrico' 'disuria y polaquiuria' 'nauseas y diarrea'
#  'infeccion respi.Descompensacion cardiaca' 'metrorragias'
#  'tos y expectoración' 'hematuria y gingivorragias' 'agresividad'
#  'sde miccional' 'si, estreñimiento' 'si, vomitos' 'si, edemas' 'coma'
#  'si, disuria' 'si, impotencia funcional' 'tos cronica refractaria'
#  'si, anasarca' 'diarrea,deshidratacion' 'si, ictericia' 'sed'
#  'perdida d ela via oral' 'intolerancia oral'
#  'estreñimiento, pacto de silencio' 'si, crisis parciales'
#  'dificultad ingesta oral' 'deterioro funcional'
#  'perdida de la via oral, sed' 'sd confusional' 'angustia' 'vomito'
#  'ascitis' 'ACV previo' 'pérdida de peso' 'palidez' 'nauseas,vómitos'
#  'expectoración' 'expect hemoptoica' 'edema m.inferiores'
#  'pus a traves de drenaje percutáneo' 'Ansiedad-insomnio'
#  'ulceras presion' 'inquietud y agitacion' 'infeccion de PIC'
#  'ulceras de presion' 'mareo' 'ni' 'n o' 'derrame pleural'
#  'negativa a la ingesta' 'incontinencia urinaria' 'candidiasis' 'estupor'
#  None 'diabetes' 'ca gastrico' 'perdida de la vía oral'
#  'mal manejo de secreciones, diarrea'
#  'encefalopatia, ascitis, insuficiencia renal' 'rotura de peg'
#  'estreñimiento, ascitis' 'náuseas y vómitos' 'inquietud /insomnio s'
#  'vejiga neurogena. Hipersalivacion.' 'hemiparesia' 'icc'
#  'animo depresivo' 'úlcera tumoral' 'hematemesis'
#  'dispepsia por metronidazol oral' 'esclerosis m.' 'demencia'
#  'fractura de cadera  si' 'agitación' 'somnolencia' 'depresion reactiva'
#  'nauseas, vómitos' 'Tos,expectoración purulenta'
#  'deterior del nivel de consciencia' 'anuria' 'ICC' 'sangrado local'
#  'perdida de via oral' 'edemas' 'hematoma en costado derecho'
#  'inquietud /insomnio' 'HDB, encefalopatia' 's.confusional'
#  'bajo nivel conciencia' 'melenas' 'deterioro estado general,melenas'
#  'agonia' 'ansiedad' 'secreciones bronquiales' 'fallo cardiaco'
#  'mareos y vómitos' 'infeccion urinaria' 'ulceras vasculares'
#  'pancreatitis aguda' 'shock cardiogenico' 'espondilodiscitis' 'ca colon'
#  's. confusional' 'ulceras' 'ascitis,ictericia' 'prurito local'
#  'agitacioón,diarrea' 'vomitos,estreñimiento' 'edema m.inf'
#  'secreciones bronquiales y agitación' 'hipo,ansiedad' 'tos improductiva'
#  'nauseas, ictericia' 'sangre en heces' 'declive severo'
#  'tos,expectoración' 'Demencia' 'HTA' 'insomnio,' 'ulcera presion' 'si'
#  'lesion quirurgica extensa' 'Dolo roseo' 'dispepsia' 'nauseas vomitos'
#  'temblor y escalofrios' 'Vomitos , diarrea' 'hipercalcemia' 'nol'
#  'broncoaspiracion' 'isquemia pie' 'globo vesical' 'dolor' 'hiperglucemia'
#  nan]
# ==================================================================
# p_terminal
# 5 ['si' 'no' 'nn' None nan]
# ==================================================================
# agonia
# 6 ['no' 'si' 'o' None 'son' nan]
# ==================================================================
# ps/ecog
# 20 [4.0 '3-4' 1.0 'no' '1-2' 2.0 3.0 0.0 '2-3' 'si' 'nk' None 7.0 'np' 100.0
#  '<70' '4<10' 'o' 'N2-3' 'nop']
# ==================================================================
# barthel
# 48 [30.0 'no' 40.0 90.0 50.0 60.0 '<60' 80.0 '<10' '<20' 70.0 99.0 100.0
#  '<40' '<50' '<30' 20.0 '<70' '<80' '40-50' 95.0 '<95' 'N<20' 'N<80'
#  '30-40' '<90' '50-60' '>20' 10.0 '<0' 65.0 '<99' '<120' '<100' 0.0 '<45'
#  None 'z30' '>60' '<35' 98.0 4.0 '<450' '>90' 25.0 85.0 35.0 45.0]
# ==================================================================
# gds/fast
# 25 ['no' 7.0 6.0 5.0 '7c' 4.0 '6-7' 3.0 2.0 '4-5' '3-4' 1.0 'n0' 'si' '5-6'
#  '7a' '<20' 'o' 'n5' 'Si 5' 'Si 4' 'si4' 'si6' 'si7' 'b']
# ==================================================================
# eva_ing
# 15 ['no' 7.0 8.0 6.0 3.0 9.0 10.0 5.0 4.0 '7-8' 2.0 0.0 None '2-3' nan]
# ==================================================================
# otros_2
# 56 ['no' 'ulcera sacra' 'edemas' 'CHILD A' 'gold IV' None 'nauseas'
#  'pap score c' 'pap score a' 'pap score b' 'pap score grupo c' 'child a'
#  'sospecha de rao' 'agitación'
#  'hipertiroidismo, hiperglucemia, infección respiratoria' 'hematuria'
#  'epistaxis' 'problema social grave'
#  'insuficiencia cardiaca descompensanda resistente al tto diuretico'
#  'ca mama' 'claudicación familiar' 'Karnofsky 30' 's. confusional'
#  'colangitis' 'tetraparesia' 'fistula recto vesical' 'itu'
#  'ulceras de presion' 'IRC' 'ascitis' 'ansiedad' 'dialisis, Parkison'
#  'ira' 'esquizofrenia' 'sindrome ansiosodepresivo' 'obesidad' 'ELA' 'lno'
#  'toc' 'negativa ingesta' 'crisis de ansiedad' 'melenas' 'coma'
#  'sospecha de itu y ausencia de garantia de cuidador' 'diarrea'
#  'oclusion intestinal' 'disnea' 'NO' 'tromboflebitis' 'insomnio'
#  'agitacion' 'derrame pleural' 'estreñimiento' 'vomitos' 'mucositis' nan]
# ==================================================================
# otros/complicaciones
# 439 ['reingreso en urgencias' 'met. pulmonares y digest' 'no'
#  'claud familiar domicilio' 'si, muguet, vómito, cefalea' 'fallo cardiaco'
#  'si, oliguria, fiebre' 'si, disuria' 'si, dolor hombro' 'si, agitación'
#  'si oclusion intestinal' 'si,infeccion osteosintesis'
#  'hematoma pared toracica' 'si, sepsis urinaria' 'broncoaspiracion'
#  'colitis pseudomebranosa' 'si, colestasis disociada'
#  'si, retención urinaria' 'asistolia' 'sd confusional'
#  'si,deterioro brusco,claudicación' 'si,claudicacion' 'rectorragias'
#  'infeccion local' 'si,deterioro brusco' 'delirium' 'vomitos'
#  'si,sangrado digestivo,itu' 'si,acv' 'infecc respiratoria'
#  'fractura isquiopubiana' 'si,oclusión' 'inf respiratoria' 'si,vomitos'
#  'oclusión intestinal' 'infeccion respiratoria' 'secundarismo opiaceo'
#  'ulceras de presion' 'si,infeccion urinaria' 'si,disnea subita'
#  'agitacion.' 'reingreso por hemocultivos +' 'diarrea' 'si,rectorragias'
#  'paciente en seguimiento por foltra' 'realizacion cpre en este ingreso'
#  'descompensación y reingreso' 'edema agudo de pulmon'
#  'si,insuficiencia respiratoria' 'reingreso programado para cpre'
#  'hematemesis' 'parada cardiaca exitus'
#  'insuficiencia renal,infeccion urinaria' 'si,infeccion'
#  'Ictus isquémico transitorio' 'hiperglucemia' 'probable infarto' 'ITU'
#  'hepatitis medicamentosa' 'si,isquemia intestinal'
#  'obtruccion intestinal' 'insuficiencia respiratoria' 'anemia'
#  'edema labio supy parestesias orales' 'retencion urinaria' 'HTA'
#  'debilidad muscular' 'deterioro de su situación clínica'
#  'si, rectorragia' 'si, perdida de via oral' 'si, fiebre' 'si, delirium'
#  'si, caida' 'Obstrucción intestinal' 'micosis oral'
#  'si, dolor dorsal, infeccion respiratorias' 'si, oclusion intestinal'
#  'candidiasis orofingea' 'perdida via oral' 'hiperglucemias'
#  'candidiasis orofaringea' 'si, tvp' 'si, alucinosis'
#  'si, artritis por microcristales' 'si, HTA'
#  'si, confusion, hiponatremia, HDA' 'si, retencion urinaria'
#  'si, epigastralgia' 'si, muguet' 'si, fallo cardiaco' 'reingresa en UPAL'
#  'si dolor abdominal' 'si, diarrea y fiebre' 'deseo reingreso'
#  'si, herida incisocontusa parietal' 'si, extravasación en brazo'
#  'neumotorax, oclusión intestinal' 'rao, sonda vesical'
#  'claudicación familiar' 'fuera de área' 'si, oliguria'
#  'reingreso en centro privado' 'fistula entero-vesical, fracaso familiar'
#  'vómitos fecaloideos' 'vomitos fecaloideos' 'protocolo de desconexión'
#  'si, mal control de dolor'
#  'si, muguet, diverticulitis, retencion urinaria'
#  'fracaso familiar en domicilio' 'si, infeccion urinaria, rectorragia'
#  'claudicacion familiar'
#  'diarrea sanguinolenta, dificultad para la via oral'
#  'no desean sonda vesical' 'empeoramiento respiratorio' 'agonia'
#  'angustia, pérdida de la via oral' 'disnea, claudicacion familiar'
#  'si, muguet, infeccion respiratoria' 'probable tromboembolismo pulmonar'
#  'sepsis' 'infeccion respiratoria, IC' 'claudicacion'
#  'intolerancia alimentaria tras realización recambio peg'
#  'ulceras por presión' 'ictericia obstructiva'
#  'reingreso por claudicacion familiar'
#  'posible infeccion respiratoria, infec urinaria' 'TVP' 'esofagitis'
#  'obstrucción intestinal' 'ictus' 'suboclusión intestinal'
#  'evolución tórpida de las lesiones cutáneas'
#  'infeccion respiratoria/infección cutánea' 'pérdida vía oral'
#  'TVP. Infección pimer dedo pié izq' 'HDA' 'si,disnea' 'dispepsia'
#  'infección respitaria, descompensación cardíaca, posible crisis comicial, sobredosificación dicumarínica, hematoespermia'
#  'TA elevadas' 'si,dolor abdominal' 'si proceso infeccioso central'
#  'si derrame pleural' 'desaturacion' 'infeccion ulceras presion'
#  'fallece antes de ser atendida' 'alergia aminoglucosidos'
#  'facies corticoidea' 'disnea brusca' 'disna refractaria'
#  'vómitos y disnea' 'si, sepsis, mal control del dolor'
#  'intervención de presentacion y cortesia'
#  'deterioro del estado general brusco'
#  'ausencia de cuidador por limitación. Intervenció social'
#  'insuficiencia renal' 'si, insuficiencia respiratoria'
#  'si, dolor en piernas, rash cutaneo' 'Obnubilación,estupor, éxitus'
#  'no visto por hado tras ingreso en fin de semana' 'tendinitis'
#  'si, infeccion respiratoria' 'oclusion intestinal'
#  'imposibilidad para realizar paracentesis' 'dificultad via oral'
#  'hipotensión' 'perdida de la via iv' 'imposibilidad para la parecentesis'
#  'ventilacion mecanica no invasiva'
#  'lesiones cutáneas tumorales en progresión extrema' 'si, sepsis grave'
#  'lesiones presión y vasculares' 'lesiones presion' 'anemizacion'
#  'isquemia arterial eeii' 'dispepsia por metronidazol oral'
#  'negativa a la ingesta' 'fiebre' 'isquemia cerebral transitoria'
#  'disnea durante fin de semana' 'artritis, celulitis, vomitos'
#  'via venosa complicada' 'si, claudicacion'
#  'deterioro del nivel de consciencia' 'transfusion' 'icc'
#  'dolor musculoesquelético' 'pancitopenia, ifec respirat' 'diarrea aguda'
#  'disnea' 'vomitos, intolerancia oral' 'ITU, RAO'
#  'angustia, disnea, secreciones' 'si,broncoaspiración'
#  'si,fracaso colaboracion con hado' 'dolor mal controlado'
#  'si, claudicación familiar' 'si,claudicacion familiar' 'agitación' 'itu'
#  'si, disnea' 'encefalopatia uremica' 'si, dolor'
#  'si, ascitis, HDB, PBE, encefalopatia' 'sindrome confusional'
#  's.confusional' 'si, insomnio, desgarro uretral insuficiencia renal'
#  'obstruccion intestinal' 'RAO, dificultad respiratoria' 'ICC'
#  'sde vena cava sup' 'insuf.renal prerrenal'
#  'absceso pélvico,fístula intestinal,sde compartimental muslo dcho'
#  'encefalopatia hepática'
#  'Fiebre, secreciones respiratorias, bajo nivel del consciencia'
#  'Fiebre, infección urinaria' 'inquietud'
#  'pancitopenia, sangrado digestivo' 'alteración enzimas hepáticas'
#  'pancreatitis aguda' 'fiebre y diarrea' 'mucositis' 'absceso facial'
#  'hematuria' 'paraparesia' 'sindrome febril' 'prostatitis' 'ira'
#  'retención urinaria' 'encefalopatía hepática' 'descompensación diabética'
#  'traumatismo costal izq en su domicilio' 'TVP, hematuria postsondaje'
#  'tromboflebitis en territorio safena int izq o colaterales'
#  'posible insuf vertebrobasilar' 'dolor y distensión abdominal'
#  'abdomen agudo' 'Hipopotasemia, Sobreefecto Sintrom'
#  'descompensación glucémica' 'Fiebre y taquipnea'
#  'sospecha de compresión medular'
#  'probable broncoaspiración, insuf respiratoria' 'si,caida'
#  'Sobredosificación ACO' 'fracaso familiar'
#  'infecciones ulceras con celulitis reiteradas'
#  'evolución tórpida de lesión' 'Deseo de finalización en hospital' 'si'
#  'dificil colaboracion' 'neutropenia febril' 'melenas y hematoquecia'
#  'reingreso por deterioro severo del estado general'
#  'cuidadora única situaciónultimosdias'
#  'reingreso por presunta reaccion alergica'
#  'mesotelioma en pieza operatoria'
#  'sindrome depresivo con manifestaciones psicoticas' 'mno'
#  'no se dispone del antibiotico iv' 'lesion ulcerosa compleja y extensa'
#  'candidiasis' None 'celulitis' 'insomnio' 'dolor abdominal'
#  'oclusion intestinal.claudicacion' 'hematemesis edema agudo de pulmon'
#  'fuera de area' 'tvp' 'rectorragia' 'traslado a UPAL'
#  'insuficiencia resp aguda' 'persiste insuficiencia cardiaca'
#  'si: sobredosificacion opioides' 'DM' 'sincope' 'nuseas' 'vertigo'
#  'herpes zoster' 'perdida via oral. Final vida' 'edemas'
#  'fractura patologica' 'persistencia sindrome febril' 'hipo refractario'
#  'oclusion intestinal. Vómitos fecaloideos' 'mo' 'agitacion psicomotriz'
#  'colangitis' 'infeccion pulmonar' 'sde confusional, crisis comiciales?'
#  'miocardiopatía dilatada, I renal crónica' 'fin de cuidados'
#  'uropatía obstruvtiva,hipertrofia de próstata,Fa revertida farmacologicamente'
#  'cura de ulcera' 'edema generalizado' 'nauseas y vómitos'
#  'absceso pared abdominal' 'nauseas' 'HTA,Diabetes, Psicopatia'
#  'PEG radiológica' 'vómitos' 'hematuria, disuria' 'gingivorragia'
#  'convulsiones por acv' 'candidiasis oral'
#  'diarrea,estreñimiento,diabetes' 'fistula liquidocefalorraquidio'
#  'disfagia absoluta' 'coma' 'dolor neuropático' 'hematuria.cancer vejiga.'
#  'si,broncoaspiracion' 'persistencia infección' 'si.infeccion urinaria'
#  'gota, Insuf renal ag' 'si,nauseas y vomitos.estreñimiento'
#  'si,parada cardiorrespiratoria' 'deterioro clinico' 'inquietud,insomnio'
#  'ulcera pierna dcha' 'crisis epileptica' 'plaquetopenia'
#  'infecciones urinarias' 'colitis ulcerosa, hipo' 'problema social'
#  'I. cardíaca, I.renal cr' 'si,rectorragia'
#  'probable broncoaspiración,diarrea' 'ulceras' 'diabetes' 'si,agitacion'
#  'Bypass axilo monofemoral desde arteria axilar izquierda (1ªporción) (L-T) hasta arteria femoral profunda izquierda (T-L) miembro inferior izquierdo'
#  'pirosis' 'nauseas,vómitos' 'cardiopatia hipertensiva, FA' 'curas'
#  'hemorragia gingival' 'neumonia' 'si,infeccion respiratoria'
#  'curas lesión tumoral abdominal' 'si,covid sintomático' 'acv'
#  'trast. Personalidad' 'si,infecciones urinarias' 'estenosis gástrica'
#  'COVID' 'infeccion' 'ulcera venosa' 'infección covid resuelta'
#  'infeccion ulceras' 'sde miccional' 'diarrea cd'
#  'sangrado lesiones cutáneas'
#  'insuficiencia renal, hidronefrosis bilateral' 'hemorragia digestiva'
#  'hiponatremia' 'hiperosmolaridad' 'broncoaspiraciones'
#  'si,nauseas y vomitos' 'esclerosis multiple' 'prurito'
#  'secreciones broncoaspiraciones' 'si,hemorragia digestiva alta'
#  'si infeccion orina' 'hemoptisis' 'negativa a ingesta'
#  'Sde confusional, convulsiones' 'Encefalopatía, Ascitis' 'astenia'
#  'recambio peg' 'ulceras vasculares' 'disminucion del nivel de conciencia'
#  'infeccion herida quirugica' 'reingreso por paracentesis hemorragica'
#  'si,sepsis respiratoria' 'si encefalopatia'
#  'claudicacion familiar (conviviente covid positivo' 'fractura de cadera'
#  'celilitis' 'crisis convulsivas' 'Hiperglucemia-ICC' 'ansiedad'
#  'candidiasis orofaringe' 'Sd. confusional' 'dolor precordia'
#  'S. confusional' 'ileo paralitico' 'sincope ,insuficiencia cardiaca'
#  'infeccion. Dolor' 'curas herida quirurgica' 'ucera de presión'
#  'dolor precordial' 'si,infección urinaria' 'infeccion orina'
#  'itu, s. confusional' 'si, infeccion urinaria' 'neumonía por aspiración'
#  'disnea y estertores' 'si,fallo multiorganico' 'agitación e insomnio'
#  'FA, miocardiopatía dilatada' 'descompensacion cardiaca'
#  'elevación de transaminasas' 'infección pulmonar'
#  'uropatia obstructiva,anemia.' 'fractura de D12'
#  'dolor MII de probable origen neuropatico'
#  'vómitos, probables emb pulmonares' 'TEP' 'somnolencia/agitación'
#  'infección urinaria' 'sepsis por cateter' 'ascitis no a tensión'
#  'ulcera sacra' 'flebitis' 'disfagia' 'curas de ulceras'
#  'sde confusional, UPP' 'posible toxicidad hepática por ceftriaxona'
#  'fistula rectouretral' 'HTA, diabetes mellitus' 'Diarrea'
#  'dipepsia,alteración emocional' 'mal control del dolor'
#  'epigastralgia y disnea a estudio' 'deterioro cognitivo' 'mareos'
#  'miembro fantasma' 'dialisis tres dias semana'
#  'adenocarcinoma pancreas estadio iv' 'espina bifida' 'trasplante renal'
#  'convulsiones' 'insuficiencia cardiaca'
#  'hernia inguinal dcha incarcerada' 'paralisis supranuclear'
#  'Abdomen agudo,neumonia' nan]
# ==================================================================
# n_estancias
# 130 [2.100000e+01 2.400000e+01 1.400000e+01 1.000000e+00 2.000000e+00
#  1.300000e+01 2.200000e+01 5.000000e+00 9.000000e+00 3.000000e+00
#  1.030000e+02 6.000000e+00 6.900000e+01 3.300000e+01 1.800000e+01
#  4.000000e+00 8.000000e+00 1.000000e+01 2.300000e+01 1.500000e+01
#  1.100000e+01 2.000000e+01 9.200000e+01 4.900000e+01 3.000000e+01
#  3.500000e+01 7.000000e+00 1.600000e+01 9.800000e+01 4.500000e+01
#  4.100000e+01 9.600000e+01 1.000000e+02 3.600000e+01 4.700000e+01
#  4.000000e+01 2.600000e+01 3.200000e+01 2.800000e+01 2.700000e+01
#  3.400000e+01 4.600000e+01 1.200000e+01 1.900000e+01 2.500000e+01
#  5.000000e+01 8.700000e+01 4.200000e+01 1.700000e+01 3.100000e+01
#  6.700000e+01 6.800000e+01 1.410000e+02 4.800000e+01 2.900000e+01
#  5.100000e+01 3.900000e+01 5.500000e+01 3.700000e+01 5.600000e+01
#  0.000000e+00 7.100000e+01 5.800000e+01 7.400000e+01 3.800000e+01
#  7.200000e+01 4.300000e+01 7.300000e+01 9.900000e+01 6.300000e+01
#  6.400000e+01 3.040000e+02 5.400000e+01 7.500000e+01 1.800000e+02
#  5.300000e+01 7.800000e+01 8.400000e+01 1.350000e+02 5.700000e+01
#  7.600000e+01 1.060000e+02 8.600000e+01 6.000000e+01 7.900000e+01
#  4.400000e+01 1.040000e+02 7.000000e+01 5.200000e+01 1.110000e+02
#  6.500000e+01 7.700000e+01 6.100000e+01 6.600000e+01 9.000000e+01
#  1.400000e+02 1.300000e+02 1.190000e+02 1.260000e+02 1.610000e+02
#  6.200000e+01 9.300000e+01 8.900000e+01 2.040000e+02 9.100000e+01
#  9.500000e+01 1.020000e+02 9.700000e+01 1.310000e+02 1.500000e+02
#  8.800000e+01 1.340000e+02 1.420000e+02          nan 1.090000e+02
#  1.230000e+02 1.380000e+02 1.070000e+02 8.000000e+01 1.660000e+02
#  1.330000e+02 5.900000e+01 1.540000e+02 1.880000e+02 1.250000e+02
#  1.010000e+02 2.793914e+06 1.170000e+02 1.180000e+02 1.710000e+02]
# ==================================================================
# n_visitas
# 59 [10.  8.  6.  1.  2.  5.  3. 21. 31. 15.  7.  4. 40. 14. 12. 18. 35.  9.
#  11. 20. 37. 34. 16. 17. 23. 24. 22. 45. 48.  0. 13. 33. 28. nan 25. 60.
#  27. 26. 19. 30. 50. 36. 43. 29. 56. 51. 41. 42. 32. 54. 71. 76. 49. 68.
#  38. 39. 99. 80. 44.]
# ==================================================================
# sedacion
# 39 ['no' 'si' 'si, morfina, haloperidol, midazolam'
#  'si, midazolam, morfina, buscapina'
#  'si, levomepromazina, midazolam, buscapina, morfina'
#  'si, buscapina, morfina' 'si, morfina, buscapina'
#  'si,midazolam,morfina,buscapina' 'si, buscap,midaz,morf'
#  'si,mid,morf,buscap' 'si, midazolam' 'si,midazolan,morh,haloperidol'
#  'si, buscap,midaz,morf,haloperidol' 'si,buscap,halop,sinogan,morf,midaz'
#  'si,busc,mid,morf,halop'
#  'si, morfina, levomepromazina, midazolam, buscapina'
#  'si, buscapina, midazolam, morfina y haloperidol'
#  'si, midazolam, haloperidol, buscapina, morfina' 'si, midaz,morf,buscap'
#  'morf,busc,halop' 'si. midazolan' 'si.morf,buscap,midaz'
#  'si, levomepromazina, midazolam, morfina,'
#  'si, buscap, midazolam, morfina,' 'np' 'si,midazolam, morfina, buscapina'
#  'si, buscap, midazolam, morfina,sinogan'
#  'si, buscap, midazolam, haloperidol,morfina,' None
#  'si,buscap,sonogan,cl mórf,midaz' 0.0 'si,buscap,midazolam,morfina,'
#  'si,midz,morf,haloperidol,buscap' 'si, buscap, midazolam,morfina,'
#  'si,cl.mórfico,midazolam' 'si,morf+buscap+haloperidol+midaz'
#  'si,morf+buscapmidaz' 'si,morf+buscap+midaz' 'NO']
# ==================================================================
# motivo_alta
# 115 ['reingreso' 'exitus' 'fin de cuidados' 'reingreso por urgencias a hado'
#  'traslado otro centro' 'traslado a upal' 'traslado a urgencias'
#  'ingreso en digestivo clínico' 'ingreso para trasplante' 'reingreso orl'
#  'traslado a cpl' 'éxitus' 'traslado a oncologia' 'reingreso upal'
#  'trasladoa upal' 'traslado a acv' 'ingreso NML clinico'
#  'petición de la familia de posponer tto' 'traslado a pasliativos'
#  'ingreso en NRL' 'ingreso UPAL' 'ingreso upal' 'traslado upal'
#  'reingreso en UPAL' 'residencia sociosanitaria' 'reingreso hospitalario'
#  'reingreso en centro privado' 'tralado' 'trasado a urgencias clínico'
#  'reingreso en upal' 'buen control de síntomas'
#  'traslado urgencias Clinico' 'traslado UPAL' 'Traslado a UPAL'
#  'Ingreso en Oncología' 'traslado a UPAL' 'ingreso en NRC' None
#  'fin cuidados' 'paso a urgencias' 'Unidad de Algias musculoesqueléticas'
#  'fin de  cuidados' 'reingreso en onc' 'traslado a urgencias del clinico'
#  'sin condiciones para seguimiento hado' 'solicitud familiar'
#  'reingres en upal' 'reingreso.' 'reingreso en neumologia'
#  'cambio de domicilio fuera de área asistencial de HADO'
#  'urg e ingreso upal' 'estable en su enfermedad'
#  'traslado a H.Gil Casares' 'ingreso en UPAL'
#  'imposibilidad de cuidados en domicilio del paciente por condiciones higienoco-sanitarias inadecuadas'
#  'Traslado a Hospital privado de agudos por decisión familiar'
#  'no fue dado de alta hospitalaria' 'traslado a Urgencias Clínico'
#  'traslado a URG Clínico' 'ingreso en HUAC para transplante pulmonar'
#  'Traslado a URG del Clínico' 'traslado urgencias'
#  'Traslado a C. Paliativos HG Casares' 'Ingreso en UPAL'
#  'reingreso programado en acv' 'reingreso en urgencias'
#  'reingreso en oncologia' 'claudicacion familiar' 'reingresoupal'
#  'fin de cuidadso' 'traslado MIR provincial' 'consulta médica'
#  'ingreso en Digestivo' 'ingreso en oncologia'
#  'exitus comunicado por la familia' 'traslado cirugia'
#  'alta paso a urgencias' 'traslado a Urgencias'
#  'traslado a urgencias tetraparesia'
#  'traslado a Urgencias e ingreso en UPAL'
#  'traslado a Urgencias, petición familiar' 'urgencias clinico'
#  'ingreso en MIR' 'ingreso en C.Plástica' 'traslado a Orl' 'ingreso MIR'
#  'tto en RTP' 'reingreso programado' 'reingreso UPAL' 'paso a uregencias'
#  'trasladoa urgencias' 'cuidados AP' 'reingreso en MIR' 'domicilio'
#  'ingreso en oncología' 'Ingreso en C.Vascular' 'no' 'derivado urgencias'
#  'Ingreso CGD' 'Traslado a Urgencias' 'alta por paso a urgencias'
#  'traslado a urgencias por COVID' 'alta por paso a uregncias'
#  'Traslado a Urgencias por el 061' 'Ingreso en ORL'
#  'Traslado a Urgencias para ingreso MIR' 'ingreso Medicina Interna'
#  'ingreso en UTR' 'alta paso por urgencias' 'ingreso en ORL'
#  'ingreso en Medicina Interna' 'Traslado a urgencias.'
#  'reingreso hospital privado' 'ingreso Cirugía vascular' 'ingreso Onco']
# ==================================================================
# medico
# 20 ['valdes' 'galego feal' 'lopez renedo.' 'villar del castillo' 'Valcarcel'
#  'suarez' 'ibáñez alonso' 'Fernandez Benito' 'masa' 'Valcárcel'
#  'fernandez benito' 'suarez prado' None 'lopez renedo' 'pazo'
#  'masa vazquez' 20.0 'beceiro' 'gómez buela' 'novo']
# ==================================================================
# year
# 6 [2017 2018 2019 2020 2021 2022]
# ==================================================================
# ast/anorx
# 6 ['si' 'no' 'np' 'ono' 'son' 'ns']
# ==================================================================
# agudo_estable
# 6 [nan 'no' 'si' 'o' None 'son']
# ==================================================================
# cronico_reag
# 5 [nan 'no' 'si' 'nsi' 'm']
# ==================================================================
# transfusion
# 4 [nan 'no' 'si' 'Si 2 concentrados']
# ==================================================================
# paracentesis
# 3 [nan 'no' 'si']
# ==================================================================
# toracocentesis
# 4 [nan 'no' 'si' None]
# ==================================================================
# ayuntamiento
# 84 [nan 'Santiago' 'Brion' 'lalin' 'ames' 'negreira' 'teo' 'Teo' 'Padron'
#  'rois' 'A Baña' 'padron' 'oroso' 'ordenes' 'Rois' 'trazo' 'La Estrada'
#  'O PINO' 'santiago' 'touro' 'boqueixon' 'estrada' 'vedra' 'tordoya'
#  'val do dubra' 'dodro' 'valga' 'santa comba' 'o Pino' 'Valga' 'Lalin'
#  'A baña' 'Ames' 'Touro' 'a baña' 'brion' 'pontecesures' 'pontecesuras'
#  'O Pino' 'santiago de compostela' 'santiago compostela' 'silleda'
#  'la estrada' 'sionlla' 'lousame' 'frades' 'pontevea' 'Vedra' 'Boqueixon'
#  'tordoia' 'o pino' 'brión' 'TEO' 'Estrada' 'a estrada' None 'Brión'
#  'Trazo' 'rianxo' 'Noia' 'noya' 'Oroso' 'ordes' 'Lousame' 'losame' 'Noya'
#  'Negreira' 'noia' 'Pontecesures' 'Dodro' 'Padrón' 'Tordoia'
#  'Val do dubra' 'santiago de com' 'Ordes' 'sigueiro' 'Lalín' 'a Estrada'
#  'vila de cruces' 'la Estrada' 'Boqueixón' 'La estrada' 'Ortoño' 'NOIA']
# ==================================================================
# fecha_alta
# 220 [nan '2022-08-11' '2022-06-03' '2022-06-07' '2022-09-13' '2022-08-13'
#  '2022-07-04' '2022-09-02' '2022-10-26' '2022-10-25' '2022-10-24'
#  '2022-11-03' '2022-11-04' '2022-09-26' '2022-07-07' '2022-05-19'
#  '2022-08-02' '2022-08-12' '2022-08-24' '2022-07-11' '2022-07-25'
#  '2022-07-30' '2022-08-01' '2022-09-08' '2022-09-19' '2022-09-21'
#  '2022-09-27' '2022-09-30' '2022-10-31' '2022-06-10' '2022-06-16'
#  '2022-07-15' '2022-10-03' '2022-11-07' '2022-11-08' '2022-06-23'
#  '2022-07-28' '2022-08-08' '2022-09-22' '2022-10-19' '2022-05-30'
#  '2022-02-20' None '2022-07-18' '2022-05-11' '2022-07-10' '2022-08-30'
#  '2022-07-19' '2022-05-12' '2022-06-28' '2022-07-05' '2022-07-26'
#  '2022-06-21' '2022-06-27' '2022-06-22' '2022-01-11' '2022-03-03'
#  '2022-03-06' '2022-03-30' '2022-05-06' '2022-06-06' '2022-06-17'
#  '2022-06-26' '2022-07-01' '2022-07-09' '2022-07-21' '2022-07-22'
#  '2022-08-10' '2022-08-16' '2022-08-17' '2022-08-18' '2022-08-20'
#  '2022-08-31' '2022-09-01' '2022-05-09' '2022-06-05' '2022-07-14'
#  '2022-08-03' '2022-02-25' '2022-06-08' '2022-06-29' '2022-08-04'
#  '2022-08-22' '2022-10-07' '2022-09-16' '2022-10-20' '2022-06-15'
#  '2022-07-29' '2022-10-17' '2022-08-09' '2022-08-14' '2022-08-19'
#  '2022-09-20' '2022-10-11' '2022-09-09' '2022-09-06' '2022-09-05'
#  '2022-06-20' '2022-07-23' '2022-10-04' '2022-10-05' '2022-08-21'
#  '2022-07-20' '2022-08-29' '2022-10-14' '2022-03-17' '2022-04-25'
#  '2022-05-22' '2022-10-27' '2022-11-02' '2022-04-12' '2022-10-18'
#  '2022-03-10' '2022-04-27' '2022-05-02' '2022-05-05' '2022-05-18'
#  '2022-08-26' '2022-09-29' '2022-04-05' '2022-05-07' '2022-05-27'
#  '2022-03-25' '2022-07-13' '2022-09-15' '2022-05-03' '2022-09-12'
#  '2022-09-25' '2022-03-14' '2022-03-28' '2022-07-31' '2022-04-04'
#  '2022-08-05' '2022-03-22' '2022-03-29' '2022-04-11' '2022-04-28'
#  '2022-05-16' '2022-09-03' '2022-07-12' '2022-06-01' '2022-08-25'
#  '2022-08-23' '26/09722' '2022-06-30' '20/09722' '2022-06-14' '2022-07-27'
#  '2022-09-23' '2022-10-10' '2022-06-09' '2022-09-17' '2022-03-23'
#  '2022-04-18' '2022-06-13' '2022-09-07' '2022-09-28' '2022-10-06'
#  '2022-10-21' '2022-10-28' '2022-10-16' '2022-06-25' '2022-10-09'
#  '2022-05-13' '2022-10-13' '2022-03-24' '2022-06-19' '2022-06-12'
#  '2022-07-08' '2022-08-15' '2022-11-09' '2022-11-10' '2022-10-30'
#  '2022-11-14' '2022-11-16' '2022-11-15' '2022-11-17' '2022-11-18'
#  '25/1022' '2022-11-20' '2022-11-21' '2022-11-22' '2022-11-23'
#  '2022-11-24' '2022-11-25' '0022-11-23' '2022-11-26' '2022-11-28'
#  '2022-11-29' '2022-11-13' '2022-12-01' '2022-11-30' '2022-11-11'
#  '2022-11-05' '30/114/22' '2022-12-02' '2022-12-05' '2022-12-09'
#  '2022-12-11' '2022-12-07' '2022-09-14' '2022-12-12' '2022-12-14'
#  '2022-12-19' '2022-12-16' '2022-12-17' '2022-12-20' '2022-12-13'
#  '2022-12-15' '2022-12-21' '2022-12-23' '2022-12-22' '26/12722'
#  '2022-12-27' '2022-12-26' '2022-12-28' '2022-12-29' '2022-12-25'
#  '2022-12-30' '2022-12-31']
# ==================================================================
# ¿?
# 4 [nan 'no' 'si' None]
# ==================================================================
# toracocen
# 3 [nan 'no' 's']
# ==================================================================

# %%
df_concatenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   h_procedencia         4013 non-null   object
#  1   s_procedencia         4014 non-null   object
#  2   ap                    4013 non-null   object
#  3   otros                 2958 non-null   object
#  4   diagnostico           4011 non-null   object
#  5   motivo_ing            4003 non-null   object
#  6   paliativo_onc/noc     4013 non-null   object
#  7   paliativo_no_onc/noc  4012 non-null   object
#  8   fiebre                4012 non-null   object
#  9   disnea                4013 non-null   object
#  10  dolor                 4014 non-null   object
#  11  delirium              4013 non-null   object
#  12  otros_1               1549 non-null   object
#  13  p_terminal            1547 non-null   object
#  14  agonia                2955 non-null   object
#  15  ps/ecog               4013 non-null   object
#  16  barthel               4013 non-null   object
#  17  gds/fast              4014 non-null   object
#  18  eva_ing               1548 non-null   object
#  19  otros_2               1548 non-null   object
#  20  otros/complicaciones  2956 non-null   object
#  21  n_estancias           4007 non-null   float64
#  22  n_visitas             3988 non-null   float64
#  23  sedacion              4009 non-null   object
#  24  motivo_alta           4013 non-null   object
#  25  medico                4013 non-null   object
#  26  year                  4014 non-null   int64
#  27  ast/anorx             4014 non-null   object
#  28  agudo_estable         2463 non-null   object
#  29  cronico_reag          2464 non-null   object
#  30  transfusion           2464 non-null   object
#  31  paracentesis          2464 non-null   object
#  32  toracocentesis        1407 non-null   object
#  33  ayuntamiento          2463 non-null   object
#  34  fecha_alta            767 non-null    object
#  35  ¿?                    1055 non-null   object
#  36  toracocen             1056 non-null   object
# dtypes: float64(2), int64(1), object(34)
# memory usage: 1.1+ MB

# %%
df_numeric = df_concatenado._get_numeric_data()
df_numeric.head()
# Out:
#    n_estancias  n_visitas  year
# 0         21.0       10.0  2017
# 1         24.0        8.0  2017
# 2         14.0        6.0  2017
# 3          1.0        1.0  2017
# 4          2.0        1.0  2017

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   n_estancias  4007 non-null   float64
#  1   n_visitas    3988 non-null   float64
#  2   year         4014 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 94.2 KB

# %%
df_numeric.isna().sum()
# Out:
# n_estancias     7
# n_visitas      26
# year            0
# dtype: int64

# %%
df_numeric.dropna(inplace=True)

# %%
df_numeric.shape
# Out:
# (3982, 3)

# %%
# df_numeric['n_estancias'] = df_numeric['n_estancias'].astype('int64')
# df_numeric['n_visitas'] = df_numeric['n_visitas'].astype('int64')

df_numeric = df_numeric.astype({'n_estancias': 'int64', 'n_visitas': 'int64'})

# %%
df_numeric.head()
# Out:
#    n_estancias  n_visitas  year
# 0           21         10  2017
# 1           24          8  2017
# 2           14          6  2017
# 3            1          1  2017
# 4            2          1  2017

# %%
x = df_numeric['year']
y = df_numeric['n_visitas']
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(x,y)

# %%
plt.hist(x, bins=20)
# Out:
# (array([ 587.,    0.,    0.,    0.,  526.,    0.,    0.,    0.,  414.,
#            0.,    0.,    0.,  641.,    0.,    0.,    0.,  759.,    0.,
#            0., 1055.]),
#  array([2017.  , 2017.25, 2017.5 , 2017.75, 2018.  , 2018.25, 2018.5 ,
#         2018.75, 2019.  , 2019.25, 2019.5 , 2019.75, 2020.  , 2020.25,
#         2020.5 , 2020.75, 2021.  , 2021.25, 2021.5 , 2021.75, 2022.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df_numeric['n_visitas'])
# Out:
# (array([3.328e+03, 4.570e+02, 1.270e+02, 3.800e+01, 2.100e+01, 5.000e+00,
#         2.000e+00, 2.000e+00, 1.000e+00, 1.000e+00]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
df_concatenado_columns = df_concatenado.select_dtypes(include= 'object').columns.tolist()

# %%
pd.set_option("display.max_rows", None)

for column in df_concatenado_columns:
    df_concatenado[column] = df_concatenado[column].str.lower()
    print("column =",df_concatenado[column].name)
    print(df_concatenado[column].value_counts())
    print("="*66)
# print(df_concatenado.head())
# Out:
# column = h_procedencia
# clinico                 1530
# no                      1250
# clínico                  654
# conxo                    329
# gil casares              146
# clincio                   44
# provincial                12
# hgc                       10
# cliinico                   8
# chuac                      6
# residencia                 5
# si                         3
# clnico                     2
# quiron la coruña           1
# hm                         1
# pontevedra                 1
# lucus augusti              1
# clinoco                    1
# clinico-ap                 1
# rosaleda                   1
# san rafael la coruña       1
# ap                         1
# hcg                        1
# clincico                   1
# salnes                     1
# hula                       1
# hm rosaleda                1
# Name: h_procedencia, dtype: int64
# ==================================================================
# column = s_procedencia
# no                                      1225
# mir                                      483
# onc                                      475
# urg                                      385
# upal                                     208
# nml                                      122
# acv                                      114
# dig                                      105
# hem                                       68
# cgd                                       53
# oncologia                                 40
# digestivo                                 37
# mirp                                      35
# ncr                                       34
# umap                                      30
# urgencias                                 28
# nrl                                       26
# hematologia                               22
# neumologia                                21
# car                                       18
# onco                                      17
# cardiologia                               16
# cot                                       16
# uro                                       14
# neumo                                     14
# cirugia vascular                          14
# reumatologia                              12
# cirugia general                           12
# orl                                       12
# neum                                      11
# rdt                                       11
# tra                                       11
# neurologia                                11
# end                                       10
# urologia                                  10
# nef                                        9
# hado                                       9
# nfr                                        9
# onc/urg                                    8
# nefrologia                                 8
# ume                                        8
# medicina interna                           8
# oncolo                                     6
# mirg                                       6
# traumatologia                              5
# neurocirugia                               5
# infecciosas                                5
# cirugia plastica                           5
# cmf                                        5
# reu                                        4
# trauma                                     4
# cpl                                        4
# hematolog                                  4
# rtp                                        4
# consultas onco                             4
# onc ccee                                   4
# gin                                        4
# cgd/urg                                    4
# radioterapia                               4
# nmlp                                       3
# cirugía vascular                           3
# mir conxo                                  3
# c. vascular                                3
# eif – mir                                  3
# utr                                        3
# cardiología                                3
# diagestivo                                 3
# c.vascular                                 3
# oncol consulta externa                     2
# urg onc                                    2
# vascular                                   2
# c.plástica                                 2
# upia                                       2
# radtp                                      2
# urg hem                                    2
# urg acv                                    2
# der                                        2
# cmx                                        2
# cadiologia                                 2
# endocrino                                  2
# hepatologia                                2
# nutricion                                  2
# hematol                                    2
# nml-consutas externas                      2
# nml-urg                                    2
# umap-mir                                   2
# eif                                        2
# card                                       2
# gine                                       2
# psqg                                       2
# tramatologia                               1
# clp                                        1
# consulta ela multidisciplinar              1
# consulta hipertension                      1
# c.externas neumologia                      1
# u. dolor                                   1
# urgrn                                      1
# endocrinologia                             1
# ccee neumologia                            1
# c externas c.plastica                      1
# anr                                        1
# c.externas mir                             1
# mir-p                                      1
# mir gil casares no                         1
# onc-consultas externa                      1
# cirugia maxilofacial                       1
# rdp                                        1
# neurologia – consultas externas            1
# urg nrl                                    1
# mirpro                                     1
# c. toracica                                1
# ginecología                                1
# cirugía cardiaca                           1
# nof                                        1
# utab                                       1
# rehab                                      1
# ccar                                       1
# cpr                                        1
# nefrología                                 1
# urg trauma                                 1
# mnl                                        1
# hospital de dia                            1
# digstivo                                   1
# onc urg                                    1
# plastica                                   1
# neuro                                      1
# neurc                                      1
# eif mir                                    1
# consultas externas digestivo               1
# neu                                        1
# mir-ap protocolo hierro en domicilio       1
# c.cardiaca                                 1
# respiratorio                               1
# onco-urg                                   1
# crg                                        1
# angiología                                 1
# mir infecciosas                            1
# ccee mir                                   1
# mir p                                      1
# 0nc                                        1
# mirc                                       1
# hematoloxia                                1
# neeumologia                                1
# mir provincial                             1
# ap                                         1
# mir-eif                                    1
# nol                                        1
# unidad ela                                 1
# consultas onc                              1
# mirhp                                      1
# hem-urg                                    1
# cvascular                                  1
# si                                         1
# cirugia vasc                               1
# cirugía torácica                           1
# nml-consultas esterna                      1
# nemologia                                  1
# neomologia                                 1
# enfermedad infecciosas                     1
# mir gil                                    1
# cirugia cardiaca                           1
# nml-cosultas externas                      1
# ccee onc                                   1
# mir-lugo                                   1
# con ext onco                               1
# urg-cirugia                                1
# mir- p -consultas externas                 1
# hemato                                     1
# maxilofac                                  1
# cee nefrologia                             1
# onc-urg                                    1
# onc-consultas                              1
# urg-onc                                    1
# hdd nml                                    1
# urg/urg                                    1
# consulta mir                               1
# cirugia toracica                           1
# Name: s_procedencia, dtype: int64
# ==================================================================
# column = ap
# no                  2767
# si                  1235
# ap                     5
# residencia             2
# pac                    1
# mo                     1
# consulta externa       1
# uro                    1
# Name: ap, dtype: int64
# ==================================================================
# column = otros
# no                                    2810
# ncr                                     46
# nef                                     20
# onc                                     11
# residencia                               8
# urg                                      7
# nefro                                    3
# familia                                  3
# residencia sanitaria                     3
# cgd                                      2
# dig                                      2
# nefro y dig                              2
# solicitud familiar                       2
# residencia san marcos                    2
# cardiologia                              2
# mno                                      1
# paliativos salnes                        1
# nol                                      1
# privado                                  1
# residencia sociosanitaria as dores       1
# hospitales madrid                        1
# p. la rosaleda                           1
# mir                                      1
# uro, cardiología                         1
# car,nefro,c.vasc                         1
# pac santiago                             1
# c. plástica                              1
# policlinico la rosaleda                  1
# ccee                                     1
# hospital la rosaleda                     1
# vascular                                 1
# familiares                               1
# acv                                      1
# consultas                                1
# rtp                                      1
# nrl                                      1
# consulta                                 1
# rosaleda                                 1
# c.e                                      1
# si                                       1
# hija                                     1
# nml-end                                  1
# iniciativa propia                        1
# nml                                      1
# h.la rosaleda                            1
# unidad ef mir                            1
# np                                       1
# uro                                      1
# c. vascular                              1
# Name: otros, dtype: int64
# ==================================================================
# column = diagnostico
# itu                                                                                                                                                                                                                                   167
# infeccion respiratoria                                                                                                                                                                                                                 97
# infeccion urinaria                                                                                                                                                                                                                     85
# icc                                                                                                                                                                                                                                    69
# cancer de colon                                                                                                                                                                                                                        67
# anciano fragil                                                                                                                                                                                                                         57
# insuficiencia cardiaca                                                                                                                                                                                                                 52
# neumonia                                                                                                                                                                                                                               44
# demencia                                                                                                                                                                                                                               44
# ela                                                                                                                                                                                                                                    43
# cancer de pulmon                                                                                                                                                                                                                       43
# cirrosis hepatica                                                                                                                                                                                                                      41
# bronquiectasias infectadas                                                                                                                                                                                                             39
# infección respiratoria                                                                                                                                                                                                                 30
# hepatocarcinoma                                                                                                                                                                                                                        30
# anciana fragil                                                                                                                                                                                                                         29
# anemia                                                                                                                                                                                                                                 28
# infección urinaria                                                                                                                                                                                                                     27
# cancer de pancreas                                                                                                                                                                                                                     25
# glioblastoma                                                                                                                                                                                                                           23
# colangiocarcinoma                                                                                                                                                                                                                      22
# demencia avanzada                                                                                                                                                                                                                      22
# amputacion                                                                                                                                                                                                                             19
# cáncer de pulmón                                                                                                                                                                                                                       19
# ca colon estadio iv                                                                                                                                                                                                                    18
# colangitis                                                                                                                                                                                                                             18
# cancer de prostata                                                                                                                                                                                                                     18
# bronquiectasias                                                                                                                                                                                                                        17
# diverticulitis                                                                                                                                                                                                                         17
# cancer de mama                                                                                                                                                                                                                         17
# ca pancreas                                                                                                                                                                                                                            17
# espondilodiscitis                                                                                                                                                                                                                      17
# broncoaspiracion                                                                                                                                                                                                                       16
# ca mama est iv                                                                                                                                                                                                                         16
# cirrosis hepática                                                                                                                                                                                                                      16
# pielonefritis                                                                                                                                                                                                                          16
# deterioro cognitivo                                                                                                                                                                                                                    15
# endocarditis                                                                                                                                                                                                                           15
# infec resp                                                                                                                                                                                                                             15
# ca mama estadio iv                                                                                                                                                                                                                     15
# ca pulmón est iv                                                                                                                                                                                                                       15
# cancer gastrico                                                                                                                                                                                                                        14
# glioblastoma multiforme                                                                                                                                                                                                                13
# anciana frágil                                                                                                                                                                                                                         13
# prostatitis                                                                                                                                                                                                                            13
# linfoma                                                                                                                                                                                                                                13
# ca colon                                                                                                                                                                                                                               13
# sindrome mielodisplasico                                                                                                                                                                                                               13
# celulitis                                                                                                                                                                                                                              13
# bacteriemia                                                                                                                                                                                                                            13
# enfermedad de pompe                                                                                                                                                                                                                    12
# ulceras vasculares                                                                                                                                                                                                                     12
# anemia cronica                                                                                                                                                                                                                         11
# acv                                                                                                                                                                                                                                    11
# esclerosis multiple                                                                                                                                                                                                                    11
# ca pulmon                                                                                                                                                                                                                              10
# deterioro cognitivo severo                                                                                                                                                                                                             10
# estesio-neuroblastoma                                                                                                                                                                                                                  10
# mieloma multiple                                                                                                                                                                                                                       10
# neumonía                                                                                                                                                                                                                                9
# cancer de recto                                                                                                                                                                                                                         9
# cirrosis                                                                                                                                                                                                                                9
# cancer de ovario                                                                                                                                                                                                                        9
# cancer de esofago                                                                                                                                                                                                                       9
# ca prostata estadio iv                                                                                                                                                                                                                  9
# fibrosis pulmonar idiopatica                                                                                                                                                                                                            9
# ulcera sacra                                                                                                                                                                                                                            8
# insuficiencia renal                                                                                                                                                                                                                     8
# sepsis urinaria                                                                                                                                                                                                                         8
# isquemia eeii                                                                                                                                                                                                                           8
# hipogammaglobulinemia                                                                                                                                                                                                                   8
# inmunodeficiencia comun variable                                                                                                                                                                                                        8
# anemia crónica no filiada                                                                                                                                                                                                               8
# ca pulmon estadio iv                                                                                                                                                                                                                    8
# neoplasia esofago                                                                                                                                                                                                                       8
# broncoaspiración                                                                                                                                                                                                                        8
# ulcera infectada                                                                                                                                                                                                                        7
# linfoma folicular                                                                                                                                                                                                                       7
# ca páncreas                                                                                                                                                                                                                             7
# ca colon est iv                                                                                                                                                                                                                         7
# tumor cerebral                                                                                                                                                                                                                          7
# neoplasia pulmon estadio iv                                                                                                                                                                                                             7
# ca prostata                                                                                                                                                                                                                             7
# ulcera vascular                                                                                                                                                                                                                         7
# amputacion transmetatarsiana                                                                                                                                                                                                            7
# lma                                                                                                                                                                                                                                     7
# deterioro cognitivo avanzado                                                                                                                                                                                                            6
# bronquiectasias sobreinfectadas                                                                                                                                                                                                         6
# neoplasia colon estadio iv                                                                                                                                                                                                              6
# cancer orl                                                                                                                                                                                                                              6
# encefalopatia anoxica                                                                                                                                                                                                                   6
# ca esofago                                                                                                                                                                                                                              6
# ca recto estadio iv                                                                                                                                                                                                                     6
# neoplasia pancreas                                                                                                                                                                                                                      6
# acv isquemico                                                                                                                                                                                                                           6
# insuficiencia respiratoria                                                                                                                                                                                                              6
# i.cardíaca                                                                                                                                                                                                                              6
# cancer pulmon                                                                                                                                                                                                                           6
# ca próstata est iv                                                                                                                                                                                                                      6
# úlcera sacra                                                                                                                                                                                                                            6
# cancer renal                                                                                                                                                                                                                            5
# cancer urotelial                                                                                                                                                                                                                        5
# deterioro                                                                                                                                                                                                                               5
# cirrosis criptogenetica                                                                                                                                                                                                                 5
# epoc reagudizado                                                                                                                                                                                                                        5
# diverticulitis aguda                                                                                                                                                                                                                    5
# adc de pulmón estadio iv                                                                                                                                                                                                                5
# ca de pulmon                                                                                                                                                                                                                            5
# adenocarcinoma de colon estadio iv                                                                                                                                                                                                      5
# cancer de cólon estadio iv                                                                                                                                                                                                              5
# absceso hepático                                                                                                                                                                                                                        5
# cancer de vejiga                                                                                                                                                                                                                        5
# diverticulitis aguda no complicada                                                                                                                                                                                                      5
# ileostomia                                                                                                                                                                                                                              5
# adenocarcinoma pulmon estadio iv                                                                                                                                                                                                        5
# osteomielitis                                                                                                                                                                                                                           5
# fractura de cadera                                                                                                                                                                                                                      5
# hepatopatia no filiada                                                                                                                                                                                                                  5
# ca pulmon est iv                                                                                                                                                                                                                        5
# infección urinaria, fallo cardiaco                                                                                                                                                                                                      5
# deterioro estado general                                                                                                                                                                                                                5
# itu.                                                                                                                                                                                                                                    5
# recambio peg                                                                                                                                                                                                                            5
# neo colon estadio iv                                                                                                                                                                                                                    5
# infeccion herida quirurgica                                                                                                                                                                                                             5
# ca mama                                                                                                                                                                                                                                 5
# cancer pancreas                                                                                                                                                                                                                         5
# cancer colon                                                                                                                                                                                                                            5
# anemia multifactorial                                                                                                                                                                                                                   5
# ulcera eeii                                                                                                                                                                                                                             5
# adenocarcinoma de pulmon estadio iv                                                                                                                                                                                                     5
# adenocarcinoma recto estadio iv                                                                                                                                                                                                         4
# itu, deterioro cognitivo severo                                                                                                                                                                                                         4
# cancer  vesical                                                                                                                                                                                                                         4
# ca endometrio                                                                                                                                                                                                                           4
# parkinson                                                                                                                                                                                                                               4
# diverticulitis no complicada                                                                                                                                                                                                            4
# ulcera traumatica                                                                                                                                                                                                                       4
# sde mielodisplásico                                                                                                                                                                                                                     4
# ca ovario                                                                                                                                                                                                                               4
# epoc                                                                                                                                                                                                                                    4
# carcinomatosis peritoneal origen ovarico,ascitis                                                                                                                                                                                        4
# neo pulmon estadio iv                                                                                                                                                                                                                   4
# sde mielodisplasico                                                                                                                                                                                                                     4
# adenocarcinoma de recto estadio iv                                                                                                                                                                                                      4
# leucemia aguda                                                                                                                                                                                                                          4
# neoplasia orl                                                                                                                                                                                                                           4
# ca renal estadio iv                                                                                                                                                                                                                     4
# i cardiaca                                                                                                                                                                                                                              4
# esclerosis múltiple                                                                                                                                                                                                                     4
# adenoca colon                                                                                                                                                                                                                           4
# ca pancreas estadio iv                                                                                                                                                                                                                  4
# celulitis eeii                                                                                                                                                                                                                          4
# adenocarcinoma de ovario estadio iv                                                                                                                                                                                                     4
# cancer de pulmon estadio iv                                                                                                                                                                                                             4
# ...
# urg e ingreso upal                                                                                         2
# reingreso en neumologia                                                                                    2
# alta por paso a urgencias                                                                                  2
# reingreso.                                                                                                 2
# reingres en upal                                                                                           2
# traslado a cpl                                                                                             2
# buen control de síntomas                                                                                   2
# ingreso en orl                                                                                             2
# ingreso en nrl                                                                                             2
# alta por paso a uregncias                                                                                  2
# traslado a acv                                                                                             2
# ingreso en utr                                                                                             1
# traslado a urgencias para ingreso mir                                                                      1
# traslado a orl                                                                                             1
# ingreso en c.plástica                                                                                      1
# ingreso medicina interna                                                                                   1
# urgencias clinico                                                                                          1
# ingreso mir                                                                                                1
# traslado a urgencias, petición familiar                                                                    1
# traslado a urgencias e ingreso en upal                                                                     1
# traslado a urgencias tetraparesia                                                                          1
# alta paso a urgencias                                                                                      1
# traslado cirugia                                                                                           1
# exitus comunicado por la familia                                                                           1
# ingreso cirugía vascular                                                                                   1
# reingreso programado                                                                                       1
# tto en rtp                                                                                                 1
# ingreso cgd                                                                                                1
# reingreso hospital privado                                                                                 1
# paso a uregencias                                                                                          1
# trasladoa urgencias                                                                                        1
# cuidados ap                                                                                                1
# alta paso por urgencias                                                                                    1
# traslado a urgencias por el 061                                                                            1
# reingreso en mir                                                                                           1
# ingreso en c.vascular                                                                                      1
# traslado a urgencias por covid                                                                             1
# traslado a urgencias.                                                                                      1
# derivado urgencias                                                                                         1
# ingreso en oncologia                                                                                       1
# ingreso en medicina interna                                                                                1
# domicilio                                                                                                  1
# traslado a urgencias clínico                                                                               1
# consulta médica                                                                                            1
# traslado mir provincial                                                                                    1
# unidad de algias musculoesqueléticas                                                                       1
# ingreso en nrc                                                                                             1
# traslado urgencias clinico                                                                                 1
# tralado                                                                                                    1
# reingreso en centro privado                                                                                1
# residencia sociosanitaria                                                                                  1
# traslado a pasliativos                                                                                     1
# petición de la familia de posponer tto                                                                     1
# ingreso nml clinico                                                                                        1
# trasladoa upal                                                                                             1
# reingreso orl                                                                                              1
# ingreso para trasplante                                                                                    1
# ingreso en digestivo clínico                                                                               1
# traslado otro centro                                                                                       1
# reingreso por urgencias a hado                                                                             1
# reingreso en onc                                                                                           1
# traslado a urgencias del clinico                                                                           1
# sin condiciones para seguimiento hado                                                                      1
# traslado a urg del clínico                                                                                 1
# fin de cuidadso                                                                                            1
# reingresoupal                                                                                              1
# claudicacion familiar                                                                                      1
# reingreso en oncologia                                                                                     1
# reingreso en urgencias                                                                                     1
# reingreso programado en acv                                                                                1
# ingreso en huac para transplante pulmonar                                                                  1
# solicitud familiar                                                                                         1
# no fue dado de alta hospitalaria                                                                           1
# traslado a hospital privado de agudos por decisión familiar                                                1
# imposibilidad de cuidados en domicilio del paciente por condiciones higienoco-sanitarias inadecuadas       1
# traslado a h.gil casares                                                                                   1
# estable en su enfermedad                                                                                   1
# cambio de domicilio fuera de área asistencial de hado                                                      1
# ingreso onco                                                                                               1
# Name: motivo_alta, dtype: int64
# ==================================================================
# column = medico
# fernandez benito       797
# villar del castillo    727
# galego feal            567
# lopez renedo           422
# suarez                 421
# valdes                 221
# novo                   182
# gómez buela            143
# suarez prado           140
# valcarcel              100
# ibáñez alonso           87
# beceiro                 70
# lopez renedo.           51
# masa                    50
# masa vazquez            28
# valcárcel                5
# pazo                     1
# Name: medico, dtype: int64
# ==================================================================
# column = ast/anorx
# no     2449
# si     1561
# np        1
# ono       1
# son       1
# ns        1
# Name: ast/anorx, dtype: int64
# ==================================================================
# column = agudo_estable
# no     2027
# si      432
# o         3
# son       1
# Name: agudo_estable, dtype: int64
# ==================================================================
# column = cronico_reag
# si     1414
# no     1048
# nsi       1
# m         1
# Name: cronico_reag, dtype: int64
# ==================================================================
# column = transfusion
# no                   2401
# si                     62
# si 2 concentrados       1
# Name: transfusion, dtype: int64
# ==================================================================
# column = paracentesis
# no    2393
# si      71
# Name: paracentesis, dtype: int64
# ==================================================================
# column = toracocentesis
# no    1404
# si       3
# Name: toracocentesis, dtype: int64
# ==================================================================
# column = ayuntamiento
# santiago                  983
# lalin                     224
# ames                      209
# teo                       183
# la estrada                 72
# padron                     52
# ordenes                    45
# rois                       44
# boqueixon                  40
# silleda                    39
# rianxo                     38
# negreira                   35
# brión                      32
# a baña                     32
# vedra                      30
# trazo                      29
# oroso                      29
# noia                       26
# lalín                      25
# brion                      25
# santiago de compostela     24
# estrada                    23
# val do dubra               23
# touro                      23
# o pino                     20
# ordes                      20
# a estrada                  20
# valga                      19
# lousame                    18
# pontecesures               18
# noya                       16
# padrón                     11
# dodro                       9
# vila de cruces              8
# tordoia                     4
# boqueixón                   4
# tordoya                     1
# sigueiro                    1
# santiago de com             1
# frades                      1
# losame                      1
# pontevea                    1
# santa comba                 1
# pontecesuras                1
# santiago compostela         1
# sionlla                     1
# ortoño                      1
# Name: ayuntamiento, dtype: int64
# ==================================================================
# column = fecha_alta
# 2022-06-23    10
# 2022-07-11    10
# 2022-06-20     9
# 2022-10-31     9
# 2022-08-12     9
# 2022-12-07     8
# 2022-11-14     8
# 2022-10-11     8
# 2022-08-02     8
# 2022-12-05     8
# 2022-06-16     8
# 2022-08-24     8
# 2022-12-19     8
# 2022-11-22     7
# 2022-08-17     7
# 2022-09-13     7
# 2022-11-18     7
# 2022-08-09     7
# 2022-09-26     7
# 2022-11-21     7
# 2022-11-04     7
# 2022-11-29     7
# 2022-12-21     7
# 2022-06-27     7
# 2022-10-24     7
# 2022-08-22     6
# 2022-08-08     6
# 2022-09-20     6
# 2022-08-31     6
# 2022-08-18     6
# 2022-07-26     6
# 2022-07-20     6
# 2022-10-14     6
# 2022-06-14     6
# 2022-06-28     6
# 2022-10-18     6
# 2022-09-19     6
# 2022-11-09     6
# 2022-06-17     6
# 2022-11-17     6
# 2022-09-30     6
# 2022-06-07     6
# 2022-09-21     6
# 2022-12-23     6
# 2022-12-12     6
# 2022-08-04     5
# 2022-07-22     5
# 2022-08-10     5
# 2022-12-28     5
# 2022-12-16     5
# 2022-10-10     5
# 2022-11-25     5
# 2022-10-28     5
# 2022-10-20     5
# 2022-08-19     5
# 2022-10-05     5
# 2022-10-13     5
# 2022-07-09     5
# 2022-08-11     5
# 2022-05-19     5
# 2022-10-19     5
# 2022-10-25     5
# 2022-08-30     5
# 2022-09-08     5
# 2022-10-03     5
# 2022-06-22     5
# 2022-09-02     5
# 2022-07-04     5
# 2022-07-28     5
# 2022-07-19     5
# 2022-11-02     4
# 2022-11-28     4
# 2022-11-30     4
# 2022-09-09     4
# 2022-08-01     4
# 2022-11-11     4
# 2022-10-27     4
# 2022-06-06     4
# 2022-06-10     4
# 2022-06-03     4
# 2022-05-05     4
# 2022-11-10     4
# 2022-11-07     4
# 2022-05-27     4
# 2022-03-25     4
# 2022-06-13     4
# 2022-08-05     4
# 2022-06-30     4
# 2022-11-16     4
# 2022-08-23     4
# 2022-12-27     4
# 2022-12-09     4
# 2022-07-21     4
# 2022-06-29     4
# 2022-07-05     4
# 2022-11-03     4
# 2022-07-07     4
# 2022-07-01     4
# 2022-12-30     4
# 2022-07-29     4
# 2022-07-27     3
# 2022-07-13     3
# 2022-12-26     3
# 2022-05-02     3
# 2022-11-08     3
# 2022-09-12     3
# 2022-09-01     3
# 2022-09-07     3
# 2022-05-09     3
# 2022-07-15     3
# 2022-10-17     3
# 2022-05-18     3
# 2022-12-20     3
# 2022-12-13     3
# 2022-11-15     3
# 2022-10-26     3
# 2022-06-08     3
# 2022-09-27     3
# 2022-11-23     3
# 2022-05-30     3
# 2022-08-25     3
# 2022-10-04     3
# 2022-07-23     3
# 2022-07-18     3
# 2022-07-12     3
# 2022-06-15     3
# 2022-06-09     3
# 2022-09-22     2
# 2022-09-23     2
# 2022-12-02     2
# 2022-04-18     2
# 2022-12-29     2
# 2022-10-06     2
# 2022-10-21     2
# 2022-10-16     2
# 2022-12-22     2
# 2022-12-15     2
# 2022-12-01     2
# 2022-11-24     2
# 2022-06-01     2
# 2022-06-26     2
# 2022-09-15     2
# 2022-08-26     2
# 2022-04-25     2
# 2022-02-20     2
# 2022-09-05     2
# 2022-09-06     2
# 2022-05-11     2
# 2022-09-16     2
# 2022-10-07     2
# 2022-06-21     2
# 2022-08-03     2
# 2022-07-14     2
# 2022-08-16     2
# 2022-03-06     2
# 2022-03-30     2
# 2022-05-06     2
# 2022-09-29     2
# 2022-03-17     2
# 2022-03-28     2
# 2022-05-16     2
# 2022-03-22     2
# 2022-12-17     1
# 2022-11-05     1
# 30/114/22      1
# 2022-07-10     1
# 2022-08-14     1
# 2022-05-12     1
# 2022-12-11     1
# 2022-03-23     1
# 2022-09-14     1
# 2022-09-17     1
# 2022-12-14     1
# 2022-02-25     1
# 2022-03-29     1
# 2022-07-31     1
# 2022-04-11     1
# 2022-06-05     1
# 2022-08-20     1
# 2022-01-11     1
# 2022-03-03     1
# 26/12722       1
# 2022-04-28     1
# 2022-08-13     1
# 20/09722       1
# 2022-12-25     1
# 2022-09-03     1
# 2022-04-04     1
# 2022-06-25     1
# 2022-10-09     1
# 2022-03-10     1
# 2022-05-13     1
# 2022-05-07     1
# 2022-03-24     1
# 2022-06-19     1
# 2022-06-12     1
# 2022-07-08     1
# 2022-08-15     1
# 2022-04-05     1
# 2022-05-03     1
# 2022-10-30     1
# 2022-09-25     1
# 2022-04-27     1
# 2022-04-12     1
# 2022-11-13     1
# 2022-05-22     1
# 25/1022        1
# 2022-11-20     1
# 2022-03-14     1
# 26/09722       1
# 2022-08-29     1
# 2022-08-21     1
# 2022-07-30     1
# 0022-11-23     1
# 2022-11-26     1
# 2022-09-28     1
# 2022-07-25     1
# 2022-12-31     1
# Name: fecha_alta, dtype: int64
# ==================================================================
# column = ¿?
# no    1048
# si       7
# Name: ¿?, dtype: int64
# ==================================================================
# column = toracocen
# no    1055
# s        1
# Name: toracocen, dtype: int64
# ==================================================================

# %%
df_concatenado.columns
# Out:
# Index(['h_procedencia', 's_procedencia', 'ap', 'otros', 'diagnostico',
#        'motivo_ing', 'paliativo_onc/noc', 'paliativo_no_onc/noc', 'fiebre',
#        'disnea', 'dolor', 'delirium', 'otros_1', 'p_terminal', 'agonia',
#        'ps/ecog', 'barthel', 'gds/fast', 'eva_ing', 'otros_2',
#        'otros/complicaciones', 'n_estancias', 'n_visitas', 'sedacion',
#        'motivo_alta', 'medico', 'year', 'ast/anorx', 'agudo_estable',
#        'cronico_reag', 'transfusion', 'paracentesis', 'toracocentesis',
#        'ayuntamiento', 'fecha_alta', '¿?', 'toracocen'],
#       dtype='object')

# %%
[df_concatenado[column].unique() for column in df_concatenado_columns]
# Out:
# [array(['gil casares', 'clinico', 'no', 'provincial', 'hula', 'conxo',
#         'chuac', 'clincio', 'clnico', 'si', 'clínico', 'cliinico', None,
#         'salnes', 'rosaleda', 'clincico', 'hgc', 'hcg', 'ap',
#         'san rafael la coruña', 'quiron la coruña', 'clinico-ap',
#         'clinoco', 'lucus augusti', 'hm', 'residencia', 'pontevedra',
#         'hm rosaleda'], dtype=object),
#  array(['upal', 'onc', 'mir', 'dig', 'urg', 'no', 'hem', 'tra', 'rdt',
#         'nml', 'mirp', 'cgd', 'ume', 'cot', 'nmlp', 'acv', 'umap', 'nef',
#         'nof', 'cardiologia', 'car', 'nrl', 'mirg', 'ncr', 'neumo', 'card',
#         'uro', 'gine', 'psqg', 'hematol', 'mir conxo', 'oncologia',
#         'nefrologia', 'digestivo', 'hematologia', 'urgencias',
#         'cirugía vascular', 'orl', 'neumologia', 'neuro', 'urologia',
#         'neurc', 'eif mir', 'cgd/urg', 'mirpro', 'cirugia general',
#         'hospital de dia', 'consulta ela multidisciplinar', 'urgrn',
#         'mir gil casares no', 'mir-ap protocolo hierro en domicilio',
#         'reumatologia', 'nml-consultas esterna', 'nml-urg',
#         'nml-cosultas externas', 'hado', 'onc-urg', 'onc-consultas',
#         'nml-consutas externas', 'urg-onc', 'hdd nml', 'onc/urg', 'end',
#         'rtp', 'urg/urg', 'infecciosas', 'hematolog', 'neurologia',
#         'consulta mir', 'trauma', 'neurocirugia', 'cirugía torácica',
#         'cirugia vasc', 'eif', 'angiología', 'hematoloxia',
#         'mir provincial', 'nol', 'mirhp', 'umap-mir', 'onc ccee',
#         'traumatologia', 'tramatologia', 'neomologia', 'si', 'cvascular',
#         'hem-urg', 'cmf', 'nutricion', 'consultas onc', 'unidad ela',
#         'cardiología', 'mir-eif', 'ap', 'cpl', 'neeumologia', 'c.plástica',
#         'mirc', '0nc', 'mir p', 'ccee mir', 'mir infecciosas', 'oncolo',
#         'crg', 'oncol consulta externa', 'radtp', 'onco-urg', 'reu',
#         'nemologia', 'onco', 'cirugia vascular', 'consultas onco',
#         'endocrino', 'hepatologia', 'nfr', 'medicina interna',
#         'cee nefrologia', 'maxilofac', 'hemato',
#         'mir- p -consultas externas', 'urg-cirugia', 'con ext onco',
#         'mir-lugo', 'ccee onc', 'neum', 'cirugia cardiaca', 'mir gil',
#         'c.vascular', 'enfermedad infecciosas', 'c.cardiaca',
#         'c. vascular', 'respiratorio', 'consultas externas digestivo',
#         'eif – mir', 'neurologia – consultas externas', 'rdp',
#         'cirugia maxilofacial', 'onc-consultas externa', 'utr', 'mir-p',
#         'c.externas mir', 'ccee neumologia', 'c externas c.plastica',
#         'endocrinologia', 'cirugia plastica', 'u. dolor',
#         'c.externas neumologia', 'consulta hipertension', 'der', 'clp',
#         'urg nrl', 'anr', 'c. toracica', 'gin', 'neu', 'urg acv',
#         'urg hem', 'radioterapia', 'vascular', 'plastica', 'onc urg',
#         'digstivo', 'urg onc', 'diagestivo', 'mnl', 'ginecología',
#         'urg trauma', 'nefrología', 'cadiologia', 'upia', 'cpr', 'ccar',
#         'rehab', 'utab', 'cmx', 'cirugía cardiaca', 'cirugia toracica'],
#        dtype=object),
#  array(['no', 'si', 'pac', None, 'ap', 'mo', 'consulta externa', 'uro',
#         'residencia'], dtype=object),
#  array(['no', 'nefro', 'cardiologia', 'cgd', 'nef', 'onc', 'uro', 'rtp',
#         'nrl', 'consulta', 'rosaleda', 'urg', 'c.e', 'si', 'consultas',
#         'residencia san marcos', 'ncr', 'familia', 'hija',
#         'iniciativa propia', 'dig', 'nml', 'h.la rosaleda',
#         'unidad ef mir', 'residencia', 'solicitud familiar', 'np',
#         'familiares', 'nml-end', 'nefro y dig', 'acv', 'mir', 'vascular',
#         'mno', 'paliativos salnes', 'nol', 'privado',
#         'residencia sociosanitaria as dores', 'residencia sanitaria',
#         'p. la rosaleda', nan, 'hospitales madrid', 'uro, cardiología',
#         'car,nefro,c.vasc', 'pac santiago', 'c. plástica',
#         'policlinico la rosaleda', 'ccee', 'hospital la rosaleda',
#         'c. vascular'], dtype=object),
#  array(['ca orl', 'melanoma vulvar', 'ca broncogenico', ...,
#         'infección prótesis vascular', 'pseudoartrosis de tibia',
#         'neoplasia pulmón'], dtype=object),
#  array(['contro d sintomas', 'mal control dolor', 'control evolutivo',
#         'admininistacion octreotido', 'control de sintomas', 'transfusion',
#         'inf.osteosintesis', 'dolor', 'valoración', 'dolor abdominal',
#         'infección respiratoria', 'valoracion', 'neumonia',
#         'control síntomas', 'celulitis', 'control de sintom',
#         'tratamiento', 'broncoaspiracion', 'control d síntomas',
#         'inyección octreótrido', 'control dolor',
#         'tratamiento antibiotico iv', 'recambio peg', 'curas',
#         'transfusión', 'postoperatorio', 'angustia', 'diarrea',
#         'valoracion ulcera', 'valoracion ulceras', 'control de síntomas',
#         'paracentesis', 'infec respirat', 'itu', 'continuacion cuidados',
#         'fiebre y dolor costal', 'antibioterapia', 'ulcera tumoral',
#         'tratamiento iv', 'dolo abdominal', 'curas herida quirurgica',
#         'ascitis', 'deterioor del estado general', 'infeccion urinaria',
#         'bronquiectasias infectadas', 'seguimiento', 'fiebre', 'hierro iv',
#         'administracion seguril iv', 'control analgesico',
#         'seguimineto evolutivo ajuste de tratamiento',
#         'tratamiento iv y control evolutivo',
#         'tratamiento antibiotico y control evolutivo',
#         'tratamiento analgesico y control evolutivo',
#         'control analgesico y recambio peg', 'cuidados paliativos',
#         'dolor precordial', 'control analgesico y valoracion hematuria',
#         'curas y control evolutivo', 'sindrome anemico-transfusión',
#         'valoración clínica', 'infección respiratoria y/o urinaria',
#         'tto antibiotico iv', 'protocolo vidaza',
#         'disnea, deterioro del estado general',
#         'control en domicilio y ajuste de tratamiento',
#         'control y tratamiento antibiotico iv',
#         'cuidados paliativos avanzadios',
#         'fase agónica, control de síntomas', 'obstrucción intestinal',
#         'síndrome anémico, protocolo transfusional', 'tto diurético iv',
#         'diarrea tóxica postquimioterapia', 'fase final de vida',
#         'descompensación metabolica dolor', 'coma',
#         'control de sintomas fase de ultimos dias',
#         'control síntomas paciente agónica', 'agitacion',
#         'administracion hierro iv', 'tratmiento sintomatico',
#         'protocolo administracion lovo/carvidopa', 'control sintomas',
#         'comntrol sintomas', 'diarrea toxica,control sintomas',
#         'cuidados finales', 'administracion tratamiento iv',
#         'control sintomatico', 'sueroterapia',
#         'valoracion por nauseas y vomitos', 'anemia', 'antibioterapia iv',
#         'control y tratamiento sintomas', 'cantrol y paracentesis',
#         'control y cuidados paliativos', 'tto vidaza', 'tratmiento iv',
#         'comntrol de sintomas', 'cancer de prostata', 'cambio peg',
#         'infeccion abdominal', 'alteración hábito intestinal',
#         'itu. descompensación diabética', 'rectorragias',
#         'infeccion respiratoria, antibioterapia iv', 'infeccion tumor',
#         'curas y control de sintomas', 'ulceras presion',
#         'transfusion hierro', 'suboclusion intestinal',
#         'oclusión intestinal', 'cuidados colostomia', 'astenia',
#         'infeccion respiratoria,', 'inyeccion octreotrido',
#         'controld e sintomas', 'valoración nutricional', 'agonía',
#         'tratamiento antibiotico iv y control evolutivo',
#         'control y curas', 'tratmiento antibiotico iv',
#         'control y tratamientop sintomas', 'tratameinto antibiotico iv',
#         'valoracion de tratamiento', 'trasfundir',
#         'reposicion colostomia, control y curas', 'analitica sanguinea',
#         'control ascitis', 'sedacion', 'oclusion intestinal',
#         'broncoaspiraciones recurrentes', 'itu...tto iv',
#         'deterioro del estado general y alteración del nivel de conciencia',
#         'curas y seguimiento', 'itu, tto antibiótico',
#         'suboclusión intestinal', 'agonía, claudicación de ap',
#         'broncoaspiración, antibióticos iv',
#         'curas de herida, intolerancia oral',
#         'infección respiratoria, antibioterapia iv',
#         'sangrado ginecologico', 'transfusión de hemoderivados',
#         'infeccion respiratorias',
#         'agitación extrema y pérdida de vía oral',
#         'administracion hierro i v', 'protocolo peg', 'recambi peg',
#         'deteriro cognitivo', 'broncoaspiración', 'bronconeumonia',
#         'protocolo recambio peg', 'situacion agonica', 'osteomielitis',
#         'descompensacion cardio respiratoria',
#         'infeccion urinaria y-o respiratoria', 'valoracion clinica',
#         'controo dolor cadra', 'administración de hierro',
#         'valoracion nutricion enteral', 'agitacion psicomotriz',
#         'tatamiento antibiotico iv', 'inquietud, sospecha de rao',
#         'control evolutivo y curas de úlceras',
#         'administracion antibiotico iv',
#         'admininistracio de antibiotico iv', 'conrol de sintomas',
#         'intolerancia via oral', 'iyeccion octreotido',
#         'transfusión hematies', 'insuficiencia respiratoria',
#         'perfusión hierro iv', 'anemia, valorar transfusion',
#         'ajuste tratamiento analgesico',
#         'oclusion intestinal control de sintomas',
#         'infeccion respiratoria y deterioro estado general',
#         'tratamiento iv en domicilio', 'estudio',
#         'ulcera inguinal izr grado iv',
#         'dolor abdominal tras paracentesis', 'curas herida quirúrgica',
#         'antibioterapia iv y continuacion cuidados',
#         'curas úlceras por presión', 'infeccion  respiratoria',
#         'continuación de cuidados',
#         'aislamiento estafilococo epidermidis en hemocultivo y klebsiella en punta de catéter. administración de daptomicina iv',
#         'continuación de cuidados. antibioterapia iv',
#         'valoración trratamiento.', 'valoración upp',
#         'continuacion de cuiodados', 'control y ajuste de tratamiento',
#         'control danalgesico', 'contrl y seguimineto',
#         'tratamioento antibiotico iv', 'mal control analgesico',
#         'control sintomas y cuidados paliativos',
#         'administracion sandostatin', 'tratamiento de sintomas',
#         'paracentesis evacuadora', 'insuficiencia cardiorespiratoria',
#         'protocolo vidaza y tto sintomatico', 'continuacion de cuidados',
#         'deterioro del estado general', 'infeccion respiratoria',
#         'manejo del dolor', 'tratamiento analgesico',
#         'control y tratamiento', 'disnea', 'administración de myozime',
#         'tratamiento antibiotico', 'insuficiecia respiratoria',
#         'situación de final de vida/últimos días', 'tto iv',
#         'lesione ee ii y herida quirúrgica', 'antibiotico iv',
#         'paracentesis y control de sintomas', 'recambio de peg',
#         'disnea y sindrome anemico',
#         'lesiones en eeii, tto antibiotico y sintomatico en general',
#         'control analitico', 'tratamiento sintomas', 'sindrome anemico',
#         'retirada picc', 'trasfusion',
#         'cambio programado de sonda vesical y administración de tto',
#         'antibioterapia intravenosa', 'descompensacion hidropica',
#         'itu, fiebre, perdida via oral', 'colocacion de bomba duodopa',
#         'paracentesis evacuadora, control de sintomas',
#         'preagonía, control de síntomas', 'control analgésico',
#         'lesiones presión', 'lesiones presion',
#         'solicitud familiar cura paliativa', 'ciatalgia', 'revision',
#         'hematuria', 'analitica de control', 'fiebre, traqueitis',
#         'sindrome febril', 'antibiotico semanal', 'dolor neuropático',
#         'situacion de agonia', 'rotura de tendones', 'tsindrome anemico',
#         'tratamient intravenoso', 'itu, tto iv', 'tto antibiot iv',
#         'tto iv antibiotico', 'ictus', 'infeccion herida quirurgica',
#         'curas y trao antibiotico', 'trato antibiotico iv',
#         'administración de vidaza', 'agonia',
#         'retirada de soporte nutricional',
#         'alteraciones hidroelectroliticas, intolerancia digestiva y control de sintomas',
#         'infeccio respiratoria', 'valoracion sng',
#         'control inquietud e insomnio',
#         'valoracion y tratamiento por encefalopatia', 'control agitacion',
#         'valoracion de dolor e inquietud', 'curas y antibioterapia',
#         'agitación', 'tto diuretico iv', 'tratamiento intravenoso',
#         'cuidados palaitivos avanzados',
#         'valoracion tratamiento antibiotico', 'negativa a la ingesta',
#         'antibioterapia intravenosa,continuación de cuidados',
#         'obstruccion intestinal', 'cambio de sonda vesical', 'evaluacion',
#         'contro de sintomas',
#         'infeccion respiratoria e insuficiencia cardiaca',
#         'tratamiento antibiotico intravenoso', None, 'curas ulcera sacra',
#         'valoración situación clinica', 'curas locales ulceras mmii',
#         'valoración y control de síntomas',
#         'transfusion y control de síntomas', 'control  evolutivo',
#         'antibioterapia iv y continuación de cuidados herida quirúrgica',
#         'valoracion broncoaspiracion', 'valoracion situacion clinica',
#         'trato antibiotico', 'antibioticos+curas', 'valoracio nutricional',
#         'infeccion ulcera presion', 'let', 'ulcera vascular',
#         'infección local y tto iv', 'protocolo iv', 'nauseas y vomitos',
#         'cambio sonda', 'retirada', 'protocolo tto iv',
#         'tto iv y control sintomas', 'protocolo antibiotico semanal',
#         'protocolo antibioterapico', 'administacion myozime',
#         'administracion zoladex', 'hipercalcemia',
#         'lesion presion infectada', 'control sintomatico y postquirurgico',
#         'celulitis en eeii derecha', 'insomnio rebelde',
#         'cuidados postquirurgicos', 'hiponatremia',
#         'recambio de peg en protocolo', 'protocolo antibiotico iv',
#         'infeccion urinaria con bacteriemia', 'vigilancia evolutiva',
#         'protocolo farmacologico', 'ditension abdominal',
#         'contol sintomas', 'trto antibiotico', 'protocolo neurologia',
#         'inf respiratoria', 'tratamientoiv', 'tratamiento i v',
#         'control scfv', 'control y tratamiento paliativo',
#         'cuidados paliativos y paracentesis',
#         'control y cuidados paliativos curas ulceras',
#         'cumplimentar tratamiento antibiotico iv', 'control y seguimiento',
#         'control del dolor', 'aumento de las secrecione',
#         'control evolutivo y ajuste de tratamiento',
#         'tratamiento iv y control', 'protocolo de transfusion',
#         'vaoracion', 'suministro de fármacos de empleo hospitalario',
#         'control analgesia',
#         'control evolutivo tratamiento antibiotico iv',
#         'control sintomas diureticos', 'tratamiento iv antibiotico',
#         'control sintomas .let',
#         'control evolutivo y tratamiento antibiotico iv',
#         'control sintomas dolor mal controlado',
#         'control analgesico y cambio infusor semanal',
#         'cuidados y evolucion. tratamiento antibiotico iv',
#         'cuidados palaitivos', 'depresion', 'alteracion comportamiento',
#         'control y curas laparotomia', 'ulceras sacras',
#         'valoracion tumoracion cervical', 'tratamiento  antibiotico iv',
#         'tratamiento  iv', 'administracion tratamioento', 'hiperglucemia',
#         'isquemia distal 1-2-5 dedo pie derecho',
#         'administracion tratamiento antibiotico iv', 'coma metabolico',
#         'valoracion oxigenoterapia', 'fiebre-disnea',
#         'valoracion tratamiento', 'antbioterapia,control de síntomas',
#         'control evolutivos',
#         'solicitud de valoración por hado desde la residencia ss as dores',
#         'metrorragia', 'valoracion y tratamiento',
#         'control sintomas y tratamiento', 'sellado pic',
#         'tratmiento antibiotico', 'control y paracentesis',
#         'control y sintomas', 'trtamiento antibiotico',
#         'ajuste de tratamiento',
#         'tratamioento antibiotico iv y curas ulceras',
#         'perdida via oral .valoracion',
#         'control y valoracion paracentesis', 'valoracion derrame',
#         'valoracion por lesiones dermicas', 'antbioterapia',
#         'cambio de peg', 'control y curas de by pass',
#         'ajuste tratamiento', 'curas tras by pass',
#         'tratamiento antibiotico y curas', 'administración furosemida iv',
#         'control de sintoms', 'infeccion de cateter', 'cura de picc',
#         'valoracion transafusion', 'tratamiento antibiótico',
#         'encefalopatia hepatica', 'antibioterapia iv, curas',
#         'analitica de sangre', 's. confusional', 'antbioterapia iv',
#         'control sintomas y tratamiento dolor', 'valoracion por edema',
#         'tratamiento antibiotico y evolucion',
#         'antibioterapia y control evolutivo',
#         'antibioterapia y curas ulceras', 'antibioterapia  iv',
#         'cntrl de sintomas', 'control sintomas paliativos',
#         'curas ulceras', 'control tras radioterapìa',
#         'cuidados peg radiologica u control sintomas',
#         'control sintoma en paliativo avanzado',
#         'control sintomas en paliativo avanzado',
#         'tratamiento antibiótico iv',
#         'control de sintomas, curas ulcera tumoral', 'scffv',
#         'control evolutivo y tratamiento', 'trtamiento antibiotico iv',
#         'demencia avanzada', 'control', 'infeccion boca negativa ingesta',
#         'continuación de cuidados, antibioterapia iv',
#         'control curas y tratamiento analgesico',
#         'dispepsi dolor abdominal', 'administración aciclovir iv',
#         'control y tratamiento antibiotico',
#         'curas y tratamiento antibiotico iv', 'anemia,transfusion',
#         'cambio sonda suprapubica', 'curas úlceras',
#         'tratamiento antbiotico', 'evolucion', 'tratatmiento antibiotico',
#         'tratamiento seguril y albúmina iv', 'tratamiento antibiotico  iv',
#         'tratamiento antbiotico iv', 'tratamiento antibiotico oral',
#         'cura ulcera', 'control clinico estreñimiento',
#         'control y tratamiento de sintomas',
#         'control sintomas y evolutivo', 's fragilidad intenso',
#         'facilitar medicacion hospitalaria',
#         'administracion sandostatin lar', 'antibioticoterapia',
#         'tansfusion', 'administracion de inmunoglobulinas',
#         'antibioticos iv', 'ascitis a tension',
#         'tratamiento antibiotico hospitalario',
#         'administración de seguril sc',
#         'control sintomas. cuidados paliativos avanzados',
#         'sindrome general', 'curas . pulsos de metilprenisolona',
#         'insuficiencia cardiaca', 'ajuste por hipertension',
#         'sedación final vida', 'seguimiento y control analítico',
#         'ajuste analgésico', 'trat alprostadil iv', 'control analítico',
#         'antibioterapia iv y control de síntomas', 'antiobioterpia iv',
#         'antibioterapia iv y curas', 'obstruccion sonda urinaria',
#         'antibioterapia  colangitis', 'valoracion seguimiento',
#         'administracion inmunoglobulinas', 'control y antibioterapia iv',
#         'encefalopatia', 'couidados paliativos',
#         'tratamiento antibiotico neumonia',
#         'control sintomas cuidados paliativos', 'vomitos',
#         'infección urinaria', 'control evolutivo, paracentesis',
#         'antibioticoterapia iv', 'scfv', 'tratamiento antibioitico iv',
#         'disfagia', 'ctratamiento antibiotico iv', 'curas y tratamiento',
#         'control evolutivo y curas', 'cvaloracion encefalopatia',
#         'administracion ganmaglobulinas', 'adminiostracion duodopa',
#         'dolor cervical', 'control lesion mandibula', 'valoracion peg',
#         'perdida via oral', 'tratamiento encefalopatia',
#         'paracentesis periodicas', 'tratamiento antibiotio iv',
#         'antibioterapia u sueroterapia iv',
#         'control ulceras y tratamiento antibiotico iv',
#         'tratamiento y control evolutivo',
#         'infeccion urinaria tratamiento antibiotico',
#         'curas  y control evolutivo',
#         'tratmiento antibiotico y control evolutivo',
#         'curas amputacion dos dedos pie', 'dolor en columna lumbar',
#         'rectorragia', 'valoracion dolor', 'prostatectomia endoscopica',
#         'posible infeccion urinaria', 'curas lesion tumoral',
#         'habituacion domicilio', 'cuidados  paliativos',
#         'administracion calcio iv', 'dolor lumbar',
#         'rehidratación ir prerrenal',
#         'co0ntrol evolutivo y paracentesis periodicas.',
#         'tratamiento paliativo', 'urocultivo de control',
#         'deterioro general', 'dolor a nivel lumbar',
#         'cuidados de final vida', 'ajuste de tratamientyo',
#         'valoracion por estupor', 'valracion de tratamiento por vahidos',
#         'tratamiento antibioptico iv', 'control dolor abdominal',
#         'trasfusion hematies', 'tratamiento y curas', 'contol de sintomas',
#         'control sde síntomas', 'cuidadosm paliativos',
#         'contrl y trtatamiento', 'uirurgica',
#         'antibioterapia iv y curas c¡quirurgicas',
#         'antibioterapia iv, curas locales',
#         'adiestramiento nutricion y control sintomas',
#         'curas de ulcera y contrl evolutivo', 'valoracion y dolor oidos',
#         'incarceracion hernia', 'valrar encefalopatia',
#         'control de sintpmas', 'tratamiento iv alprostadil',
#         'encefalopatía', 'insomnio', 'amd. de inmunoglobulinas',
#         'sugiran iv', 'vigilancia postoperatorio', 'contrl de sintomas',
#         'control s de síntomas', 'antibioterapia sc', 'furosemida iv',
#         'contrlol de sintomas', 'antibioterapia  sc',
#         'control envolutivo y trtatamiento',
#         'tratamiento antibiotico y control evolitivo', 'control curas',
#         'control sintomatico y tratamioento paliativo',
#         'control y curas de ulceras', 'control analgesico y curas',
#         'cvaloracion dolor y fiebre',
#         'control y cumplimentacion tratamiento antibiotico',
#         'valoracion y diahgnostico', 'valoracion por disfagia',
#         'valoracion por deterioro general',
#         'valoracion y cuidados paliativos',
#         'administracion tratamiento antibiotico', 'convulsiones scffv',
#         'administración alprostadil iv', 'control evolutiva',
#         'antibioterapia iv,control de síntomas', 'dolor rebelde',
#         'control simtomas', 'neumonia tratamiento iv', 'diureticos iv',
#         'taramiento qantibiotico iv', 'furosemida sc',
#         'tratamieto furosemida iv', 'curas ulcera vascular mmii izquierdo',
#         'antibiotico', 'tantibioterapia iv',
#         'recambio peg a boton de alimentacion',
#         'administracion de azacitidina', 'administracion 5 azatadina',
#         'control sintomas y paracentesis evacuadorasa',
#         'curas celulitis eeii izquieda',
#         'control evolutivo y ulceras sacras',
#         'cuidados paliativos avanzados',
#         'paracentesis evacuadoras periodicas',
#         'antibioterapia iv por hemocultivos positivos',
#         'recambio canula traqueostomia', 'ulcera sacra',
#         'control sintomas diureticos iv infusor',
#         'deterioro enfermedad nieman pick',
#         'valoracion ulcera sacra sangrante',
#         'valoracion ulceras de decubito', 'valoracion ulcera sacra',
#         'cambio canula traqueostomia', 'deterioro estado general',
#         'valoración en domicilio', 'cambios canula traqueostomia',
#         'control en domicilio portador vmi nocturna', 'control por itu',
#         'covid', 'paracentesis y control sintomas', 'cuidados pañiativos',
#         'tratamiento furosemida iv', 'curas úlcera',
#         'transfusión,control de síntomas', 'valoración y tratamiento',
#         'tratamiento furosemida sc', 'valoración y tto',
#         'control de sítomas', 'tratamiento y control de síntomas',
#         'cambio cánula traqueotomía', 'control clínico', 'eccema',
#         'final de vida', 'antifúngico iv', 'antibiotico iv, curas by-pass',
#         'recambio pca', 'tratamiento alprostadil', 'tratamiento 5aza',
#         'tratamiento diurético', 'nutrición', 'inmunoglobulinas',
#         'antibioterapia vo', 'tratamiento inmunoglobulinas',
#         'tratamiento con inmunoglobulinas', 'tratamiento diurético iv',
#         'curas ulcera brazo derecho',
#         'curas gastrostomia y antibioterapia',
#         'ncontrol evolutivo y tratamiento',
#         'control evolutivo y cuidados paliativos',
#         'administracion de tratamiento antibiotico iv',
#         'tratmiento antibiortico iv', 'recambio botan de alimentacion',
#         'curas de amputacion 3er dedo pie izquierdo',
#         'curas de hematoma en dorso mano', 'oxigenoterapia', 'diuréticos',
#         'paracentesis periodica', 'tratamiento antibioticom iv',
#         'control sintomas y tratamiento iv',
#         'control de sintomas y tratamiento iv',
#         'control sintomas y ajuste de tratamiento',
#         'deterioro progresivo y descontrol glucemico',
#         'evaluacion de ulceras en eeii', 'tratamiento antiibiotico iv',
#         'valracion y ajuste de tratamiento', 'negativa ingesta oral',
#         'valoración disnea', 'tratamiento.'], dtype=object),
#  array(['si', 'no', None, 'mo', 'nsi', 'o', 'so', 'm'], dtype=object),
#  array(['si', 'no', None, 'ns', 'o', 'nsi', 'm'], dtype=object),
#  array(['no', 'si', 'b', 'ni', 'nsi', 'ssi', None, 'nop'], dtype=object),
#  array(['no', 'si', None, 'nsi'], dtype=object),
#  array(['si', 'no', 'ni', 'nsi'], dtype=object),
#  array(['no', 'si', 'nsi', None, 'mo', 'son'], dtype=object),
#  array(['no', 'estreñimiento', 'mucositis', 'hematuria',
#         'nauseas y vómitos', 'oligoanuria,itu', 'infeccion respiratoria',
#         'tos', 'si, hipotensión', 'si, vómitos', 'edemas, oliguria',
#         'candidiasis orof.', 'agitacion', 'vómitos fecaloideos', 'itu',
#         'exudación herida', 'anemia', 'si, diarrea, mareo', 'sangrado',
#         'diarrea', 'edema lengua', '0clusión intestinal',
#         'insuficiencia respiratoria', 'si,nauseas y vomitos', 'vómitos',
#         'muguet', 'si,vomitos,hematemesis', 'insomnio', 'mialgias', 'hipo',
#         'dolor abdominal', 'inquietud psicomotriz', 'hipotension',
#         'nauseas', 'deterioro cognitivo', 'abdomen agudo', 'ictericia',
#         'retencion urinaria', 'si,retencion urinaria', 'agitacion,panico',
#         'obstruccion intestinal', 'coma profundo', 'comatosa',
#         'tiritona y fiebre', 'vomitos', 'nauseas,vómitos, edema m.inf',
#         'disfagia', 'inquietud', 'nauseas, vómitos, inquietud',
#         'nauseas y vomitos', 'candidiasis oral', 'dolor epigastrico',
#         'disuria y polaquiuria', 'nauseas y diarrea',
#         'infeccion respi.descompensacion cardiaca', 'metrorragias',
#         'tos y expectoración', 'hematuria y gingivorragias', 'agresividad',
#         'sde miccional', 'si, estreñimiento', 'si, vomitos', 'si, edemas',
#         'coma', 'si, disuria', 'si, impotencia funcional',
#         'tos cronica refractaria', 'si, anasarca',
#         'diarrea,deshidratacion', 'si, ictericia', 'sed',
#         'perdida d ela via oral', 'intolerancia oral',
#         'estreñimiento, pacto de silencio', 'si, crisis parciales',
#         'dificultad ingesta oral', 'deterioro funcional',
#         'perdida de la via oral, sed', 'sd confusional', 'angustia',
#         'vomito', 'ascitis', 'acv previo', 'pérdida de peso', 'palidez',
#         'nauseas,vómitos', 'expectoración', 'expect hemoptoica',
#         'edema m.inferiores', 'pus a traves de drenaje percutáneo',
#         'ansiedad-insomnio', 'ulceras presion', 'inquietud y agitacion',
#         'infeccion de pic', 'ulceras de presion', 'mareo', 'ni', 'n o',
#         'derrame pleural', 'negativa a la ingesta',
#         'incontinencia urinaria', 'candidiasis', 'estupor', None,
#         'diabetes', 'ca gastrico', 'perdida de la vía oral',
#         'mal manejo de secreciones, diarrea',
#         'encefalopatia, ascitis, insuficiencia renal', 'rotura de peg',
#         'estreñimiento, ascitis', 'náuseas y vómitos',
#         'inquietud /insomnio s', 'vejiga neurogena. hipersalivacion.',
#         'hemiparesia', 'icc', 'animo depresivo', 'úlcera tumoral',
#         'hematemesis', 'dispepsia por metronidazol oral', 'esclerosis m.',
#         'demencia', 'fractura de cadera  si', 'agitación', 'somnolencia',
#         'depresion reactiva', 'nauseas, vómitos',
#         'tos,expectoración purulenta', 'deterior del nivel de consciencia',
#         'anuria', 'sangrado local', 'perdida de via oral', 'edemas',
#         'hematoma en costado derecho', 'inquietud /insomnio',
#         'hdb, encefalopatia', 's.confusional', 'bajo nivel conciencia',
#         'melenas', 'deterioro estado general,melenas', 'agonia',
#         'ansiedad', 'secreciones bronquiales', 'fallo cardiaco',
#         'mareos y vómitos', 'infeccion urinaria', 'ulceras vasculares',
#         'pancreatitis aguda', 'shock cardiogenico', 'espondilodiscitis',
#         'ca colon', 's. confusional', 'ulceras', 'ascitis,ictericia',
#         'prurito local', 'agitacioón,diarrea', 'vomitos,estreñimiento',
#         'edema m.inf', 'secreciones bronquiales y agitación',
#         'hipo,ansiedad', 'tos improductiva', 'nauseas, ictericia',
#         'sangre en heces', 'declive severo', 'tos,expectoración', 'hta',
#         'insomnio,', 'ulcera presion', 'si', 'lesion quirurgica extensa',
#         'dolo roseo', 'dispepsia', 'nauseas vomitos',
#         'temblor y escalofrios', 'vomitos , diarrea', 'hipercalcemia',
#         'nol', 'broncoaspiracion', 'isquemia pie', 'globo vesical',
#         'dolor', 'hiperglucemia', nan], dtype=object),
#  array(['si', 'no', 'nn', None, nan], dtype=object),
#  array(['no', 'si', 'o', None, 'son', nan], dtype=object),
#  array([nan, '3-4', 'no', '1-2', '2-3', 'si', 'nk', None, 'np', '<70',
#         '4<10', 'o', 'n2-3', 'nop'], dtype=object),
#  array([nan, 'no', '<60', '<10', '<20', '<40', '<50', '<30', '<70', '<80',
#         '40-50', '<95', 'n<20', 'n<80', '30-40', '<90', '50-60', '>20',
#         '<0', '<99', '<120', '<100', '<45', None, 'z30', '>60', '<35',
#         '<450', '>90'], dtype=object),
#  array(['no', nan, '7c', '6-7', '4-5', '3-4', 'n0', 'si', '5-6', '7a',
#         '<20', 'o', 'n5', 'si 5', 'si 4', 'si4', 'si6', 'si7', 'b'],
#        dtype=object),
#  array(['no', nan, '7-8', None, '2-3'], dtype=object),
#  array(['no', 'ulcera sacra', 'edemas', 'child a', 'gold iv', None,
#         'nauseas', 'pap score c', 'pap score a', 'pap score b',
#         'pap score grupo c', 'sospecha de rao', 'agitación',
#         'hipertiroidismo, hiperglucemia, infección respiratoria',
#         'hematuria', 'epistaxis', 'problema social grave',
#         'insuficiencia cardiaca descompensanda resistente al tto diuretico',
#         'ca mama', 'claudicación familiar', 'karnofsky 30',
#         's. confusional', 'colangitis', 'tetraparesia',
#         'fistula recto vesical', 'itu', 'ulceras de presion', 'irc',
#         'ascitis', 'ansiedad', 'dialisis, parkison', 'ira',
#         'esquizofrenia', 'sindrome ansiosodepresivo', 'obesidad', 'ela',
#         'lno', 'toc', 'negativa ingesta', 'crisis de ansiedad', 'melenas',
#         'coma', 'sospecha de itu y ausencia de garantia de cuidador',
#         'diarrea', 'oclusion intestinal', 'disnea', 'tromboflebitis',
#         'insomnio', 'agitacion', 'derrame pleural', 'estreñimiento',
#         'vomitos', 'mucositis', nan], dtype=object),
#  array(['reingreso en urgencias', 'met. pulmonares y digest', 'no',
#         'claud familiar domicilio', 'si, muguet, vómito, cefalea',
#         'fallo cardiaco', 'si, oliguria, fiebre', 'si, disuria',
#         'si, dolor hombro', 'si, agitación', 'si oclusion intestinal',
#         'si,infeccion osteosintesis', 'hematoma pared toracica',
#         'si, sepsis urinaria', 'broncoaspiracion',
#         'colitis pseudomebranosa', 'si, colestasis disociada',
#         'si, retención urinaria', 'asistolia', 'sd confusional',
#         'si,deterioro brusco,claudicación', 'si,claudicacion',
#         'rectorragias', 'infeccion local', 'si,deterioro brusco',
#         'delirium', 'vomitos', 'si,sangrado digestivo,itu', 'si,acv',
#         'infecc respiratoria', 'fractura isquiopubiana', 'si,oclusión',
#         'inf respiratoria', 'si,vomitos', 'oclusión intestinal',
#         'infeccion respiratoria', 'secundarismo opiaceo',
#         'ulceras de presion', 'si,infeccion urinaria', 'si,disnea subita',
#         'agitacion.', 'reingreso por hemocultivos +', 'diarrea',
#         'si,rectorragias', 'paciente en seguimiento por foltra',
#         'realizacion cpre en este ingreso', 'descompensación y reingreso',
#         'edema agudo de pulmon', 'si,insuficiencia respiratoria',
#         'reingreso programado para cpre', 'hematemesis',
#         'parada cardiaca exitus', 'insuficiencia renal,infeccion urinaria',
#         'si,infeccion', 'ictus isquémico transitorio', 'hiperglucemia',
#         'probable infarto', 'itu', 'hepatitis medicamentosa',
#         'si,isquemia intestinal', 'obtruccion intestinal',
#         'insuficiencia respiratoria', 'anemia',
#         'edema labio supy parestesias orales', 'retencion urinaria', 'hta',
#         'debilidad muscular', 'deterioro de su situación clínica',
#         'si, rectorragia', 'si, perdida de via oral', 'si, fiebre',
#         'si, delirium', 'si, caida', 'obstrucción intestinal',
#         'micosis oral', 'si, dolor dorsal, infeccion respiratorias',
#         'si, oclusion intestinal', 'candidiasis orofingea',
#         'perdida via oral', 'hiperglucemias', 'candidiasis orofaringea',
#         'si, tvp', 'si, alucinosis', 'si, artritis por microcristales',
#         'si, hta', 'si, confusion, hiponatremia, hda',
#         'si, retencion urinaria', 'si, epigastralgia', 'si, muguet',
#         'si, fallo cardiaco', 'reingresa en upal', 'si dolor abdominal',
#         'si, diarrea y fiebre', 'deseo reingreso',
#         'si, herida incisocontusa parietal', 'si, extravasación en brazo',
#         'neumotorax, oclusión intestinal', 'rao, sonda vesical',
#         'claudicación familiar', 'fuera de área', 'si, oliguria',
#         'reingreso en centro privado',
#         'fistula entero-vesical, fracaso familiar', 'vómitos fecaloideos',
#         'vomitos fecaloideos', 'protocolo de desconexión',
#         'si, mal control de dolor',
#         'si, muguet, diverticulitis, retencion urinaria',
#         'fracaso familiar en domicilio',
#         'si, infeccion urinaria, rectorragia', 'claudicacion familiar',
#         'diarrea sanguinolenta, dificultad para la via oral',
#         'no desean sonda vesical', 'empeoramiento respiratorio', 'agonia',
#         'angustia, pérdida de la via oral',
#         'disnea, claudicacion familiar',
#         'si, muguet, infeccion respiratoria',
#         'probable tromboembolismo pulmonar', 'sepsis',
#         'infeccion respiratoria, ic', 'claudicacion',
#         'intolerancia alimentaria tras realización recambio peg',
#         'ulceras por presión', 'ictericia obstructiva',
#         'reingreso por claudicacion familiar',
#         'posible infeccion respiratoria, infec urinaria', 'tvp',
#         'esofagitis', 'ictus', 'suboclusión intestinal',
#         'evolución tórpida de las lesiones cutáneas',
#         'infeccion respiratoria/infección cutánea', 'pérdida vía oral',
#         'tvp. infección pimer dedo pié izq', 'hda', 'si,disnea',
#         'dispepsia',
#         'infección respitaria, descompensación cardíaca, posible crisis comicial, sobredosificación dicumarínica, hematoespermia',
#         'ta elevadas', 'si,dolor abdominal',
#         'si proceso infeccioso central', 'si derrame pleural',
#         'desaturacion', 'infeccion ulceras presion',
#         'fallece antes de ser atendida', 'alergia aminoglucosidos',
#         'facies corticoidea', 'disnea brusca', 'disna refractaria',
#         'vómitos y disnea', 'si, sepsis, mal control del dolor',
#         'intervención de presentacion y cortesia',
#         'deterioro del estado general brusco',
#         'ausencia de cuidador por limitación. intervenció social',
#         'insuficiencia renal', 'si, insuficiencia respiratoria',
#         'si, dolor en piernas, rash cutaneo',
#         'obnubilación,estupor, éxitus',
#         'no visto por hado tras ingreso en fin de semana', 'tendinitis',
#         'si, infeccion respiratoria', 'oclusion intestinal',
#         'imposibilidad para realizar paracentesis', 'dificultad via oral',
#         'hipotensión', 'perdida de la via iv',
#         'imposibilidad para la parecentesis',
#         'ventilacion mecanica no invasiva',
#         'lesiones cutáneas tumorales en progresión extrema',
#         'si, sepsis grave', 'lesiones presión y vasculares',
#         'lesiones presion', 'anemizacion', 'isquemia arterial eeii',
#         'dispepsia por metronidazol oral', 'negativa a la ingesta',
#         'fiebre', 'isquemia cerebral transitoria',
#         'disnea durante fin de semana', 'artritis, celulitis, vomitos',
#         'via venosa complicada', 'si, claudicacion',
#         'deterioro del nivel de consciencia', 'transfusion', 'icc',
#         'dolor musculoesquelético', 'pancitopenia, ifec respirat',
#         'diarrea aguda', 'disnea', 'vomitos, intolerancia oral',
#         'itu, rao', 'angustia, disnea, secreciones', 'si,broncoaspiración',
#         'si,fracaso colaboracion con hado', 'dolor mal controlado',
#         'si, claudicación familiar', 'si,claudicacion familiar',
#         'agitación', 'si, disnea', 'encefalopatia uremica', 'si, dolor',
#         'si, ascitis, hdb, pbe, encefalopatia', 'sindrome confusional',
#         's.confusional',
#         'si, insomnio, desgarro uretral insuficiencia renal',
#         'obstruccion intestinal', 'rao, dificultad respiratoria',
#         'sde vena cava sup', 'insuf.renal prerrenal',
#         'absceso pélvico,fístula intestinal,sde compartimental muslo dcho',
#         'encefalopatia hepática',
#         'fiebre, secreciones respiratorias, bajo nivel del consciencia',
#         'fiebre, infección urinaria', 'inquietud',
#         'pancitopenia, sangrado digestivo', 'alteración enzimas hepáticas',
#         'pancreatitis aguda', 'fiebre y diarrea', 'mucositis',
#         'absceso facial', 'hematuria', 'paraparesia', 'sindrome febril',
#         'prostatitis', 'ira', 'retención urinaria',
#         'encefalopatía hepática', 'descompensación diabética',
#         'traumatismo costal izq en su domicilio',
#         'tvp, hematuria postsondaje',
#         'tromboflebitis en territorio safena int izq o colaterales',
#         'posible insuf vertebrobasilar', 'dolor y distensión abdominal',
#         'abdomen agudo', 'hipopotasemia, sobreefecto sintrom',
#         'descompensación glucémica', 'fiebre y taquipnea',
#         'sospecha de compresión medular',
#         'probable broncoaspiración, insuf respiratoria', 'si,caida',
#         'sobredosificación aco', 'fracaso familiar',
#         'infecciones ulceras con celulitis reiteradas',
#         'evolución tórpida de lesión', 'deseo de finalización en hospital',
#         'si', 'dificil colaboracion', 'neutropenia febril',
#         'melenas y hematoquecia',
#         'reingreso por deterioro severo del estado general',
#         'cuidadora única situaciónultimosdias',
#         'reingreso por presunta reaccion alergica',
#         'mesotelioma en pieza operatoria',
#         'sindrome depresivo con manifestaciones psicoticas', 'mno',
#         'no se dispone del antibiotico iv',
#         'lesion ulcerosa compleja y extensa', 'candidiasis', None,
#         'celulitis', 'insomnio', 'dolor abdominal',
#         'oclusion intestinal.claudicacion',
#         'hematemesis edema agudo de pulmon', 'fuera de area',
#         'rectorragia', 'traslado a upal', 'insuficiencia resp aguda',
#         'persiste insuficiencia cardiaca',
#         'si: sobredosificacion opioides', 'dm', 'sincope', 'nuseas',
#         'vertigo', 'herpes zoster', 'perdida via oral. final vida',
#         'edemas', 'fractura patologica', 'persistencia sindrome febril',
#         'hipo refractario', 'oclusion intestinal. vómitos fecaloideos',
#         'mo', 'agitacion psicomotriz', 'colangitis', 'infeccion pulmonar',
#         'sde confusional, crisis comiciales?',
#         'miocardiopatía dilatada, i renal crónica', 'fin de cuidados',
#         'uropatía obstruvtiva,hipertrofia de próstata,fa revertida farmacologicamente',
#         'cura de ulcera', 'edema generalizado', 'nauseas y vómitos',
#         'absceso pared abdominal', 'nauseas', 'hta,diabetes, psicopatia',
#         'peg radiológica', 'vómitos', 'hematuria, disuria',
#         'gingivorragia', 'convulsiones por acv', 'candidiasis oral',
#         'diarrea,estreñimiento,diabetes', 'fistula liquidocefalorraquidio',
#         'disfagia absoluta', 'coma', 'dolor neuropático',
#         'hematuria.cancer vejiga.', 'si,broncoaspiracion',
#         'persistencia infección', 'si.infeccion urinaria',
#         'gota, insuf renal ag', 'si,nauseas y vomitos.estreñimiento',
#         'si,parada cardiorrespiratoria', 'deterioro clinico',
#         'inquietud,insomnio', 'ulcera pierna dcha', 'crisis epileptica',
#         'plaquetopenia', 'infecciones urinarias', 'colitis ulcerosa, hipo',
#         'problema social', 'i. cardíaca, i.renal cr', 'si,rectorragia',
#         'probable broncoaspiración,diarrea', 'ulceras', 'diabetes',
#         'si,agitacion',
#         'bypass axilo monofemoral desde arteria axilar izquierda (1ªporción) (l-t) hasta arteria femoral profunda izquierda (t-l) miembro inferior izquierdo',
#         'pirosis', 'nauseas,vómitos', 'cardiopatia hipertensiva, fa',
#         'curas', 'hemorragia gingival', 'neumonia',
#         'si,infeccion respiratoria', 'curas lesión tumoral abdominal',
#         'si,covid sintomático', 'acv', 'trast. personalidad',
#         'si,infecciones urinarias', 'estenosis gástrica', 'covid',
#         'infeccion', 'ulcera venosa', 'infección covid resuelta',
#         'infeccion ulceras', 'sde miccional', 'diarrea cd',
#         'sangrado lesiones cutáneas',
#         'insuficiencia renal, hidronefrosis bilateral',
#         'hemorragia digestiva', 'hiponatremia', 'hiperosmolaridad',
#         'broncoaspiraciones', 'si,nauseas y vomitos',
#         'esclerosis multiple', 'prurito', 'secreciones broncoaspiraciones',
#         'si,hemorragia digestiva alta', 'si infeccion orina', 'hemoptisis',
#         'negativa a ingesta', 'sde confusional, convulsiones',
#         'encefalopatía, ascitis', 'astenia', 'recambio peg',
#         'ulceras vasculares', 'disminucion del nivel de conciencia',
#         'infeccion herida quirugica',
#         'reingreso por paracentesis hemorragica', 'si,sepsis respiratoria',
#         'si encefalopatia',
#         'claudicacion familiar (conviviente covid positivo',
#         'fractura de cadera', 'celilitis', 'crisis convulsivas',
#         'hiperglucemia-icc', 'ansiedad', 'candidiasis orofaringe',
#         'sd. confusional', 'dolor precordia', 's. confusional',
#         'ileo paralitico', 'sincope ,insuficiencia cardiaca',
#         'infeccion. dolor', 'curas herida quirurgica', 'ucera de presión',
#         'dolor precordial', 'si,infección urinaria', 'infeccion orina',
#         'itu, s. confusional', 'si, infeccion urinaria',
#         'neumonía por aspiración', 'disnea y estertores',
#         'si,fallo multiorganico', 'agitación e insomnio',
#         'fa, miocardiopatía dilatada', 'descompensacion cardiaca',
#         'elevación de transaminasas', 'infección pulmonar',
#         'uropatia obstructiva,anemia.', 'fractura de d12',
#         'dolor mii de probable origen neuropatico',
#         'vómitos, probables emb pulmonares', 'tep',
#         'somnolencia/agitación', 'infección urinaria',
#         'sepsis por cateter', 'ascitis no a tensión', 'ulcera sacra',
#         'flebitis', 'disfagia', 'curas de ulceras', 'sde confusional, upp',
#         'posible toxicidad hepática por ceftriaxona',
#         'fistula rectouretral', 'hta, diabetes mellitus',
#         'dipepsia,alteración emocional', 'mal control del dolor',
#         'epigastralgia y disnea a estudio', 'deterioro cognitivo',
#         'mareos', 'miembro fantasma', 'dialisis tres dias semana',
#         'adenocarcinoma pancreas estadio iv', 'espina bifida',
#         'trasplante renal', 'convulsiones', 'insuficiencia cardiaca',
#         'hernia inguinal dcha incarcerada', 'paralisis supranuclear',
#         'abdomen agudo,neumonia', nan], dtype=object),
#  array(['no', 'si', 'si, morfina, haloperidol, midazolam',
#         'si, midazolam, morfina, buscapina',
#         'si, levomepromazina, midazolam, buscapina, morfina',
#         'si, buscapina, morfina', 'si, morfina, buscapina',
#         'si,midazolam,morfina,buscapina', 'si, buscap,midaz,morf',
#         'si,mid,morf,buscap', 'si, midazolam',
#         'si,midazolan,morh,haloperidol',
#         'si, buscap,midaz,morf,haloperidol',
#         'si,buscap,halop,sinogan,morf,midaz', 'si,busc,mid,morf,halop',
#         'si, morfina, levomepromazina, midazolam, buscapina',
#         'si, buscapina, midazolam, morfina y haloperidol',
#         'si, midazolam, haloperidol, buscapina, morfina',
#         'si, midaz,morf,buscap', 'morf,busc,halop', 'si. midazolan',
#         'si.morf,buscap,midaz', 'si, levomepromazina, midazolam, morfina,',
#         'si, buscap, midazolam, morfina,', 'np',
#         'si,midazolam, morfina, buscapina',
#         'si, buscap, midazolam, morfina,sinogan',
#         'si, buscap, midazolam, haloperidol,morfina,', None,
#         'si,buscap,sonogan,cl mórf,midaz', nan,
#         'si,buscap,midazolam,morfina,', 'si,midz,morf,haloperidol,buscap',
#         'si, buscap, midazolam,morfina,', 'si,cl.mórfico,midazolam',
#         'si,morf+buscap+haloperidol+midaz', 'si,morf+buscapmidaz',
#         'si,morf+buscap+midaz'], dtype=object),
#  array(['reingreso', 'exitus', 'fin de cuidados',
#         'reingreso por urgencias a hado', 'traslado otro centro',
#         'traslado a upal', 'traslado a urgencias',
#         'ingreso en digestivo clínico', 'ingreso para trasplante',
#         'reingreso orl', 'traslado a cpl', 'éxitus',
#         'traslado a oncologia', 'reingreso upal', 'trasladoa upal',
#         'traslado a acv', 'ingreso nml clinico',
#         'petición de la familia de posponer tto', 'traslado a pasliativos',
#         'ingreso en nrl', 'ingreso upal', 'traslado upal',
#         'reingreso en upal', 'residencia sociosanitaria',
#         'reingreso hospitalario', 'reingreso en centro privado', 'tralado',
#         'trasado a urgencias clínico', 'buen control de síntomas',
#         'traslado urgencias clinico', 'ingreso en oncología',
#         'ingreso en nrc', None, 'fin cuidados', 'paso a urgencias',
#         'unidad de algias musculoesqueléticas', 'fin de  cuidados',
#         'reingreso en onc', 'traslado a urgencias del clinico',
#         'sin condiciones para seguimiento hado', 'solicitud familiar',
#         'reingres en upal', 'reingreso.', 'reingreso en neumologia',
#         'cambio de domicilio fuera de área asistencial de hado',
#         'urg e ingreso upal', 'estable en su enfermedad',
#         'traslado a h.gil casares', 'ingreso en upal',
#         'imposibilidad de cuidados en domicilio del paciente por condiciones higienoco-sanitarias inadecuadas',
#         'traslado a hospital privado de agudos por decisión familiar',
#         'no fue dado de alta hospitalaria', 'traslado a urgencias clínico',
#         'traslado a urg clínico',
#         'ingreso en huac para transplante pulmonar',
#         'traslado a urg del clínico', 'traslado urgencias',
#         'traslado a c. paliativos hg casares',
#         'reingreso programado en acv', 'reingreso en urgencias',
#         'reingreso en oncologia', 'claudicacion familiar', 'reingresoupal',
#         'fin de cuidadso', 'traslado mir provincial', 'consulta médica',
#         'ingreso en digestivo', 'ingreso en oncologia',
#         'exitus comunicado por la familia', 'traslado cirugia',
#         'alta paso a urgencias', 'traslado a urgencias tetraparesia',
#         'traslado a urgencias e ingreso en upal',
#         'traslado a urgencias, petición familiar', 'urgencias clinico',
#         'ingreso en mir', 'ingreso en c.plástica', 'traslado a orl',
#         'ingreso mir', 'tto en rtp', 'reingreso programado',
#         'paso a uregencias', 'trasladoa urgencias', 'cuidados ap',
#         'reingreso en mir', 'domicilio', 'ingreso en c.vascular', 'no',
#         'derivado urgencias', 'ingreso cgd', 'alta por paso a urgencias',
#         'traslado a urgencias por covid', 'alta por paso a uregncias',
#         'traslado a urgencias por el 061', 'ingreso en orl',
#         'traslado a urgencias para ingreso mir',
#         'ingreso medicina interna', 'ingreso en utr',
#         'alta paso por urgencias', 'ingreso en medicina interna',
#         'traslado a urgencias.', 'reingreso hospital privado',
#         'ingreso cirugía vascular', 'ingreso onco'], dtype=object),
#  array(['valdes', 'galego feal', 'lopez renedo.', 'villar del castillo',
#         'valcarcel', 'suarez', 'ibáñez alonso', 'fernandez benito', 'masa',
#         'valcárcel', 'suarez prado', None, 'lopez renedo', 'pazo',
#         'masa vazquez', nan, 'beceiro', 'gómez buela', 'novo'],
#        dtype=object),
#  array(['si', 'no', 'np', 'ono', 'son', 'ns'], dtype=object),
#  array([nan, 'no', 'si', 'o', None, 'son'], dtype=object),
#  array([nan, 'no', 'si', 'nsi', 'm'], dtype=object),
#  array([nan, 'no', 'si', 'si 2 concentrados'], dtype=object),
#  array([nan, 'no', 'si'], dtype=object),
#  array([nan, 'no', 'si', None], dtype=object),
#  array([nan, 'santiago', 'brion', 'lalin', 'ames', 'negreira', 'teo',
#         'padron', 'rois', 'a baña', 'oroso', 'ordenes', 'trazo',
#         'la estrada', 'o pino', 'touro', 'boqueixon', 'estrada', 'vedra',
#         'tordoya', 'val do dubra', 'dodro', 'valga', 'santa comba',
#         'pontecesures', 'pontecesuras', 'santiago de compostela',
#         'santiago compostela', 'silleda', 'sionlla', 'lousame', 'frades',
#         'pontevea', 'tordoia', 'brión', 'a estrada', None, 'rianxo',
#         'noia', 'noya', 'ordes', 'losame', 'padrón', 'santiago de com',
#         'sigueiro', 'lalín', 'vila de cruces', 'boqueixón', 'ortoño'],
#        dtype=object),
#  array([nan, '2022-08-11', '2022-06-03', '2022-06-07', '2022-09-13',
#         '2022-08-13', '2022-07-04', '2022-09-02', '2022-10-26',
#         '2022-10-25', '2022-10-24', '2022-11-03', '2022-11-04',
#         '2022-09-26', '2022-07-07', '2022-05-19', '2022-08-02',
#         '2022-08-12', '2022-08-24', '2022-07-11', '2022-07-25',
#         '2022-07-30', '2022-08-01', '2022-09-08', '2022-09-19',
#         '2022-09-21', '2022-09-27', '2022-09-30', '2022-10-31',
#         '2022-06-10', '2022-06-16', '2022-07-15', '2022-10-03',
#         '2022-11-07', '2022-11-08', '2022-06-23', '2022-07-28',
#         '2022-08-08', '2022-09-22', '2022-10-19', '2022-05-30',
#         '2022-02-20', None, '2022-07-18', '2022-05-11', '2022-07-10',
#         '2022-08-30', '2022-07-19', '2022-05-12', '2022-06-28',
#         '2022-07-05', '2022-07-26', '2022-06-21', '2022-06-27',
#         '2022-06-22', '2022-01-11', '2022-03-03', '2022-03-06',
#         '2022-03-30', '2022-05-06', '2022-06-06', '2022-06-17',
#         '2022-06-26', '2022-07-01', '2022-07-09', '2022-07-21',
#         '2022-07-22', '2022-08-10', '2022-08-16', '2022-08-17',
#         '2022-08-18', '2022-08-20', '2022-08-31', '2022-09-01',
#         '2022-05-09', '2022-06-05', '2022-07-14', '2022-08-03',
#         '2022-02-25', '2022-06-08', '2022-06-29', '2022-08-04',
#         '2022-08-22', '2022-10-07', '2022-09-16', '2022-10-20',
#         '2022-06-15', '2022-07-29', '2022-10-17', '2022-08-09',
#         '2022-08-14', '2022-08-19', '2022-09-20', '2022-10-11',
#         '2022-09-09', '2022-09-06', '2022-09-05', '2022-06-20',
#         '2022-07-23', '2022-10-04', '2022-10-05', '2022-08-21',
#         '2022-07-20', '2022-08-29', '2022-10-14', '2022-03-17',
#         '2022-04-25', '2022-05-22', '2022-10-27', '2022-11-02',
#         '2022-04-12', '2022-10-18', '2022-03-10', '2022-04-27',
#         '2022-05-02', '2022-05-05', '2022-05-18', '2022-08-26',
#         '2022-09-29', '2022-04-05', '2022-05-07', '2022-05-27',
#         '2022-03-25', '2022-07-13', '2022-09-15', '2022-05-03',
#         '2022-09-12', '2022-09-25', '2022-03-14', '2022-03-28',
#         '2022-07-31', '2022-04-04', '2022-08-05', '2022-03-22',
#         '2022-03-29', '2022-04-11', '2022-04-28', '2022-05-16',
#         '2022-09-03', '2022-07-12', '2022-06-01', '2022-08-25',
#         '2022-08-23', '26/09722', '2022-06-30', '20/09722', '2022-06-14',
#         '2022-07-27', '2022-09-23', '2022-10-10', '2022-06-09',
#         '2022-09-17', '2022-03-23', '2022-04-18', '2022-06-13',
#         '2022-09-07', '2022-09-28', '2022-10-06', '2022-10-21',
#         '2022-10-28', '2022-10-16', '2022-06-25', '2022-10-09',
#         '2022-05-13', '2022-10-13', '2022-03-24', '2022-06-19',
#         '2022-06-12', '2022-07-08', '2022-08-15', '2022-11-09',
#         '2022-11-10', '2022-10-30', '2022-11-14', '2022-11-16',
#         '2022-11-15', '2022-11-17', '2022-11-18', '25/1022', '2022-11-20',
#         '2022-11-21', '2022-11-22', '2022-11-23', '2022-11-24',
#         '2022-11-25', '0022-11-23', '2022-11-26', '2022-11-28',
#         '2022-11-29', '2022-11-13', '2022-12-01', '2022-11-30',
#         '2022-11-11', '2022-11-05', '30/114/22', '2022-12-02',
#         '2022-12-05', '2022-12-09', '2022-12-11', '2022-12-07',
#         '2022-09-14', '2022-12-12', '2022-12-14', '2022-12-19',
#         '2022-12-16', '2022-12-17', '2022-12-20', '2022-12-13',
#         '2022-12-15', '2022-12-21', '2022-12-23', '2022-12-22', '26/12722',
#         '2022-12-27', '2022-12-26', '2022-12-28', '2022-12-29',
#         '2022-12-25', '2022-12-30', '2022-12-31'], dtype=object),
#  array([nan, 'no', 'si', None], dtype=object),
#  array([nan, 'no', 's'], dtype=object)]

# %%
# Abrir archivo en modo escritura
with open('valores_concatenado.txt', 'w') as file:
    # Escribir los valores únicos de cada columna en el archivo
    for column in df_concatenado_columns:
        unique_values = df_concatenado[column].unique()
        file.write(f'{column}: {unique_values}\n')

# Cerrar archivo
file.close()

# %%
df_concatenado['ap'].unique()
# Out:
# array(['no', 'si', 'pac', None, 'ap', 'mo', 'consulta externa', 'uro',
#        'residencia'], dtype=object)

# %%
# helpful modules
import fuzzywuzzy
from fuzzywuzzy import process
import chardet

# %%
def get_matches(query, data , column, limit=100):
    data = data[column].unique()
    matches = fuzzywuzzy.process.extract(query, data, limit=limit,scorer=fuzzywuzzy.fuzz.token_sort_ratio)
    return matches

# %%
get_matches(query='cirugia', data= df_concatenado, column= 's_procedencia')
# Out:
# [('urg-cirugia', 78),
#  ('neurocirugia', 74),
#  ('cirugia vasc', 74),
#  ('cirugía torácica', 67),
#  ('cirugia general', 64),
#  ('cirugia vascular', 61),
#  ('cirugia cardiaca', 61),
#  ('cirugia plastica', 61),
#  ('cirugia toracica', 61),
#  ('crg', 60),
#  ('cadiologia', 59),
#  ('cardiologia', 56),
#  ('mirg', 55),
#  ('cirugía vascular', 55),
#  ('upia', 55),
#  ('cirugía cardiaca', 55),
#  ('urologia', 53),
#  ('reumatologia', 53),
#  ('umap-mir', 53),
#  ('cirugia maxilofacial', 52),
#  ('oncologia', 50),
#  ('urgencias', 50),
#  ('traumatologia', 50),
#  ('cee nefrologia', 48),
#  ('endocrinologia', 48),
#  ('nefrologia', 47),
#  ('neumologia', 47),
#  ('neurologia', 47),
#  ('cardiología', 47),
#  ('c.cardiaca', 47),
#  ('c. toracica', 47),
#  ('trauma', 46),
#  ('ccee neumologia', 45),
#  ('neeumologia', 44),
#  ('cgd/urg', 43),
#  ('onc-urg', 43),
#  ('urg-onc', 43),
#  ('onc/urg', 43),
#  ('urg/urg', 43),
#  ('c.externas neumologia', 43),
#  ('urg nrl', 43),
#  ('urg acv', 43),
#  ('onc urg', 43),
#  ('urg onc', 43),
#  ('tramatologia', 42),
#  ('radioterapia', 42),
#  ('mir', 40),
#  ('dig', 40),
#  ('urg', 40),
#  ('tra', 40),
#  ('cgd', 40),
#  ('car', 40),
#  ('ncr', 40),
#  ('ccee mir', 40),
#  ('onco-urg', 40),
#  ('reu', 40),
#  ('mir-lugo', 40),
#  ('gin', 40),
#  ('vascular', 40),
#  ('digstivo', 40),
#  ('cpr', 40),
#  ('mir conxo', 38),
#  ('digestivo', 38),
#  ('angiología', 38),
#  ('mir provincial', 38),
#  ('cvascular', 38),
#  ('c.plástica', 38),
#  ('nemologia', 38),
#  ('endocrino', 38),
#  ('nefrología', 38),
#  ('upal', 36),
#  ('mirp', 36),
#  ('umap', 36),
#  ('card', 36),
#  ('gine', 36),
#  ('mirc', 36),
#  ('ccar', 36),
#  ('utab', 36),
#  ('neomologia', 35),
#  ('unidad ela', 35),
#  ('medicina interna', 35),
#  ('c.vascular', 35),
#  ('c. vascular', 35),
#  ('diagestivo', 35),
#  ('ginecología', 35),
#  ('urg trauma', 35),
#  ('hematologia', 33),
#  ('urgrn', 33),
#  ('infecciosas', 33),
#  ('mirhp', 33),
#  ('mir p', 33),
#  ('radtp', 33),
#  ('hepatologia', 33),
#  ('neurologia – consultas externas', 33),
#  ('mir-p', 33),
#  ('rehab', 33),
#  ('mir gil casares no', 32),
#  ('consulta mir', 32),
#  ('respiratorio', 32),
#  ('mirpro', 31)]

# %%
# get the top 10 closest matches to "string"
matches = fuzzywuzzy.process.extract("gil casares", df_concatenado['h_procedencia'].unique(), limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)

# take a look at them
matches
# Out:
# [('gil casares', 100),
#  ('salnes', 47),
#  ('san rafael la coruña', 40),
#  ('quiron la coruña', 38),
#  ('residencia', 38),
#  ('lucus augusti', 33),
#  ('rosaleda', 32),
#  ('si', 31),
#  ('provincial', 29),
#  ('hcg', 29)]

# %%
# function to replace rows in the provided column of the provided dataframe
# that match the provided string above the provided ratio with the provided string
def replace_matches_in_column(df, column, string_to_match, min_ratio = 90):
    # get a list of unique strings
    strings = df[column].unique()
    
    # get the top 10 closest matches to our input string
    matches = fuzzywuzzy.process.extract(string_to_match, strings, 
                                         limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)

    # only get matches with a ratio > 90
    close_matches = [matches[0] for matches in matches if matches[1] >= min_ratio]

    # get the rows of all the close matches in our dataframe
    rows_with_matches = df[column].isin(close_matches)

    # replace all rows with close matches with the input matches 
    df.loc[rows_with_matches, column] = string_to_match
    
    # let us know the function's done
    print("All done!")

# %%
replace_matches_in_column(df = df_concatenado, column = 'h_procedencia', string_to_match = "no")
# Out:
# All done!

# %%
# Guardar una copia en csv de los datos concatenados en data

df_concatenado.to_csv(path_or_buf= "./data/HADO_concat.csv", sep="^")

# %%
from thefuzz import fuzz
from thefuzz import process

# %% [markdown]
# Para realizar un análisis de los diagnósticos principales en Python, se pueden seguir los siguientes pasos:
#
# 1. Cargar los datos: se deben cargar los datos que contienen los diagnósticos de los pacientes en un objeto de Pandas DataFrame.
#
# 2. Limpiar y preprocesar los datos: es importante revisar y limpiar los datos, identificar y eliminar duplicados, y transformar los datos a un formato uniforme y consistente.
#
# 3. Identificar los diagnósticos principales: para identificar los diagnósticos principales, se pueden utilizar diferentes técnicas, como el conteo de frecuencias, la agrupación de diagnósticos similares o el uso de modelos de aprendizaje automático para la clasificación.
#
# 4. Realizar un análisis exploratorio: una vez identificados los diagnósticos principales, se puede realizar un análisis exploratorio para identificar patrones y relaciones con otras variables, utilizando gráficos, tablas y estadísticas descriptivas.
#
# 5. Aplicar técnicas de minería de datos: para profundizar en el análisis, se pueden aplicar técnicas de minería de datos, como el análisis de asociación o la modelización predictiva, para identificar patrones y relaciones más complejas.
#
# 6. Presentar los resultados: finalmente, se deben presentar los resultados de manera clara y comprensible, utilizando gráficos, tablas y estadísticas relevantes.

# %%
df_concatenado['diagnostico'].unique().tolist()
# Out:
# ['ca orl',
#  'melanoma vulvar',
#  'ca broncogenico',
#  'cirrosis hepatica',
#  'neplasia de mama estadio iv',
#  'anemia',
#  'adenoca de pulmon',
#  'leucemia linfatica cronica',
#  'fx meseta tibial',
#  'cancer de mama',
#  'cancer de prostata',
#  'deterioro estado general',
#  'cancer próstata',
#  'tumor cerebral',
#  'adenoca colon iv',
#  'ca prostata',
#  'cancer colon',
#  'ca próstata',
#  'neumonia',
#  'niemann-pick',
#  'sarcoidosis',
#  'ca mama',
#  'cancer pancreas',
#  'infección urinaria, fallo cardiaco',
#  'melanoma fosa nasal',
#  'ca timo',
#  'infeccion respiratoria',
#  's.down',
#  'bocio intratoracico',
#  'sepsisi respiratoria',
#  'intolerancia oral',
#  'infeccion urinaria',
#  'esclerosis múltiple',
#  'demencia, fallo multiorganico',
#  'cancer de parotida',
#  'itu',
#  'úlceras mmii',
#  'smd',
#  'cancer de cólon estadio iv',
#  'fractura cadera',
#  'infección respiratoria',
#  'fallo cardiaco',
#  'infec resp',
#  'ca. endometrio',
#  'cancer suprarrenal',
#  'amputación',
#  'fractura vertebral',
#  'ca. prostata',
#  'acv',
#  'ulceras vasculares',
#  'epoc e infección respiratoria',
#  'infección herida quirúrgica',
#  'hsa',
#  'deteriorocognitivo',
#  'deterioro cognitivo',
#  'miocardiopatia hipertrófica',
#  'sindrome general',
#  'masa abdominal',
#  'hepatopatia cronica',
#  'politraumatismo',
#  'melanoma',
#  'epoc, infección respiratoria',
#  'adenoca. recto',
#  'ca. de sigma',
#  'cancer de vejiga',
#  'ictus',
#  'fa. valvulopatia aortica, ic',
#  'sindrome febril, irc',
#  'diverticulitis aguda',
#  'ca.epidermoide labio',
#  'itu asintomática',
#  'sifilis terciaria, cardiopatia congenita',
#  'craneofaringioma',
#  'mieloma multiple',
#  'endocarditis',
#  'ca. pulmon',
#  'oclusion intestinal',
#  'isquemia eeii',
#  'ca. colon',
#  'lma',
#  'sepsis urinaria',
#  'amputacion transmetatarsiana',
#  'ca. sigma',
#  'ca vejiga',
#  'cancer gastrico',
#  'tratamiento antibiotico iv',
#  'demencia',
#  'e.l.a',
#  'ca. gastrico',
#  'bronquiectasias',
#  'insuficiencia cardiaca',
#  'cancer de lengua estadio iv',
#  'carcinoma de sigma',
#  'infeccion bronquiectasias',
#  'colangiocarcinima',
#  'infeccion material',
#  'ca pulmon estadio iv',
#  'fractura d-12',
#  'ucera mid',
#  'ca endometrio',
#  'broncoaspiracion',
#  'fibrosis pulmonar',
#  'cancer de pancreas',
#  'anciano fragil',
#  'cancer de esofago',
#  'adenocarcino colon estadio iv',
#  'neo recto infeccion respiratoria',
#  'linfoma hodking',
#  'deterioro estado general trastorno metabolico',
#  'ela',
#  'infeccion respiratoria. alzheimer',
#  'infeccion herida quirurgica',
#  'cancer de colon',
#  'trombocitemia esencial',
#  'neo colon',
#  'anemia cronica.neo colon',
#  'adenocarcinoma de ovario estadio iv',
#  'anemia proceso cronico demencia',
#  'alzheimer.tromboembolismo pulmonar',
#  'tumor vesical',
#  'ulceras en miembro inferior derecho',
#  'hepatocarcinoma estadio iv',
#  'linfoma bajo grado',
#  'deteriioro cogitivo grave',
#  'anoxia cerebral',
#  'ca pancreas',
#  'sindrome mielodisplasico',
#  'deterioro cognitivo, neumonia',
#  'lmmc',
#  'gastroenteritis',
#  'bronquiectasias infectadas',
#  'ca epidermoide sien estadio iv',
#  'cáncer de pulmon',
#  'bronquiectasias sobreinfectadas',
#  'cancer de recto',
#  'síndrome mielodisplásico',
#  'cancer urotelial',
#  'talasemia.síndrome anemico',
#  'infeccion urinaria hemorragia digestiva',
#  'neoplasia rectosepsi urinaria',
#  'insuficiencia cardiaca descompensada',
#  'deterioro cognitivo avanzado',
#  'masa abdominal anexial',
#  'arteriopatia obliterante generalizada',
#  'cancer orl',
#  'glioblastoma',
#  'esquizofrenia.anciano frágil',
#  'ca laringe',
#  'ca de mama',
#  'cancer de vulva',
#  'cancer de pulmon',
#  'cancer ce cavum',
#  'enfermedad charcot',
#  'loes snc',
#  'colangitis',
#  'sarcoma indiferenciado en progresion',
#  'neoplasia renal con metastasis hepaticas y pulmonares',
#  'parkinson',
#  'adenocarcinoma prostata estadio iv',
#  'neoplasia pancreas',
#  'adenocarcinoma gastrico estadio iv',
#  'neoplasia pulmonar, cirrosis',
#  'amputacion y ulceras pie izquierdo',
#  'adenocarcinoma colñom estadio iv',
#  'adernocarcinoma gastrico estadio iv.',
#  'adenocarcinoma recto estadio iv',
#  'adenocarcinoma ovarico estadio iv',
#  'neoplasia vejiga estadio iv',
#  'neoplasia recto.acv.borncoaspiracionº',
#  'glioblastoma multiforme',
#  'sepsis urinaria,anciano fragil',
#  'insuficiencia cardiaca. llc atipica',
#  'oclusión intestinal. esquizofrenia paranoide',
#  'ca esofago',
#  'ca ovario',
#  'ca gastrico de  lauren',
#  'ca de pancreas estadio iv',
#  'deshidratacion',
#  'adenocaercinoma colon estadio iv',
#  'neoplasia colon estadio iv',
#  'ca sigma. met hepáticas',
#  'sde mielodisplasico',
#  'neumonia. deterioro cognitivo',
#  'broquiectasias',
#  'leucemia aguda',
#  'ca epidermoide senos paranasales',
#  'sospecha ca tiroides',
#  'ca colon estadio iv',
#  'meningitis postoperatoria',
#  'vomitos.neo recto estadio iv',
#  'ulceras multiples',
#  'itu. klebsiella. transplante renal',
#  'itu. klebsiella.',
#  'rectorragia',
#  'neo biliar',
#  'epidermoide paranasales',
#  'osteomielitis vertebral',
#  'ca cervix est figo iv b',
#  'ca renal estadio iv',
#  'hepatocarcinoma',
#  'itu. hepatopatía crónica',
#  'timoma. miastenia gravis',
#  'leucemialinfática aguda',
#  'tumor malar',
#  'pielonefritis',
#  'carcinoma de próstata',
#  'recambio peg',
#  'cancer páncreas',
#  'cancer cavidad oral',
#  'cancer cae',
#  'fpi',
#  'sindrome febril',
#  'cancer gástrico',
#  'talasemia',
#  'ca cavum e infeccion nosocomial',
#  'ca ocario estadío iv',
#  'cancer vesicula',
#  'adenoca pulmón',
#  'cancer boca, mama y esófago',
#  'ca  pulmon',
#  'adenoca ciego',
#  'demencia severa',
#  'diverticulitis',
#  'hidrocefalia obstructiva.adenoca colon',
#  'cancer gástrico est iv',
#  'ca trecto est iv. met. pulm y cerebrales',
#  'peg',
#  'cancer ovario',
#  'cancer pulmon',
#  'linfoma folicular',
#  'cancer vagina y recto',
#  'espondilodiscitis',
#  'hematoma infectado',
#  'lnh',
#  'anorexia',
#  'arteriopatia ulceras cardiopatia',
#  'miastenia.bronquiectasias infectadas',
#  'ulcera eeii',
#  'diverticulitis no complicada',
#  'mieloma',
#  'demencia fast 7',
#  'denencia cuerpos lewy',
#  'anemia con rasgo talasemico',
#  'perforacion recto por isquemia',
#  'colostomia curas',
#  'adenocarcinoma de esofago',
#  'leucemia mielode aguda',
#  'fibrosis pulmonar idiopatica',
#  'anemia multifactorial',
#  'encefalopatia anoxica',
#  'cancer de ovario',
#  's mielodisplasico',
#  'colangiocarcinoma',
#  'deterioro cognitivo 6-7',
#  'tetraplejia',
#  'ca recto estadio iv',
#  'adenica biliar/pancreático',
#  'e. parkinson',
#  'enf de charcot, infección de herida quirúrgica',
#  'ca cervix',
#  'cancer parotida en progresion',
#  'endocaditis baceriana',
#  'cancer de sigma e iv',
#  'deterioro cognitivo severo',
#  'anemia ferropénica',
#  'esclerosis multiple',
#  'acv y deterioro cognitivo',
#  'sidrome de anciano fragil',
#  'demencia grave',
#  'deterioto cognitivo',
#  'tumor snc',
#  'artritis reumatoide',
#  's. ansioso depresivo',
#  'hemotorax',
#  'bronquiolis infecciosa',
#  'adenocarcinoma de pancreas',
#  'anemia ferropenica',
#  'enfermedad de parkinson',
#  'adenocarcinoma de pulmon',
#  'acv isquemico',
#  'adenocarcinoma anillo de sello',
#  'absceso',
#  'smd/lma',
#  'ca esofago e iv',
#  'demencia avanzada, obstrucción intestinal',
#  'acv, sng',
#  'ca indiferenciado de pulmón',
#  'ulceras por decubito',
#  'ca riñon estadio iv',
#  'linfoma no hodking',
#  'lnhg',
#  'ulcera sacra grado iv',
#  'broncoaspiración',
#  'adenocarcinoma de colon estadio iv',
#  'adenocarcinoma de sigma',
#  'carcinoma microcitico de pulmon estadio iv',
#  'epoc',
#  'brnquiectasias',
#  'adenocarcinoma gastrico',
#  'adenocarcionoa de prostata',
#  'infeccioón respiratoria',
#  'lmc/smd',
#  'ulceras mmii',
#  'acdenocarcinoma prostata estadio iv',
#  'infeccion respiratoria,ela',
#  'adenocarcinoma endometrial',
#  'adenocarcinoma de recto estadio iv',
#  'tumor ovárico',
#  'cirrosis',
#  'adenoca de colon',
#  'colangiocarcinoma est iv',
#  'sde anciano fragil,insuf cardiaca, inf respirat, reagudiz insuf renal',
#  'adenoca de recto',
#  'carcinoma suelo boca en control sintomas',
#  'ca epidermoide cervix',
#  'cirrosis biliar primaria',
#  'neoplasia suelo de la boca',
#  'dolor abdominal',
#  'ca epidermoide pulmón',
#  'sde mielodisplásico',
#  'arteriopatia periferica, sde metabólico, f. auricular',
#  'cancer colorrectal est iv',
#  'deterioro cognitivo severo. ca vejiga',
#  'ca colon.lnh.silicosis',
#  'miocardiopatia dilatada.icc.cirrosis hepática',
#  'diverticulitis aguda no complicada',
#  'colangitis ag, coledocolitiasis',
#  'ca pulmon,epoc,bronquiectasias',
#  'deterioro estado general,fr cadera',
#  'ca endometrio,ca colon',
#  'ca colon est iv',
#  'ca colorrectal est iv',
#  'osteoartrosis rodilla dcha, artroplastia total',
#  'infección respiratoria. ictus',
#  'dehiscencia herida quirúrgica.arteriopatía periférica.sde metabólico',
#  'endocarditis bacteriana',
#  'úlceras por presión. paraplejia',
#  'ca mama est iv',
#  'cancer de pulmón',
#  'leucemia linfoide',
#  'anemia crónica no filiada',
#  'ca de colon est iv',
#  'itu. ca renal intervenido',
#  'fr de tibia intervenida',
#  'neumonia. epoc agudizado. insuf cardíaca',
#  'infec respiratoria.suboclusión intestinal.ca recto.',
#  'miocardiopatia hipertrófica.icc.prótesis valvulares',
#  'insuf renal aguda',
#  'infec urinaria versus intestinal',
#  'infec urinaria. ca riñon',
#  'absceso supravesical. enf de crohn',
#  'colonizacion bronquial p. aeruginosa',
#  'cancer seno paranasal',
#  'cancer de laringe',
#  'sepsis respiratoria',
#  'absceso mano',
#  'leucemia',
#  'upp. paraplejia',
#  'carcinoma celulas merkel',
#  'demencia vascular',
#  's. de alzheimer',
#  'itu.ca próstata. hepatopatia crónica',
#  'infección respiratoria y/o urinaria. deterioro cognitivo severo',
#  'ca mama estadio iv',
#  'neoplasia gastrica estadio iv',
#  'celulitis eeii',
#  'agudizacion epocº',
#  'neo recto estadio iv',
#  'ca maama estadio iv',
#  'ineumonia basal izquierda',
#  'pluripatologia',
#  'demencia fast7',
#  'insuficiencia cardiaca refractaria',
#  'neoplasia esofago estadio iv',
#  'infeccion urinaria por blea',
#  'infeccion por blea',
#  'astrocitoma',
#  'demencia cuerpos lewy fast 7',
#  'demencia avanzada fast 7c',
#  'ca gastrico estadio iv',
#  'ca urotelial estadio iv',
#  'erisipela',
#  'sindrome mieloproliferatico progresion a leucemia',
#  'adenocarcinoma pancreas',
#  'pie diabetico ulceras',
#  'ca endometrio estadio iv',
#  'ca ovario estadio iv',
#  'demencia senil',
#  'sindrome down obesidad saos',
#  'fractura de cadera',
#  'síndrome anciano frágil con set',
#  'infección heridas quirúrgicas',
#  'ca mamam estadioiv',
#  'insuficiencia respiratoria',
#  'dolor inguinal',
#  'control dolor',
#  'discitis',
#  'ulceras de mal conmtrol en eeii',
#  'ca recto dehiscencia colostomia',
#  'encefalopatia postanoxica',
#  'ca de recto est iv',
#  'anaplasico de tiroides',
#  'cancer de pulmon estadio iv',
#  'enfermedad de pompe',
#  'ca colon iv',
#  'absceso pie',
#  'deterioro cognitivo avanzado. let',
#  'absceso renal',
#  'celulitis en eeii',
#  'cancer de endometrio75',
#  'síndrome mielodisplasico',
#  'síndrome anémico',
#  'ca sigma',
#  'ca urotelial eiv',
#  'demencia senil avanzado',
#  'ca cavidad oral intervenido',
#  'cirrosis, hepatoca',
#  'tumor pelvico',
#  'deterioro cognictivo avanzado',
#  'i.cardiaca',
#  'insuficiencia cardio respiratoria',
#  'ca orl y pulmon',
#  'insuficiencia cardiorespiratoria',
#  'cancer de endometrio',
#  'itu. cirrosis',
#  'cirrosis . colonizado por bleas',
#  'cirrosis. itu',
#  'nieman-pick',
#  'neumonia nosocomial',
#  'itu.',
#  'infeccion respiratoeia, ic',
#  'hepatocarcinoma e-iv',
#  'talasemia en anciano fragil',
#  'dolor',
#  'proceso linfoproliferativo',
#  'masa pulmonar',
#  'epoc, masa pulmonar',
#  'síndrome de anciano fragil',
#  'carcinomatosis peritoneal, demencia',
#  'tetraparesia, itu, sonda vesical permanente',
#  'cancer de páncreas',
#  'insuficiencia respiratoria crónica',
#  'ca duodeno',
#  'ca pulmon',
#  'colangiocarcinoma,tumor renal',
#  'adenocarcinoma de endometrio',
#  'ca mamaest iv, epoc grave',
#  'itu. paraplejía',
#  'infeccion protesis',
#  'itu.incont urinaria. ca cuello uterino',
#  'fungemia',
#  'carcinoma de vesicula',
#  'sepsis de origen respiratorio',
#  'septicemia',
#  'icc. hematoma mmii',
#  'colangiocarcinoma.',
#  'carcinomatosis peritoneal',
#  'sde anciano frágil',
#  'adenoca ovario',
#  'diverticulitis aguda complicada (perforación)',
#  'estenosis del canal lumbar',
#  'insuficiencia renal',
#  'alzheimer',
#  'ca pulmón est iv,ca próstata est iv',
#  'ca prostata est iv',
#  'ciatalgia',
#  'ca de prostata',
#  'infeccion postquirúrgica artrodesis cv',
#  'itu. d.mellitus. acv',
#  'infección artroplastia hombro izq',
#  'piomiositis, bacteriemia marsa',
#  'espondilodiscitis, anemia, irc',
#  'itu. sondaje vesical permanente',
#  'artropatia degenerativa',
#  'masa pelvica, carcinomatosis, ascitis',
#  'adenoca pulmon',
#  'masa ovarica. carcinomatosis',
#  'hombro doloroso traumatico',
#  'cancer de utero',
#  'sindrome anemico',
#  'polimiositis',
#  'insuficiencia renal, deterioro cognitivo',
#  'caner de mama estadio iv',
#  'bnmc',
#  'herniorrafia inguinal',
#  'anemia aguda',
#  'anemia cronica',
#  'ulcera diabetica pie',
#  'infeccion klebsiella multirresistente',
#  'endocarditis bacteriana.osteosarcoma femur',
#  'pielonefritis aguda',
#  'bornquiectasias infectadas, asma',
#  'adenoca recto',
#  'ca epidermoide labio sup',
#  'ca colon, mx endobronquial',
#  'ca sigma est iv',
#  'sarcoma fusocelular muslo dcho est iv',
#  'sd noonan. celulitis',
#  'e. parkinson avanzada',
#  'ulcera vascular sobreinfectada',
#  'anciana fragil',
#  'osteomielitis',
#  'neumonia, pancitopenia',
#  'metastasis múltiples',
#  'adenocarcinoma de ciego estadio iv',
#  'cancer pulmón',
#  'ca páncreas',
#  'ca cólon',
#  'adeno pancreas estadio iv',
#  'alteracion deglucion pluripatologico',
#  'microcitico pulmon estadio iv',
#  'hepatocarcinoma encefalopatia',
#  'parkinson demencia avanzada fast 7c',
#  'ca prostata celulitis subcutanea eeii',
#  'linfoma no hodgkin',
#  'cancer deprimario desconocido',
#  'síndrome de anciano frágil en situación de final de vida',
#  'neoplasia ginecologia, carcinomatosis, fistula enterovaginal',
#  'nefroangioesclerosis',
#  'neumonia bilateral',
#  'carcnoma de pulmon',
#  'bacteriemia',
#  'carcinoma de recto',
#  'carcinoma de vejiga',
#  'carcinoma de colon',
#  'ca tiroides',
#  'adenoca gastrico',
#  'ca prostata. hematuria',
#  'demencia, alt comportamiento perdida de la via oral',
#  'carcinoma de mama',
#  'ca.pulmón',
#  'adenoca gástrico',
#  'dolor abdominal no filiado',
#  'epoc terminal',
#  'adenoca de pulmón estadio iv',
#  'ca indiferenciado est iv',
#  'ca de recto',
#  'secuelas tras tce, estenosis ao severa, deterioro cognitivo grave',
#  'ca prostata estadio iv',
#  'ca hepatobiliar estadio iv',
#  'ca pulmón est iv',
#  'colonizacion por klebsiela',
#  'ca suelo de boca est iv',
#  'paciente pluripatologico',
#  'ca renalestadio iv',
#  'ca gastrica',
#  'sospecha acv,enfermedad de alzheimer',
#  'ca próstata est iv',
#  'infeccion broncoaspirativa,parkinson,deterioro cognitiva',
#  'icc,bacteriemia por estafilococo, htp, ascitis, insuf renal',
#  'cancer intestinal',
#  'celulitis mimbro inferior',
#  'deterioro cognitivo severo, enf parkinson',
#  'neumonia neumococica bilateral, colangiocarcinoma',
#  'infeccion protesis hombro',
#  'infeccion broncoaspirativa',
#  'ca epidermoide de esofago',
#  'demencia avanzada',
#  'fracturas craneales',
#  'epoc agudizado',
#  'salmonellosis',
#  'i.cardiaca refractaria',
#  'sindrome anciano fragil',
#  'anciano pluripatologico',
#  'cancer de gastrico estadio iv',
#  'tce',
#  'neoplasia recto estadio iv',
#  'isquemia arterial mmii',
#  'adenocarcinoma de mama estadio iv',
#  'ulcera traumatica',
#  'colangitis de repeticion',
#  'adenoma hipofisis',
#  'ca endometrio e iv',
#  'neo gastrica estadio iv',
#  'probable infeccion urinaria',
#  'prostatis',
#  'cardiopatia refractaria',
#  'insuficiencia renal crónica',
#  'ulcera infectada',
#  'masa anexial',
#  'bocio endotoracico',
#  'sindrome confusional',
#  'adenocarcinoma de pulmon estadio iv',
#  'linfoma t cutaneo',
#  'adenoca de prostata',
#  'ca pulmon est iv',
#  'itu.deterioro cognitivo severo. sospecha neoplasia pulmón',
#  'cirrosis hepática, insuf renal crónica,endocarditis mitral,infarto esplénico, colección intaabdominal,fístula umbilical',
#  'hepatopatia crónica',
#  'ulcera varicosa,obesidad mórbida',
#  'posible sepsis de origen no filiado',
#  'ulcera sacra',
#  'deterioro cognitivo severo, enf parkison, d.mellitus,cardiopatia valvular,gammapatia monoclonal,insuf renal',
#  'deterioro cognitivo severo,esquizofrenia,neoplasia pulmón,itu',
#  'deterioro cognitivo severo, insuf cardiaca, valvulopatía mitral',
#  'infección respiratora. anciana frágil',
#  'suboclusión intestinal, adenoca recto',
#  'leucemia linfátic crónica',
#  'ca recto',
#  'ca pulmón,mieloma múltiple',
#  'icc,insuficiencia respiratoria global,cardiopatía hipertensiva',
#  'cefalea y sde confusional. icc',
#  'ulceras vasculares en eeii',
#  'sde confusional leve. icc',
#  'ca epidermoide oral región mentoniana',
#  'itu,neoplasia pulonar,deterioro cognitivo',
#  'ca ovario est iv',
#  'itu,diabetes mellitus,deterioro cognitivo severo',
#  'itu, anenoca recto',
#  'agonia, deterioro cognitivo',
#  'itu, deterioro cognitivo',
#  'neumonia,ic',
#  'infección respiratoria por pseudomonas, bronquiectasias',
#  'itu,demencia severa',
#  'neoplasia mieloproliferativa crónica tipo policitemia vera, enfermedad renal crónica avanzada',
#  'deterioro estado general paciente fragil',
#  'deshidratación. irenal cr',
#  'bronquiectasias infectadas por ps aeruginosa',
#  'ic avanzada clase funcional iv',
#  'ca renal est iv',
#  'anemia.sospecha suboclusión intestinal. probable proceso neoplásico intestinal.',
#  'agitación.deterioro cognitivo grave.patología de cadera dcha no diagnosticada',
#  'ca próstata, broncopatía cr',
#  'itu, deterioro cognitivo severo',
#  'ulcera trocánter izq',
#  'sospecha suboclusión intestinal. probable neo de colon',
#  'edema agudo de pulmón,neo colon transverso',
#  'ca renal',
#  'suboclusión intestinal por bridas y nódulo hepático',
#  'adenocarcinoma pancreas estadio iv',
#  'icc, insuf respiratoria mixta,adenoma velloso rectosigmoideo,sangrado digestivo bajo',
#  'icc, fa, broncopatía crónica, adenoma tubulosovelloso rectosigmoideo y sangrado digestivo bajo',
#  'cancer renal',
#  'broncoaspiracion. sindrome general',
#  'ulcera pierna',
#  'i respiratoria bursitis rodilla',
#  'hepatocarcinoma e iv',
#  'ulcera varicosa grave con infeccion stafilo multirresistente',
#  'nemonia,ic,ulceras piernas',
#  'bronquiestasis infectas:pseudomona aerug',
#  'cancer  vesical',
#  'cancer de cardias',
#  'celulitis',
#  'politraumatismo conlesion axonal difusa',
#  'adenoma hipofisario',
#  'trombosis v.yugular izq',
#  'lesión ulcerosa en pierna',
#  'epoc severo',
#  'cancer vias biliar',
#  'colangiocarcinoma es iv',
#  'leucemia mieloblastica',
#  'enfermedad de whipple',
#  'enfermedad de motoneurona',
#  'eca de vejiga infeccion urinaria',
#  'sindrome de miller-dieker',
#  'cancer de orofarnge',
#  'colonizacion germenes multirresistentes',
#  'síndrome anciano frágil',
#  'cancer de tiroides',
#  'cancer de endometriocontrol analgesico',
#  'ca de pancreas',
#  'hemorragia digestiva',
#  'infeccion respiratoria y urinaria',
#  'broquiectasias sobreinfectadas',
#  'meningioma',
#  'cirugia abdominal',
#  'linfoma',
#  'merkeloma',
#  'poliquistosis renal',
#  'cancer prostata y vejiga',
#  'ca de recto est-iv',
#  '1tu',
#  'lumbalgia',
#  'cancer de prostata y gist',
#  'sacroileitis',
#  'cancer de cervix',
#  'irc',
#  'hepatocarcinoma multicentrico',
#  'síndrome general',
#  'adca colon eiv',
#  'cancer neuroendocrino',
#  'infecion ptc',
#  'protocolo enf de pompe',
#  'ca pulmon e iv',
#  'artritis rodilla',
#  'sarcoidosis silicosis',
#  'epoc avanzado',
#  'ca prostata ee- iv',
#  'deterioro estado general paciemnte fragil',
#  'encefalopatia -anoxica',
#  'ca pulmon  iv',
#  'cushing',
#  'hiponatremia',
#  'cancer epidermoide',
#  'shock septico',
#  'adenocarcinoma pulmon estadio iv',
#  'ca pancreas estadio iv',
#  'demencia avanzada fast 7',
#  'sind hallerman sterif',
#  'neoplasia prostata estadio iv',
#  'adenocarcinoma pulmonar estadio iv',
#  'enf crohn. sind. intestino corto',
#  'sindrome facetario',
#  'amputacion',
#  'leucemia mieloide aguda',
#  'hepatocarcinoma , smd',
#  'ca epidermoide suelo de boca',
#  'icc',
#  'let broncoaspiracion de repèticion',
#  'colanfgiocarcinoma',
#  'ca colon e iv',
#  'cancer de vesicula',
#  'dehiscencia herida quirurgica',
#  'ca urotelial alto grado',
#  'infeccion abdominal',
#  'neoplasia pulmon estadio iv.',
#  'insuficiencia cardiaca avanzada',
#  'bronquiectasia infectadas',
#  'cancer oral',
#  'sobreinfeccion placas calcinosis',
#  'neoplasia mama .traumatismo por caida',
#  'neoplasia vesicula estadio iv',
#  '.demencia cuerpos lewi',
#  'prostatitis',
#  'adenocarcinoma hepatobilñiar',
#  'ca microcitico pulmón e iv',
#  'adenocarcinoma colon estadio iv',
#  'neoplasia mieloproliferativa',
#  'neoplasia mama estadio iv',
#  'iitu de repeticion',
#  'diverticulitis aguda complicada',
#  'hemorragia subaracnoidea',
#  'abcesos hepaticos',
#  'neoplasia esofago',
#  'adenocarcinoma de recto',
#  'ca renal e iv',
#  'sarcoma abdominal.',
#  'ca orofaringe',
#  'ca epidermoide de orofaringe',
#  'absceso cerebral',
#  'adenocarcinoma de prostata estadio iv',
#  'ca gastrico',
#  'anciano frágil',
#  'celulitis facial',
#  'neoplasia prostata',
#  'diabetes anciana fragil',
#  'obliteracion iliaca  grado iv',
#  'crisis asmatica',
#  'ulcera vascular',
#  'ca trigono retromolar',
#  'bronqiectasias',
#  'colecistitis aguda',
#  'mts oseas',
#  'distrofia muscular',
#  'pancreatitis',
#  'colangitis,cirrosis hepática,sospecha de hepatocarcinoma',
#  'leucoencefalopatia vascular,infec respirat',
#  'upp,esquizofrenia',
#  'sarcoma',
#  'bronquiectasis infectadas',
#  'calculos biliares',
#  'leucemia mielomonocítica',
#  'insuf.cardíaca',
#  'infec. respirat, deterioro cognitivo severo',
#  'adenoca colon',
#  'miocardiopatia dilatada',
#  'ait',
#  'enterolisis',
#  'isquemia arterial aguda',
#  'infecion respiratoria',
#  'obliteracion femoro poplitea derecha',
#  'fibrosis quistica',
#  'infeccion urinarui',
#  'ineumonia retrocardiaca',
#  'deterioro anciana fragil',
#  'pseudomixoma peritoneal',
#  'nieman pick',
#  'ca bronquialveolar',
#  'artritis carpo derecho',
#  'demenciam avanzada',
#  'adenocarcinoma pulmon',
#  'cardiopatia isquemica cronica',
#  'herida abdominal',
#  'miocardiopatia',
#  'infecc respiratoria',
#  'pie diabetico',
#  'cancer de recto.anemia',
#  'ca urotelial',
#  'enfermedad crohn . fournier',
#  'itu. agitacion',
#  'neoplasia urotelial. fibrosis pulmonar',
#  'trasplante cardíaco.tep.osteomielitis esternal',
#  'i.cardíaca',
#  'infeccion herida quirugica',
#  'ca celulas renales',
#  'neoplasia de vulva',
#  'neoplasia de colon',
#  'neoplasia de pulmon',
#  'neoplasia de pancreas',
#  'neoplasia de sigma',
#  'obliteracion femoro poplitea izquierda',
#  'neoplasia de ovario estadio iv',
#  'hernia lumbar',
#  'sde mielodisplásico.lma',
#  'icc. miocardiopatía dilatada',
#  'upps, deterioro cognitivo severo',
#  'ca colon',
#  'absceso abdominal',
#  'absceso pared abdominal',
#  'neumonia, ca colon',
#  'itu, i.renal cr',
#  'absceso msd, icc, ir global, ircr',
#  'neumonia basal dcha, empiema',
#  'ulceras varicosas',
#  'deterioro cognitivo severo, itu, inf resp',
#  'infec resp, epoc',
#  'inf resp,cirrosis hepática, irc en hemodiálisis, ca pulmón',
#  'leucemia linf crónica',
#  'neomonia por broncoaspiración',
#  'demencia avanzada. anciana fragil',
#  'diverticulitis aguda. demencia.',
#  'neoplasia sigma-recto',
#  'cirrosis hepatica- itu',
#  'dolor de dificil control',
#  'by pass obliteracion femoro poplitea',
#  'metastasis oseas de primario desconocido',
#  'celulitis brazo derecho',
#  'dolor mal controlado',
#  'ca colon estadio iv metas cerebrales',
#  'itu. anciano fragil',
#  'neoplasia colon sigma',
#  'demencia avanzada. perdida via oral',
#  'neo pulmon estadio iv',
#  'cacer de colon estadio iv',
#  'mesotelioma pleural',
#  'ca de colon',
#  'cancer recto estadio iv',
#  'ca encia',
#  'sarcoma pleomorfico',
#  'ulceras de decubito eeii',
#  'ca colos, penfogoide ampolloso',
#  'neo mama estadio iv',
#  'bacteriemia,pancreatitis ag,tce',
#  'ulceras vasculares, paciente fragil',
#  'encefalopatia',
#  'adenocarcinoma pancreaas estadio iv',
#  'bacteriemia, ir cr, ca pulmón',
#  'ca gástrico, isquemia mesentérica, tep',
#  'ulceras vasculares eeiiizq',
#  'cancer vejiga',
#  'ca pancreas estadioiv',
#  'ca pulmón e iv',
#  'tratamiento antibiotico, ic delirium',
#  'hematuria',
#  'icc, hipoalbuminemia',
#  'dificultad para tragar',
#  'cirrosis hepática, hepatocarcinoma',
#  'icc, i renal cr',
#  'ictus isquémico',
#  'liposarcoma pleomorfico',
#  'ca de pulmon estadio iv',
#  'i.cardíaca epoc',
#  'demencia, itu',
#  'icc. herida abierta en flexura codo derecho',
#  'deteriroro cognitivo',
#  'artritis reumatoidea',
#  'adenoca colon e iv',
#  'ca pulmón',
#  'cancer de colon y gastrico',
#  'estado vegetativo. infecion respiratoria.',
#  'itu .paraplejia.',
#  'icc. cor pulmonale',
#  'laminectomia c3- c4',
#  'by pass femorom popliteo izquierdo ulceran talon',
#  'anmputacion transmetatarsiana  4 y 5 dedo pie derecho',
#  'meningitis virus h.zoster',
#  'insuficiencia cardíaca',
#  'ca prostata estadio iv, lumboartrosis, itu en paciente sondado',
#  'endocarditis bacteriana, acv',
#  'fiebre,diarrea,deterioro cognitivo',
#  'valoracion ulceras',
#  'ca colon, estenosis gástrica',
#  'ulcera pierna izq, insuf venosa',
#  'enfermedad de whiple',
#  'ca colo, toxicidad a quimioterapia',
#  'isquemia eeii izquierda. demencia',
#  'ulceras  en eeii izquierda pantorrilla',
#  'compresion medular',
#  'psraplejia',
#  'enf. nieman pick',
#  'leucemia mielomonocitica cronica',
#  'upps, esclerosis múltiple, epilepsia',
#  'linfoma alto grado',
#  'epid agudizada',
#  'ca microcitico pulmon e iv',
#  'neoplasia de pancreas estadio',
#  'enfermedad de lyme',
#  'ca pulmón, transplantado cardíaco',
#  'icc, i renal crónica',
#  'anemia microcitica',
#  'adenocarcinoma esofago-gastrico',
#  'neo- colon estadio iv',
#  'infeccion tracto urinario',
#  'neoplasia orl',
#  'colangiocarcinoma estadio iv',
#  'carcinoma urotelial estadio iv',
#  'itu. teptraplejia',
#  'ulcera vascular m.inf.izq,miocardiopatia. insuf.renal cr',
#  'bypass',
#  'ca microcítico pulmón',
#  'absceso uterino',
#  'neoplasia colon dolor mal controlado',
#  'neoplasia colon itu',
#  'leucemia mieloide',
#  'adenoca páncreas',
#  'bacteriemia, sospecha de colangitis',
#  'neo orofaringe',
#  'bacteriemis, seminoma',
#  'cancer escamoso',
#  'ulcera traumática muslo izq, covid +',
#  'recidiva ca esófago',
#  'infección respiratoria, deterioro cognitivo severo',
#  'infección respitoria, ic',
#  'adenoca próstata e iv',
#  'acv   isquemico alteracion deglucion',
#  'isquemia mesenterica',
#  'lesion medular',
#  'ca colon e-iv',
#  'ca neuroendocrino',
#  'ca vejiga, acv',
#  'cirrosis alcohólica',
#  'enfermedad cavitada m. avium',
#  'gist',
#  'colangiocarcinoma,adenocarcinoma de pulmón,carcinoma epidermoide de glotis',
#  'dispepsia. icc.',
#  'meningitis',
#  'encefalopatia postcovid',
#  'ulcera isquiatica',
#  'i.cardíaca,ulcera traumática pierna dcha',
#  'revascularizacion',
#  'ca pancreas, infección peripancreatica',
#  'tumor cereblal',
#  'abscesos hepáticos',
#  'desnutricion proteica-calorica',
#  'hipogammaglobulinemia',
#  'protesis vascular infectada',
#  'ca pulmón, oblit aortofemoral izq',
#  'aneurismectomia',
#  'hipertiroidismo por amiodarona',
#  'ulcera  miembro inferiror derecho',
#  'ulceras',
#  'enfermedad intersticial fase fibrotica',
#  'cancer de prostata estadio iv',
#  'i. cardíaca',
#  'tumor indiferenciado abdominal de origen desconocido estadio iv',
#  'ca pancreas, colección encapsulada peripancreatica,ca próstata',
#  'hematoma',
#  'icc, infecc respiratoria',
#  'ic descompensada',
#  'ca mama estadio iv,fr patológica cuello y diáfisis femoral ixq,tumor neuroendocrino de páncreas',
#  'deterioro cognitivo avanzado,trastorno motor esofágico',
#  'sospecha de itu, encefalopatía anóxica',
#  'lumbalgia, aneurisma de aorta',
#  'ulcera isquion',
#  'cancer de sigma',
#  'epoc, infec.respirat',
#  'isquemia arterial aguda eeii',
#  'absceso paravesical',
#  'ca epidermoide est iv',
#  'hipernefroma',
#  'dolor precordial',
#  'itu/infección respiratoria. deterioro cognitivo severo',
#  'ulcera pierna izq, insuf venosa. i.cardíaca',
#  'ulcera isquiatica, esclerosis multiple',
#  'linfoma b de células grandes intravascular',
#  'encefalopatia post anoxica',
#  'encefalopatía hepática. cirrosis hepática',
#  'hipertension demencia avanzada',
#  'neoplasia pancreas estadio iv',
#  'ca gástrico',
#  'scffv',
#  'icc, deterioro cognitivo grave',
#  'ella',
#  'carcinomatosis',
#  'ulcera venosa',
#  'leiomiosarcoma',
#  'astrocitoma est iv',
#  'ca epidermoide cavum',
#  'arteriopatía periférica crónica: obliteración iliofemoral bilateral, grado iv en mii',
#  'infección bypass aortofemoral izq',
#  'ca recto est iv',
#  'capulmón est iv',
#  'gonartrosis bilateral',
#  'amputación digital',
#  'linfoma no hogkin',
#  'mesotelioma',
#  'obliteracion fp-mii',
#  'cirrosis criptogenica',
#  'cardiopatia en fa',
#  'cordoma, infección sacroccigea',
#  ...]

# %%
df_concatenado.head()
# Out:
#   h_procedencia s_procedencia  ap otros                  diagnostico  \
# 0   gil casares          upal  no    no                       ca orl
# 1       clinico           onc  no    no              melanoma vulvar
# 2       clinico           mir  no    no              ca broncogenico
# 3       clinico           dig  no    no            cirrosis hepatica
# 4       clinico           urg  no    no  neplasia de mama estadio iv
#
#                    motivo_ing paliativo_onc/noc paliativo_no_onc/noc fiebre  \
# 0           contro d sintomas                si                   si     no
# 1           mal control dolor                si                   no     no
# 2           control evolutivo                si                   si     no
# 3  admininistacion octreotido                no                   no     no
# 4         control de sintomas                si                   no     no
#
#   disnea dolor delirium otros_1 p_terminal agonia ps/ecog barthel gds/fast  \
# 0     no    si       no      no         si     no     NaN     NaN       no
# 1     no    si       no      no         si     no     3-4      no       no
# 2     si    no       no      no         no     no     3-4     NaN       no
# 3     no    no       no      no         no     no     NaN     NaN       no
# 4     si    si       no      no         si     no     NaN     NaN       no
#
#   eva_ing otros_2      otros/complicaciones  n_estancias  n_visitas sedacion  \
# 0      no      no    reingreso en urgencias         21.0       10.0       no
# 1      no      no  met. pulmonares y digest         24.0        8.0       no
# 2      no      no                        no         14.0        6.0       no
# 3      no      no                        no          1.0        1.0       no
# 4     NaN      no                        no          2.0        1.0       no
#
#        motivo_alta         medico  year ast/anorx agudo_estable cronico_reag  \
# 0        reingreso         valdes  2017        si           NaN          NaN
# 1           exitus    galego feal  2017        si           NaN          NaN
# 2  fin de cuidados  lopez renedo.  2017        no           NaN          NaN
# 3  fin de cuidados  lopez renedo.  2017        no           NaN          NaN
# 4           exitus  lopez renedo.  2017        no           NaN          NaN
#
#   transfusion paracentesis toracocentesis ayuntamiento fecha_alta   ¿?  \
# 0         NaN          NaN            NaN          NaN        NaN  NaN
# 1         NaN          NaN            NaN          NaN        NaN  NaN
# 2         NaN          NaN            NaN          NaN        NaN  NaN
# 3         NaN          NaN            NaN          NaN        NaN  NaN
# 4         NaN          NaN            NaN          NaN        NaN  NaN
#
#   toracocen
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# # Kedro
#
# 1. Instalar Kedro y crear el proyecto
# 2. Instalar modulos y librerías necesarias en `requirements.txt` (ir actualizando a medida que se van añadiendo)
# 3. Añadir y leer los datos del proyecto:
#    1. Añadimos los archivos en la carpeta `data/01_raw`
#    2. Creamos un archivo python que contenga una clase para que lea los datos por ejemplo: ODS_Data_Set en `src/hado_cares`
